# %% [markdown]
# # **Comet Experiment**

# %%
# Install the comet_ml if the code below is missing the package
# !pip install comet_ml

# %%
# import comet_ml at the top of your file
from comet_ml import Experiment

# Create an experiment with your api key:
experiment = Experiment(
    api_key="ZBRB8H2ncCGZsUoS6CqVIAr0y",
    project_name="general",
    workspace="knetshiongolwe",
)
# Out:
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/knetshiongolwe/general/4aed267b35f14b309732dc96dd53971d

# %% [markdown]
# <a id="section-one"></a>
#
# # **Import libraries and datasets**
#
# We will be working with the famous Surprise(Simple Python RecommendatIon System Engine.) Library, Surprise is a Python scikit for building and analyzing recommender systems that deal with explicit rating data.
#
# Below are all libraries that are used through out this notebook.

# %%
# data analysis libraries
import pandas as pd
import numpy as np

# visualisation libraries
from matplotlib import pyplot as plt
import seaborn as sns
from numpy.random import RandomState


# Notebook styling
# %matplotlib inline
sns.set()


# ML Models
from surprise import Reader
from surprise import Dataset
from surprise.model_selection import cross_validate
from surprise import CoClustering
from surprise.accuracy import rmse
from surprise import accuracy

# ML Pre processing
from surprise.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Hyperparameter tuning
from surprise.model_selection import GridSearchCV

# High performance hyperparameter tuning
#from tune_sklearn import TuneSearchCV
#import warnings
#warnings.filterwarnings("ignore")

# %% [markdown]
# # **Loading data**
# <a id="section-two"></a>
#
# We will load all the dataframes that we desire to work with

# %%
#Pandas libraries used in the notebook.
train = pd.read_csv('./data/train.csv')
test_df = pd.read_csv('./data/test.csv')
df_movies = pd.read_csv('./data/movies.csv')
# df_samp = pd.read_csv('/kaggle/input/edsa-recommender-system-predict/sample_submission.csv')
# df_imdb = pd.read_csv('/kaggle/input/edsa-recommender-system-predict/imdb_data.csv')
# df_gtags = pd.read_csv("/kaggle/input/edsa-recommender-system-predict/genome_tags.csv")
# df_scores = pd.read_csv("/kaggle/input/edsa-recommender-system-predict/genome_scores.csv")
# df_tags = pd.read_csv("/kaggle/input/edsa-recommender-system-predict/tags.csv")
# df_links = pd.read_csv("/kaggle/input/edsa-recommender-system-predict/links.csv")

# %% [markdown]
# <a id="section-three"></a>
# # **Evaluating Data**
#
# Here is the data that we are was given to us.
# Supplied Files
# *
# * train.csv - The training split of the dataset. Contains user and movie IDs with associated rating data.
#
# *Description of the data that is given to us *

# %%
#viewing training data
train.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %% [markdown]
# Train:
#
# * UserId
# * movieId : Identifier for movies used
# * rating : Ratings are made on a 5-star scale, with half-star increments (0.5 stars - 5.0 stars).
# * timestamp: represent seconds since midnight Coordinated Universal Time (UTC) of January 1, 1970.

# %%
#Viewing movies data
df_movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %% [markdown]
# Movies:
#
# * movieId : Identifier for movies used
#
# * title : These were entered manually or imported from https://www.themoviedb.org/, and include the year of release in parentheses. Errors and inconsistencies may exist in these titles.
#
# * genres: Genres are a pipe-separated list, and are selected from the following:
#
#     * Action
#     * Adventure
#     * Animation
#     * Children's
#     * Comedy
#     * Crime
#     * Documentary
#     * Drama
#     * Fantasy
#     * Film-Noir
#     * Horror
#     * Musical
#     * Mystery
#     * Romance
#     * Sci-Fi
#     * Thriller
#     * War
#     * Western
#     * (no genres listed)

# %% [markdown]
# <a id="section-four"></a>
# # **Data Preprocessing**
# **Preparing raw data:**
#
# We will first prepare this raw data to make it suitable for our machine learning model. This is a very crucial step while for creating a machine learning model.

# %% [markdown]
# <a id="subsection-one"></a>
# # **Checking for missing values column wise**
#
# **Handling Missing Data:**
#
# In our dataset, there may be some missing values. We cannot train our model with a dataset that contains missing values. So we have to check if our dataset has missing values.

# %%
#check for missing values
train.isnull().sum()
# Out:
# userId       0
# movieId      0
# rating       0
# timestamp    0
# dtype: int64

# %% [markdown]
# <a id="subsection-two"></a>
# # **Checking for duplicates records**
# **Checking Duplicate Values:**
#
# At times our dataset may entail some duplicated values which are not necessary therefore this values must be removed, befor removing these duplicates we are able to first check if we do have them. We will implement this by the code below.

# %%
#check duplicates
dup_bool = train.duplicated(['userId','movieId','rating'])

#display duplicates
print("Number of duplicate records:",sum(dup_bool))
# Out:
# Number of duplicate records: 0

# %% [markdown]
# <a id="subsection-three"></a>
# # **Creating a copy**
#
# We will rename our train data as df and look at the top 5 records in the dataframe.

# %%
df = train.copy()

# %%
#create a copy of the train data
df_train = train.copy()

#display top 5 records
df_train.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %% [markdown]
# ## **Evaluating Length of Unique Values**

# %%
# Find the length of the unique use
len(df_train['userId'].unique()), len(df_train['movieId'].unique())
# Out:
# (671, 9066)

# %%
#view movies
df_movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %% [markdown]
# ## **Joining Datasets**

# %%
# Merge
df_merge1 = df_train.merge(df_movies, on = 'movieId')
df_merge1.head()
# Out:
#    userId  movieId  rating   timestamp                   title genres
# 0       1       31     2.5  1260759144  Dangerous Minds (1995)  Drama
# 1       7       31     3.0   851868750  Dangerous Minds (1995)  Drama
# 2      31       31     4.0  1273541953  Dangerous Minds (1995)  Drama
# 3      32       31     4.0   834828440  Dangerous Minds (1995)  Drama
# 4      36       31     3.0   847057202  Dangerous Minds (1995)  Drama

# %% [markdown]
# # **Collaborative Filtering**
#
# **What Is Collaborative Filtering?**
#
# Collaborative filtering is a technique that can filter out items that a user might like on the basis of reactions by similar users.
#
# It works by searching a large group of people and finding a smaller set of users with tastes similar to a particular user. It looks at the items they like and combines them to create a ranked list of suggestions.
#
# to be more precise it is based on similarity in preference , taste and choices of two users. A good example that we can give you could be if user A likes movies 1,2 and 3 and user B likes movies 2,3 and 4 then this implies that they have similar interests and user A should like movie 4 and B should like movie 1.
#
#
# **Why Do We Consider Collaborating Filtering Over Content Based Filtering?**
#
# Collaborative filtering recommender engine is a much better algorithim then content content based filtering since it is able to do feature laerning on its own, in other words it can laern which features to use
#
# **Advantages of Collaborative filtering:**
#
# Taken that we find collaborative filtering better than content based, We will give a few adavntages to support the argument.
#
# * Takes other user ratings into consideration
# * Doesnt need to study or extract information from recommended item.
# * It adapts to the user' interest which might change over time.
#
# **About Collaborative Filtering Datasets:**
#
# To take note that in order for us to implement this algorithm or any recommendation algorithms  we need a specific dataset that is stuctured in a specific format. This data should entail a set of items and users who have reacted to some of the items.
#
# While working with such data, you’ll mostly see it in the form of a matrix consisting of the reactions given by a set of users to some items from a set of items. Each row would contain the ratings given by a user, and each column would contain the ratings received by an item. A matrix with five users and five items could look like this:
#
#
# **Rating Matrix:**
#
#
# ![](https://files.realpython.com/media/rating-matrix.04153775e4c1.jpg)
#
# The matrix shows five users who have rated some of the items on a scale of 1 to 5. For example, the first user has given a rating 4 to the third item. n most cases, the cells in the matrix are empty, as users only rate a few items. It’s highly unlikely for every user to rate or react to every item available. A matrix with mostly empty cells is called sparse, and the opposite to that (a mostly filled matrix) is called dense.
#
# **How do you measure the accuracy of the ratings you calculate?**
#
# Esentially there are many approaches but we will explain the main approach that we will need for this project which is the Root Mean Square Error (RMSE), in which you predict ratings for a test dataset of user-item pairs whose rating values are already known. The difference between the known value and the predicted value would be the error. Square all the error values for the test set, find the average (or mean), and then take the square root of that average to get the RMSE.
#
# ![](https://www.analyticsvidhya.com/wp-content/uploads/2016/02/rmse.png)
#
# Another metric to measure the accuracy is Mean Absolute Error (MAE), in which you find the magnitude of error by finding its absolute value and then taking the average of all error values.
#
# However we will be focusing on the RMSE for our predictions.
#
# Before diving deep into the code we would like to clarify the Type of collaborative filtering we are going to implement.
#
# Recommender Sysem is divided ito Three brances of which collaborative filtering is entailed, the figure below will make a clear breakdown to the reader.
#
# ![](https://www.seoclerk.com/pics/want61009-1nSWOn1525162745.jpg)
#
# You will notice that Collaborative filtering consist of two filtering techniques,
#
# * **Model-based Technique**
# * **Memory-based filtering**
#
# We will give a short description of these techniques.
#
# * **Model-based Technique**
# Model based collaborative filtering algorithms provide item recommendations by first developing a model of user ratings. With these systems you will build a model from user ratings and then make recommendations based on that model, this offers a speed and scalability that not available when
# youre forced to refer back to the entire dataset to make a prediction.
#
# * **Memory based filtering**
# Memory based rely heavely on simple similarity measures(cosine similarity, pearson correlation and more) to match similar people or items together.
# thses consist of two methods namely **Item based** and **user based** collaborative filtering.
#
# The figure below defines the two filtering methods.
#
# ![](https://cdn-images-1.medium.com/max/1600/1*7uW5hLXztSu_FOmZOWpB6g.png)

# %% [markdown]
#  ### **Loading as Surprise Dataframe**
#
# We will be using the dataset module which loads the pandas dataframe that is available for this experiment, The reader function is used to parse a file containing ratings data. The default format in which it accepts data is
# that each rating is stored in a separate line in the order user, movie and rating

# %%
# Loading as Surprise dataframe 
reader = Reader()
data = Dataset.load_from_df(train[['userId', 'movieId', 'rating']], reader)

# %% [markdown]
# ### **Splitting into Train and Test Set**
#
# Another way to implement the sampling of the trainset and testset without the use of a cross validate procedure is by using a train test split given the sizes , with the acuracy metrics of choice.
#
# We use a random trainset and testset with the testset that is only 15% of the ratings.

# %%
# Data split 85/15
trainset, testset = train_test_split(data, test_size=0.15)

# %% [markdown]
# ### **Training  Model**
#
# Using the base algoritm of `Co Clustering` we will fit method which will train the algorithm on the trainset and and the test() method which will return the predictions made from the testset furthermore storing all our predictions on a dataframe called test.

# %%
co_clust = CoClustering()

# %%
# Fitting our trainset
co_clust.fit(trainset)

# Using the 15% testset to make predictions
predictions = co_clust.test(testset) 
predictions

test = pd.DataFrame(predictions)

# %% [markdown]
# Let us have a closer look into the predictions on the dataframe test.

# %%
# View the head
test.head()
# Out:
#    uid    iid  r_ui       est                    details
# 0  580   1343   3.5  3.538235  {'was_impossible': False}
# 1  199  89492   4.0  3.399947  {'was_impossible': False}
# 2  243   2987   3.5  3.415926  {'was_impossible': False}
# 3  461   1721   4.0  2.467934  {'was_impossible': False}
# 4  575   2287   1.0  4.108223  {'was_impossible': False}

# %% [markdown]
# ### **Evaluate Model**
#
# Utilising the test dataframe that we have created we are going to predict some of the ratings for each userId and movieId pair, this ratings predictions will be collected and stored as a list consiting of these pairs, ideally this list will help in predicting unknown values in the original matrix(test_df dataframe) (this is also known as matrix completion)
#
# Let us look at the list called ratings predictions.

# %%
# We are trying to predict ratings for every userId / movieId pair, we implement the below list comprehension to achieve this.
ratings_predictions=[co_clust.predict(row.userId, row.movieId) for _,row in test_df.iterrows()]
ratings_predictions
# Out:
# [Prediction(uid=102413, iid=74, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=122968, iid=52328, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=89372, iid=1188, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=1812, iid=6874, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=7355, iid=112175, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=159376, iid=2087, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=47553, iid=1172, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=70393, iid=7361, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=42418, iid=594, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=101637, iid=923, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=131243, iid=648, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=8979, iid=130976, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=110801, iid=4356, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=96360, iid=2087, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=146684, iid=2716, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=94751, iid=2340, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=49679, iid=5971, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=22510, iid=919, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=160179, iid=6936, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=127341, iid=107081, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=59996, iid=174585, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=10296, iid=175569, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=59956, iid=2193, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=22123, iid=6874, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=133900, iid=1278, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=78262, iid=42718, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=68032, iid=111781, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=94339, iid=4836, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=80176, iid=593, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=65606, iid=2987, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=50731, iid=1238, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=12429, iid=79, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=30447, iid=5299, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=55131, iid=912, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=86222, iid=208, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=69779, iid=2858, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=83491, iid=593, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=26248, iid=2716, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=124345, iid=7382, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=51734, iid=1527, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=134691, iid=1653, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=72315, iid=160826, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=141048, iid=1240, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=46716, iid=118696, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=113124, iid=908, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=14773, iid=122892, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=67890, iid=235, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=40523, iid=5952, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=147912, iid=1377, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=129333, iid=5303, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=147935, iid=97188, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=22534, iid=1200, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=102436, iid=150, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=20959, iid=2505, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=103834, iid=1124, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=118906, iid=134680, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=68536, iid=2318, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=48683, iid=105844, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=103678, iid=914, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=98956, iid=117887, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=59219, iid=6893, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=49435, iid=596, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=135556, iid=49272, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=88230, iid=59141, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=6936, iid=2802, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=4559, iid=1459, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=114526, iid=1645, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=39183, iid=680, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=74041, iid=1275, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=23432, iid=593, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=8739, iid=356, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=58904, iid=96821, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=82917, iid=73572, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=157095, iid=87232, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=24641, iid=1363, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=149866, iid=509, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=14508, iid=4531, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=135340, iid=179819, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=33844, iid=113037, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=125515, iid=59315, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=59621, iid=1201, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=40991, iid=38038, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=44895, iid=165549, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=67353, iid=1234, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=141022, iid=2012, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=3369, iid=1101, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=114459, iid=108, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=61551, iid=7044, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=11966, iid=48518, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=56968, iid=4027, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=100171, iid=3858, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=88466, iid=153, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=81271, iid=4034, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=81663, iid=595, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=54748, iid=7022, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=103799, iid=54001, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=141622, iid=180, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=33844, iid=3827, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=38776, iid=780, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=140902, iid=7153, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=119259, iid=334, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=38814, iid=1407, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=134613, iid=906, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=21727, iid=1240, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=33145, iid=357, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=98524, iid=58803, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=134780, iid=2985, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=147260, iid=2571, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=21180, iid=357, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=9494, iid=53121, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=13062, iid=541, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=117309, iid=111, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=91053, iid=110, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=122138, iid=5618, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=160139, iid=2273, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=33574, iid=122892, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=20331, iid=6593, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=30831, iid=4901, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=77889, iid=2208, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=92197, iid=1586, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=32972, iid=4993, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=119531, iid=3753, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=98110, iid=122918, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=83040, iid=1405, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=152575, iid=1037, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=143295, iid=2986, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=25178, iid=2169, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=18580, iid=104211, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=160749, iid=541, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=91836, iid=1573, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=18513, iid=1358, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=136248, iid=198, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=59344, iid=2083, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=25801, iid=3683, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=15459, iid=3606, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=113668, iid=61248, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=132126, iid=663, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=133761, iid=103027, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=35620, iid=122886, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=25634, iid=3915, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=75830, iid=7379, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=107347, iid=3471, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=127342, iid=4911, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=118804, iid=165, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=56992, iid=2529, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=27963, iid=4993, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=138533, iid=1466, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=87772, iid=3481, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=67637, iid=2046, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=89865, iid=2700, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=774, iid=69406, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=113331, iid=110, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=67799, iid=2301, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=30621, iid=30793, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=141385, iid=3386, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=98434, iid=1258, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=18303, iid=465, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=49169, iid=296, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=12817, iid=593, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=149638, iid=26150, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=59418, iid=51084, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=112064, iid=202439, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=110852, iid=1304, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=15121, iid=33493, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=88230, iid=2366, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=46233, iid=6604, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=20055, iid=5358, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=97680, iid=2952, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=63257, iid=1882, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=548, iid=7383, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=36637, iid=19, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=12033, iid=4876, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=94178, iid=187229, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=150223, iid=73017, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=97942, iid=2393, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=72315, iid=27675, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=92111, iid=173, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=161725, iid=27674, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=128472, iid=3525, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=121029, iid=3451, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=60856, iid=1265, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=141899, iid=508, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=92412, iid=89745, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=106379, iid=6754, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=82183, iid=112183, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=139924, iid=2699, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=122214, iid=105, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=143835, iid=139747, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=125884, iid=5010, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=89394, iid=3623, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=26117, iid=2724, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=10353, iid=4085, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=82428, iid=2375, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=82521, iid=2355, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=14614, iid=3257, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=82273, iid=839, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=41215, iid=4995, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=98144, iid=122904, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=49376, iid=122900, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=87554, iid=2053, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=61912, iid=54372, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=91660, iid=103980, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=162481, iid=2395, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=38008, iid=4776, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=145650, iid=8169, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=93297, iid=4082, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=144308, iid=260, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=120866, iid=1356, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=149332, iid=2324, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=75282, iid=1196, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=39730, iid=1222, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=115912, iid=2517, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=108322, iid=2023, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=101116, iid=5445, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=5968, iid=185, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=29431, iid=34332, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=10458, iid=32, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=109133, iid=27660, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=93712, iid=2950, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=1831, iid=6565, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=22175, iid=76093, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=56949, iid=6377, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=48404, iid=799, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=94093, iid=60069, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=58007, iid=3984, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=66052, iid=593, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=145078, iid=1587, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=23395, iid=3578, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=41449, iid=1225, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=29021, iid=170637, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=89247, iid=2005, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=31889, iid=105954, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=117472, iid=45722, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=735, iid=32, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=137293, iid=77985, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=83150, iid=1049, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=76040, iid=1704, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=80602, iid=2529, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=150773, iid=72919, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=140059, iid=1982, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=48124, iid=104, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=19384, iid=70286, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=132182, iid=173291, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=28863, iid=318, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=81519, iid=480, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=71639, iid=5574, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=42688, iid=8644, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=87229, iid=37729, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=132482, iid=1884, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=112064, iid=1036, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=25469, iid=48516, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=154515, iid=45499, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=139725, iid=5008, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=60564, iid=3044, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=143798, iid=179135, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=91400, iid=3499, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=142640, iid=5679, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=107316, iid=50872, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=113704, iid=2724, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=145956, iid=4975, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=116486, iid=1235, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=17582, iid=596, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=116942, iid=3114, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=67433, iid=1203, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=84641, iid=2375, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=80907, iid=6333, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=118475, iid=40819, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=150882, iid=5618, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=149666, iid=1732, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=94600, iid=5418, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=100021, iid=899, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=135878, iid=597, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=125504, iid=276, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=16746, iid=7179, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=16658, iid=2459, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=25532, iid=5673, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=67474, iid=65261, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=88430, iid=7073, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=96925, iid=3999, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=134768, iid=249, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=91668, iid=218, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=140038, iid=3091, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=11486, iid=51662, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=95395, iid=93831, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=156938, iid=1230, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=143030, iid=6932, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=74507, iid=3535, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=110618, iid=34162, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=12313, iid=1271, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=15418, iid=4235, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=64069, iid=109487, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=16822, iid=1262, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=697, iid=5254, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=72850, iid=99114, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=21141, iid=76, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=52964, iid=2379, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=66657, iid=5816, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=92269, iid=2000, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=127493, iid=4103, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=53533, iid=1584, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=17650, iid=97938, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=117350, iid=91535, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=158724, iid=3166, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=88102, iid=4661, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=127681, iid=597, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=159936, iid=1687, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=89536, iid=177689, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=55005, iid=3253, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=37616, iid=5942, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=123315, iid=86190, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=29104, iid=6537, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=82304, iid=44195, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=122497, iid=7022, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=161546, iid=74458, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=10824, iid=60, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=86103, iid=6537, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=90410, iid=3468, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=78373, iid=1267, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=100956, iid=3726, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=19799, iid=2502, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=66455, iid=8961, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=60464, iid=68157, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=35585, iid=84152, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=108577, iid=4563, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=157161, iid=2942, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=81231, iid=2890, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=53771, iid=8368, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=115131, iid=97304, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=97923, iid=110553, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=158147, iid=32587, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=9443, iid=8533, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=66401, iid=1911, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=59866, iid=5952, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=155165, iid=170705, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=49170, iid=2944, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=37753, iid=136622, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=7205, iid=903, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=87094, iid=1081, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=119657, iid=6999, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=51360, iid=30749, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=138588, iid=3147, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=154422, iid=586, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=82267, iid=6936, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=41024, iid=480, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=38727, iid=2110, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=11466, iid=1240, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=153348, iid=5692, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=155985, iid=78266, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=62774, iid=1291, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=129204, iid=1603, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=138105, iid=912, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=132222, iid=3826, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=148431, iid=3331, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=107973, iid=431, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=123621, iid=44022, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=33525, iid=3535, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=20223, iid=1278, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=5872, iid=8984, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=108521, iid=61024, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=77139, iid=7454, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=19140, iid=1917, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=51474, iid=247, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=139968, iid=4085, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=28829, iid=5418, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=134780, iid=748, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=127937, iid=2359, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=61787, iid=7439, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=61379, iid=90249, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=32958, iid=5981, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=84900, iid=1150, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=70616, iid=4527, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=110123, iid=7147, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=70063, iid=1203, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=17166, iid=5090, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=145872, iid=80928, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=48379, iid=2858, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=3743, iid=3354, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=101734, iid=6502, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=144860, iid=8169, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=136503, iid=2174, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=110971, iid=7016, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=51288, iid=355, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=77628, iid=2921, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=66050, iid=2329, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=148746, iid=8528, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=47733, iid=2116, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=107136, iid=2126, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=119324, iid=1042, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=20055, iid=80, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=28346, iid=480, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=97890, iid=91386, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=7865, iid=7164, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=111514, iid=587, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=128110, iid=3555, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=121714, iid=1206, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=143741, iid=5952, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=35674, iid=8368, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=5052, iid=1537, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=80930, iid=3, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=157775, iid=780, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=150088, iid=3263, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=77446, iid=6711, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=9361, iid=2671, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=104320, iid=44840, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=101039, iid=260, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=149296, iid=1748, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=139911, iid=3798, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=17303, iid=1639, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=34777, iid=3623, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=101644, iid=5679, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=80266, iid=100, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=76019, iid=63853, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=136050, iid=3996, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=4358, iid=33493, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=34765, iid=506, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=148378, iid=7451, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=77379, iid=3450, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=95998, iid=96610, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=98328, iid=84637, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=133729, iid=1221, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=107513, iid=8512, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=112118, iid=709, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=150155, iid=356, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=158685, iid=207, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=101559, iid=2338, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=120242, iid=435, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=47073, iid=3527, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=129562, iid=858, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=77657, iid=98056, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=100396, iid=1210, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=142111, iid=3811, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=49816, iid=60336, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=93560, iid=25825, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=113199, iid=1033, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=101775, iid=5349, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=40211, iid=78041, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=64030, iid=50, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=89838, iid=3793, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=113727, iid=2482, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=123832, iid=71252, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=133742, iid=60684, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=11742, iid=6807, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=106753, iid=30812, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=31176, iid=1207, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=561, iid=1213, r_ui=None, est=3.8132158730913566, details={'was_impossible': False}),
#  Prediction(uid=3272, iid=6281, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=136708, iid=1089, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=36825, iid=2657, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=112897, iid=42217, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=158028, iid=1096, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=105508, iid=76251, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=118668, iid=3255, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=149910, iid=3972, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=41644, iid=150, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=36082, iid=167634, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=46515, iid=1284, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=137198, iid=8591, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=9750, iid=8360, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=38263, iid=2542, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
# ...
#  Prediction(uid=109427, iid=318, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=146319, iid=115617, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=62852, iid=172, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=77367, iid=97172, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=96266, iid=4886, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=44411, iid=111, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=160747, iid=4133, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=133786, iid=1186, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=32963, iid=88125, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=79078, iid=799, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=117348, iid=1378, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=35349, iid=4553, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=140939, iid=2996, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=70051, iid=4016, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=27326, iid=54001, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=133607, iid=213, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=15859, iid=1334, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=2379, iid=2096, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=5692, iid=2424, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=52692, iid=1777, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=159326, iid=296, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=139100, iid=6979, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=6262, iid=593, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=107269, iid=52717, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=115900, iid=1254, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=29896, iid=177593, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=41653, iid=1732, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=159890, iid=2542, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=134949, iid=3247, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=33751, iid=3576, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=34231, iid=247, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=20073, iid=273, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=111663, iid=1104, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=55189, iid=83613, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=88336, iid=1343, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=47842, iid=588, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=1977, iid=2183, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=149897, iid=3690, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=160917, iid=45517, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=103896, iid=1196, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=59260, iid=2735, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=72106, iid=541, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=78982, iid=3481, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=127240, iid=608, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=26453, iid=56788, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=32063, iid=2395, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=1977, iid=7055, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=76531, iid=25841, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=131621, iid=4649, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=97164, iid=2571, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=85941, iid=139148, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=129386, iid=428, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=146414, iid=86320, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=78849, iid=6684, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=5800, iid=1147, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=28682, iid=64957, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=106195, iid=35836, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=24092, iid=1527, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=156210, iid=3527, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=128743, iid=1203, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=129814, iid=112138, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=156617, iid=550, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=130302, iid=107, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=103153, iid=2355, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=93884, iid=3435, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=128632, iid=4886, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=28225, iid=2875, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=139311, iid=3114, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=77386, iid=588, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=124726, iid=5464, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=100065, iid=46965, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=98599, iid=527, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=122749, iid=112, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=138541, iid=272, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=91109, iid=593, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=93687, iid=30707, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=32778, iid=108981, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=90656, iid=55069, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=63999, iid=65261, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=71076, iid=1090, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=33291, iid=8525, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=19997, iid=48394, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=18831, iid=2959, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=22283, iid=4017, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=123298, iid=588, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=83077, iid=3469, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=131474, iid=80463, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=29965, iid=7153, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=60597, iid=1947, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=142171, iid=2053, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=26135, iid=2797, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=35930, iid=2918, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=136174, iid=2712, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=149279, iid=1620, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=107755, iid=2081, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=41177, iid=3504, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=154143, iid=373, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=2834, iid=48780, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=73033, iid=2081, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=158271, iid=2902, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=57079, iid=84392, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=6445, iid=4366, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=42148, iid=288, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=36319, iid=1304, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=59853, iid=111, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=2482, iid=1353, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=82680, iid=785, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=74583, iid=4069, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=45196, iid=2906, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=53532, iid=474, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=32753, iid=1078, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=20555, iid=2005, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=112471, iid=56367, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=24006, iid=160, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=125325, iid=7153, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=154682, iid=49272, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=91450, iid=3408, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=140694, iid=2502, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=58686, iid=1212, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=22142, iid=316, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=48429, iid=2000, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=55701, iid=49649, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=74069, iid=1373, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=86780, iid=4022, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=17188, iid=293, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=2638, iid=6345, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=9236, iid=46976, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=122217, iid=6296, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=129627, iid=64511, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=9580, iid=1089, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=103959, iid=71429, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=122011, iid=2700, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=123759, iid=4483, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=39710, iid=2528, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=65760, iid=5477, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=57174, iid=163, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=66544, iid=6535, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=101917, iid=2245, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=102044, iid=663, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=155319, iid=1196, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=154484, iid=4794, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=9865, iid=187593, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=29981, iid=102407, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=152648, iid=5349, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=74517, iid=2297, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=151082, iid=3967, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=156979, iid=73017, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=130145, iid=7160, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=32562, iid=99114, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=22219, iid=110, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=26672, iid=48385, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=17271, iid=3159, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  Prediction(uid=12223, iid=89745, r_ui=None, est=3.5443807865604744, details={'was_impossible': False}),
#  ...]

# %% [markdown]
# We will store the list of predictions in a dataframe which will essentially in help in creating the familiar format of the dataframe

# %%
# Converting our prediction into a familiar format-Dataframe
df_pred=pd.DataFrame(ratings_predictions)
df_pred
# Out:
#            uid     iid  r_ui       est                    details
# 0       102413      74  None  3.544381  {'was_impossible': False}
# 1       122968   52328  None  3.544381  {'was_impossible': False}
# 2        89372    1188  None  3.544381  {'was_impossible': False}
# 3         1812    6874  None  3.544381  {'was_impossible': False}
# 4         7355  112175  None  3.544381  {'was_impossible': False}
# ...        ...     ...   ...       ...                        ...
# 249996   30316     637  None  3.544381  {'was_impossible': False}
# 249997   82743    1270  None  3.544381  {'was_impossible': False}
# 249998  140187    1282  None  3.544381  {'was_impossible': False}
# 249999    5399    6373  None  3.544381  {'was_impossible': False}
# 250000   13849    2412  None  3.544381  {'was_impossible': False}
#
# [250001 rows x 5 columns]

# %%
# Renaming our predictions to original names
df_pred=df_pred.rename(columns={'uid':'userId', 'iid':'movieId','est':'rating'})
df_pred.drop(['r_ui','details'],axis=1,inplace=True)

# %%
# Snippet of our ratings
df_pred.head()
# Out:
#    userId  movieId    rating
# 0  102413       74  3.544381
# 1  122968    52328  3.544381
# 2   89372     1188  3.544381
# 3    1812     6874  3.544381
# 4    7355   112175  3.544381

# %%
# Concatenating userId/movieId into a single Id column.(code has to be run twice to get desired outcome)
df_pred['Id']=df_pred.apply(lambda x:'%s_%s' % (x['userId'],x['movieId']),axis=1)
df_pred['Id']=df_pred.apply(lambda x:'%s_%s' % (x['userId'],x['movieId']),axis=1)

# %%
# drop the two features from the dataset userId and movieId
df_pred.drop(['userId', 'movieId'], inplace=True, axis= 1)

# %% [markdown]
# ## **Preparing Submission**
#
# The submission of this competition has to be in csv file entailing a id and rating column

# %%
# df_pred = df_pred[['Id', 'rating']]
# df_pred.shape

# %%
# df_pred.to_csv("coClustering_model_base.csv", index=False)

# %% [markdown]
# # IMPORTANT NOTE

# %% [markdown]
# In this notebook: This model is implemented on sample dataset, however, with the same procedure this model was implemented on a notebook on kaggle but because of memory issues this notebook was then moved here to GitHub. Another issues arises when implementing the notebook because of the huge dataset. This issue can be resolved in the three following steps.
# 1. Clone this repository.
# 2. Go to kaggle and download the dataset on: https://www.kaggle.com/c/edsa-recommender-system-predict/data
# 3. Replace the data on the folder titled 'data' with three dataset loaded in this notebook.
# 4. If you run this whole notebook you it will return a csv file title `coClustering_model_base.csv`.
# 5. Uploading that file on kaggle will give a score of
