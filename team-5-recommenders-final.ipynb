# %% [markdown]
# # **Introduction**
#
# “What movies should I check out tonight?”
#
# How many times have you had to answer this question when you came home from work? As for me — yes, I've to answer it for what felt like a million times. From Netflix, ShowMax, to HBO the need to build robust movie recommendation systems is becoming extremely important given the huge demand for personalized content of modern consumers.
#
# An example of a recommendation system is such as this:
#
# User X watches Rick and Morty and Dragon Ball Z.
# User Y does search on Rick and Morty, then the system suggests Dragon Ball Y  from data collected about user X.
# Recommendation systems are used not only for movies but on multiple other products and services like Amazon (Books, Items), Pandora/Spotify (Music), Google (News, Search), YouTube (Videos) etc.
#
# Recommender systems help users select similar items when something is being chosen online. There are several companies that actually use these systems, as such the biggest companies such Netflix or Amazon would suggest to the users movies that might interest. Other companies such as Yelp use recommender systems to suggest different resturants and services. The main point to use these systems is to reach out to users by provider best customer services and improve customer satisfaction.

# %% [markdown]
# ![](https://i.pinimg.com/originals/d9/58/5e/d9585efc140b5d3689b3341aa5c35df1.jpg)

# %% [markdown]
# The current recommendation systems that are bring used and are popular are the content-based filtering and collaborative filtering which works by implementing different information sources to make the recommendations.
#
# - **Content-based filtering (CBF)** : makes recommendations based on user preferences for product features.
# - **Collaborative filtering (CF)**:  mimics user-to-user recommendations (i.e. it relies on how other users have responded to the same items). It predicts users preferences as a linear, weighted combination of other user preferences.
#
# We have to note that both of these methods have **limitations**: The CBF can recommend a new item but needs more data on user preferences to give out the best match. On the other hand, the CF requires large dataset with active users who rated the product before to make the most accurate predictions. The combination of both of these methods is known as hybrid recommendation systems.

# %% [markdown]
# # **Problem Statement**
#
# Construct a recommendation algorithm based on content or collaborative filtering, capable of accurately predicting how a user will rate a movie they have not yet viewed based on their historical preferences.

# %% [markdown]
# # **Comet Experiment**

# %% [markdown]
# For effective experimentation and version controll we used Comet. Comet, built specifically for Machine Learning, allows us to track changes to our models as we develop, train, and test them. It provides a convenient graphical interface to moniter model performance while tweaking the model, along with the ability to reproduce any logged experiment. Below is a guide on how to use Comet.

# %%
# Remove the # to install comet
#pip install comet_ml

# %%
"""
# import comet_ml at the top of your file
from comet_ml import Experiment

# Create an experiment with your api key:
experiment = Experiment(
    api_key="ZBRB8H2ncCGZsUoS6CqVIAr0y",
    project_name="general",
    workspace="knetshiongolwe",
)
"""

# %% [markdown]
# # **Table of contents:**
# - [Import libraries and datasets](#section-one)
# - [Loading data](#section-two)
# - [Evaluating Data](#section-three)
# - [Data preprocessing](#section-four)
#   * [Checking for missing values column wise](#subsection-one)
#   * [Checking for duplicates records](#subsection-two)
#   * [Create copy](#subsection-three)
#   * [Evaluating Length of Unique Values](#subsection-four)
#   * [Evaluating unique values for movies](#subsection-four)
#   * [Joining Datasets](#subsection-four)
# - [Exploratory data analysis](#section-four)
# - [Collaborative and Content base filtering](#section-five)
# - [content Based Filtering](#section-five)
# - [Collaborative Based Filtering](#section-six)
#   * [Item-Item based](#subsection-one)
#   * [User-User](#subsection-two)
#   * [Singular value decomposition](#subsection-three)
# - [Model Building](#section-seven)
# - [Attempt prediction with altering parameters](#section-eight)
# - [Submission](#section-nine)
# - [Links to the Notebooks](Section-)
# - [Links to Github and Trello](Section)
# - [Conclusion](#section-ten)
# - [Collaborators](Section-)
# - [Acknowledgements](#section-eleven)
# - [References](#section-twelve)
# - [Comet](#section-thirteen)

# %% [markdown]
# ![](https://i.pinimg.com/originals/be/b9/1c/beb91c4fb913bbb224d5e90c5d497016.gif)
#
# ***Let’s get you the best movie!***

# %% [markdown]
# <a id="section-one"></a>
#
# # **Import libraries and datasets**
#
# We will be working with the famous Surprise(Simple Python RecommendatIon System Engine.) Library, Surprise is a Python scikit for building and analyzing recommender systems that deal with explicit rating data.
#
# Below are all libraries that are used through out this notebook.

# %%
# data analysis libraries
import pandas as pd
import numpy as np

# Kaggle requirements
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
        

# visualisation libraries
from matplotlib import pyplot as plt
import seaborn as sns
from numpy.random import RandomState


#word cloud
# %matplotlib inline
import wordcloud

from wordcloud import WordCloud, STOPWORDS
# %matplotlib inline
sns.set()

# visualisation libraries
from matplotlib import pyplot as plt
import seaborn as sns
from plotly.offline import init_notebook_mode, plot, iplot
import plotly.graph_objs as go
init_notebook_mode(connected=True)


# ML Models
from surprise import Reader
from surprise import Dataset
from surprise.model_selection import cross_validate
from surprise import NormalPredictor
from surprise import KNNBasic
from surprise import KNNWithMeans
from surprise import KNNWithZScore
from surprise import KNNBaseline
from surprise import SVD
from surprise import BaselineOnly
from surprise import SVDpp
from surprise import NMF
from surprise import SlopeOne
from surprise import CoClustering
from surprise.accuracy import rmse
from surprise import accuracy
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# ML Pre processing
from surprise.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Hyperparameter tuning
from surprise.model_selection import GridSearchCV

# High performance hyperparameter tuning
#from tune_sklearn import TuneSearchCV
#import warnings
#warnings.filterwarnings("ignore")
# Out:
# /kaggle/input/edsa-recommender-system-predict/sample_submission.csv
# /kaggle/input/edsa-recommender-system-predict/movies.csv
# /kaggle/input/edsa-recommender-system-predict/imdb_data.csv
# /kaggle/input/edsa-recommender-system-predict/genome_tags.csv
# /kaggle/input/edsa-recommender-system-predict/genome_scores.csv
# /kaggle/input/edsa-recommender-system-predict/train.csv
# /kaggle/input/edsa-recommender-system-predict/test.csv
# /kaggle/input/edsa-recommender-system-predict/tags.csv
# /kaggle/input/edsa-recommender-system-predict/links.csv
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # **Loading data**
# <a id="section-two"></a>
#
# We will load all the dataframes that we desire to work with

# %%
#Pandas libraries used in the notebook.
train = pd.read_csv('/kaggle/input/edsa-recommender-system-predict/train.csv')
test_df = pd.read_csv('/kaggle/input/edsa-recommender-system-predict/test.csv')
df_movies = pd.read_csv('/kaggle/input/edsa-recommender-system-predict/movies.csv')
df_samp = pd.read_csv('/kaggle/input/edsa-recommender-system-predict/sample_submission.csv')
df_imdb = pd.read_csv('/kaggle/input/edsa-recommender-system-predict/imdb_data.csv')
df_gtags = pd.read_csv("/kaggle/input/edsa-recommender-system-predict/genome_tags.csv")
df_scores = pd.read_csv("/kaggle/input/edsa-recommender-system-predict/genome_scores.csv")
df_tags = pd.read_csv("/kaggle/input/edsa-recommender-system-predict/tags.csv")
df_links = pd.read_csv("/kaggle/input/edsa-recommender-system-predict/links.csv")

# %% [markdown]
# <a id="section-three"></a>
# # **Evaluating Data**
#
# Here is the data that we are was given to us.
# Supplied Files
# * genome_scores.csv - a score mapping the strength between movies and tag-related properties. Read more here
# * genome_tags.csv - user assigned tags for genome-related scores
# * imdb_data.csv - Additional movie metadata scraped from IMDB using the links.csv file.
# * links.csv - File providing a mapping between a MovieLens ID and associated IMDB and TMDB IDs.
# * sample_submission.csv - Sample of the submission format for the hackathon.
# * tags.csv - User assigned for the movies within the dataset.
# * test.csv - The test split of the dataset. Contains user and movie IDs with no rating data.
# * train.csv - The training split of the dataset. Contains user and movie IDs with associated rating data.
#
# *Description of the data that is given to us *

# %%
#viewing training data
train.head()
# Out:
#    userId  movieId  rating   timestamp
# 0    5163    57669     4.0  1518349992
# 1  106343        5     4.5  1206238739
# 2  146790     5459     5.0  1076215539
# 3  106362    32296     2.0  1423042565
# 4    9041      366     3.0   833375837

# %% [markdown]
# Train:
#
# * UserId
# * movieId : Identifier for movies used
# * rating : Ratings are made on a 5-star scale, with half-star increments (0.5 stars - 5.0 stars).
# * timestamp: represent seconds since midnight Coordinated Universal Time (UTC) of January 1, 1970.

# %%
#Viewing movies data
df_movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %% [markdown]
# Movies:
#
# * movieId : Identifier for movies used
#
# * title : These were entered manually or imported from https://www.themoviedb.org/, and include the year of release in parentheses. Errors and inconsistencies may exist in these titles.
#
# * genres: Genres are a pipe-separated list, and are selected from the following:
#
#     * Action
#     * Adventure
#     * Animation
#     * Children's
#     * Comedy
#     * Crime
#     * Documentary
#     * Drama
#     * Fantasy
#     * Film-Noir
#     * Horror
#     * Musical
#     * Mystery
#     * Romance
#     * Sci-Fi
#     * Thriller
#     * War
#     * Western
#     * (no genres listed)

# %%
#Viewing imdb dataframe

df_imdb.head(1)
# Out:
#    movieId                                         title_cast       director  \
# 0        1  Tom Hanks|Tim Allen|Don Rickles|Jim Varney|Wal...  John Lasseter
#
#    runtime       budget                     plot_keywords
# 0     81.0  $30,000,000  toy|rivalry|cowboy|cgi animation

# %%
#Viewing Genrome tags
df_gtags.head(1)
# Out:
#    tagId  tag
# 0      1  007

# %% [markdown]
# genome-tags:
#
# * tagId
# * tag : tag descriptions for the tag IDs in the genome file

# %%
#Viewing scores
df_scores.head()
# Out:
#    movieId  tagId  relevance
# 0        1      1    0.02875
# 1        1      2    0.02375
# 2        1      3    0.06250
# 3        1      4    0.07575
# 4        1      5    0.14075

# %% [markdown]
# genome-scores:
#
# * movieId : Identifier for movies
# * tagId :
# * relevance

# %%
#viewing tags
df_tags.head()
# Out:
#    userId  movieId               tag   timestamp
# 0       3      260           classic  1439472355
# 1       3      260            sci-fi  1439472256
# 2       4     1732       dark comedy  1573943598
# 3       4     1732    great dialogue  1573943604
# 4       4     7569  so bad it's good  1573943455

# %% [markdown]
# tags:
#
# * userId
# * movieId
# * tag : User-generated metadata about movies. Each tag is typically a single word or short phrase. The meaning, value, and * purpose of a particular tag is determined by each user.
# * timestamp : represent seconds since midnight Coordinated Universal Time (UTC) of January 1, 1970

# %%
#view links
df_links.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %% [markdown]
# Links:
#
# * movieId : Identifier for movies used by https://movielens.org
# * imdbId : Identifier for movies used by http://www.imdb.com
# * tmdbId : An identifier for movies used by https://www.themoviedb.org.

# %% [markdown]
# <a id="section-four"></a>
# # **Data Preprocessing**
# **Preparing raw data:**
#
# We will first prepare this raw data to make it suitable for our machine learning model. This is a very crucial step while for creating a machine learning model.

# %% [markdown]
# <a id="subsection-one"></a>
# # **Checking for missing values column wise**
#
# **Handling Missing Data:**
#
# In our dataset, there may be some missing values. We cannot train our model with a dataset that contains missing values. So we have to check if our dataset has missing values.

# %%
#check for missing values
train.isnull().sum()
# Out:
# userId       0
# movieId      0
# rating       0
# timestamp    0
# dtype: int64

# %% [markdown]
# <a id="subsection-two"></a>
# # **Checking for duplicates records**
# **Checking Duplicate Values:**
#
# At times our dataset may entail some duplicated values which are not necessary therefore this values must be removed, befor removing these duplicates we are able to first check if we do have them. We will implement this by the code below.

# %%
# check duplicates
dup_bool = train.duplicated(['userId', 'movieId', 'rating'])

# display duplicates
print("Number of duplicate records:", sum(dup_bool))
# Out:
# Number of duplicate records: 0

# %% [markdown]
# <a id="subsection-three"></a>
# # **Creating a copy**
#
# We will rename our train data as df and look at the top 5 records in the dataframe.

# %%
# Create a copy
df = train.copy()

# %%
# Create a copy of the train data
df_train = train.copy()

# Display top 5 records
df_train.head()
# Out:
#    userId  movieId  rating   timestamp
# 0    5163    57669     4.0  1518349992
# 1  106343        5     4.5  1206238739
# 2  146790     5459     5.0  1076215539
# 3  106362    32296     2.0  1423042565
# 4    9041      366     3.0   833375837

# %% [markdown]
# ## **Evaluating Length of Unique Values**

# %%
# Find the length of the unique use
len(df_train['userId'].unique()), len(df_train['movieId'].unique())
# Out:
# (162541, 48213)

# %%
# View movies
df_movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %% [markdown]
# # Evaluating unique values for movies

# %%
# View unique values of movies
len(df_movies['movieId'].unique())
# Out:
# 62423

# %% [markdown]
# ## **Joining Datasets**

# %%
# Merge the ratings and movies
df_merge1 = df_train.merge(df_movies, on='movieId')
# View the first 5 rows
df_merge1.head()
# Out:
#    userId  movieId  rating   timestamp             title  \
# 0    5163    57669     4.0  1518349992  In Bruges (2008)
# 1   87388    57669     3.5  1237455297  In Bruges (2008)
# 2  137050    57669     4.0  1425631854  In Bruges (2008)
# 3  120490    57669     4.5  1408228517  In Bruges (2008)
# 4   50616    57669     4.5  1446941640  In Bruges (2008)
#
#                         genres
# 0  Comedy|Crime|Drama|Thriller
# 1  Comedy|Crime|Drama|Thriller
# 2  Comedy|Crime|Drama|Thriller
# 3  Comedy|Crime|Drama|Thriller
# 4  Comedy|Crime|Drama|Thriller

# %%
# Merging the dataset with that of the imbd
df_merge2 = df_train.merge(df_imdb, on="movieId")
# View first 5 rows
df_merge2.head()
# Out:
#    userId  movieId  rating   timestamp  \
# 0    5163    57669     4.0  1518349992
# 1   87388    57669     3.5  1237455297
# 2  137050    57669     4.0  1425631854
# 3  120490    57669     4.5  1408228517
# 4   50616    57669     4.5  1446941640
#
#                                           title_cast         director  \
# 0  Elizabeth Berrington|Rudy Blomme|Olivier Bonjo...  Martin McDonagh
# 1  Elizabeth Berrington|Rudy Blomme|Olivier Bonjo...  Martin McDonagh
# 2  Elizabeth Berrington|Rudy Blomme|Olivier Bonjo...  Martin McDonagh
# 3  Elizabeth Berrington|Rudy Blomme|Olivier Bonjo...  Martin McDonagh
# 4  Elizabeth Berrington|Rudy Blomme|Olivier Bonjo...  Martin McDonagh
#
#    runtime       budget              plot_keywords
# 0    107.0  $15,000,000  dwarf|bruges|irish|hitman
# 1    107.0  $15,000,000  dwarf|bruges|irish|hitman
# 2    107.0  $15,000,000  dwarf|bruges|irish|hitman
# 3    107.0  $15,000,000  dwarf|bruges|irish|hitman
# 4    107.0  $15,000,000  dwarf|bruges|irish|hitman

# %%
# Merging the merge data earlier on with the df_imbd
df_merge3 = df_merge1.merge(df_imdb, on="movieId" )
# View first 5 rows
df_merge3.head()
# Out:
#    userId  movieId  rating   timestamp             title  \
# 0    5163    57669     4.0  1518349992  In Bruges (2008)
# 1   87388    57669     3.5  1237455297  In Bruges (2008)
# 2  137050    57669     4.0  1425631854  In Bruges (2008)
# 3  120490    57669     4.5  1408228517  In Bruges (2008)
# 4   50616    57669     4.5  1446941640  In Bruges (2008)
#
#                         genres  \
# 0  Comedy|Crime|Drama|Thriller
# 1  Comedy|Crime|Drama|Thriller
# 2  Comedy|Crime|Drama|Thriller
# 3  Comedy|Crime|Drama|Thriller
# 4  Comedy|Crime|Drama|Thriller
#
#                                           title_cast         director  \
# 0  Elizabeth Berrington|Rudy Blomme|Olivier Bonjo...  Martin McDonagh
# 1  Elizabeth Berrington|Rudy Blomme|Olivier Bonjo...  Martin McDonagh
# 2  Elizabeth Berrington|Rudy Blomme|Olivier Bonjo...  Martin McDonagh
# 3  Elizabeth Berrington|Rudy Blomme|Olivier Bonjo...  Martin McDonagh
# 4  Elizabeth Berrington|Rudy Blomme|Olivier Bonjo...  Martin McDonagh
#
#    runtime       budget              plot_keywords
# 0    107.0  $15,000,000  dwarf|bruges|irish|hitman
# 1    107.0  $15,000,000  dwarf|bruges|irish|hitman
# 2    107.0  $15,000,000  dwarf|bruges|irish|hitman
# 3    107.0  $15,000,000  dwarf|bruges|irish|hitman
# 4    107.0  $15,000,000  dwarf|bruges|irish|hitman

# %%
# Check the null values of the data that has just been merged.
df_merge3.isnull().sum()
# Out:
# userId                 0
# movieId                0
# rating                 0
# timestamp              0
# title                  0
# genres                 0
# title_cast       2604407
# director         2602688
# runtime          2653058
# budget           3152276
# plot_keywords    2610043
# dtype: int64

# %%
# View keywords
df_merge3['plot_keywords'].tail(100)
# Out:
# 9632931                                                NaN
# 9632932    sex|male frontal nudity|prostitution|perversity
# 9632933                                     color in title
# 9632934                                                NaN
# 9632935         murder|serial killer|peeping|female nudity
#                                 ...
# 9633026                                                NaN
# 9633027      janitor|income|housing problem|social problem
# 9633028                                                NaN
# 9633029                     soldier|italy|partisan|fascist
# 9633030             genius|artist|greek american|direction
# Name: plot_keywords, Length: 100, dtype: object

# %%
# Extract unique values from rating column
train['rating'].unique()
# Out:
# array([4. , 4.5, 5. , 2. , 3. , 1. , 3.5, 2.5, 0.5, 1.5])

# %% [markdown]
# ## **Merging More Datasets**

# %% [markdown]
# The following code was going to provide us with a merge of a dataset of the tahes that are available. However, we get an error indicating that this is quite huge and we will have to either minimize the dataset or try to find another alternative.

# %%
# Merging the dataset with that of the imbd
df_merge2 = df_train.merge(df_imdb, on="movieId")
df_merge2.head(1)
# Out:
#    userId  movieId  rating   timestamp  \
# 0    5163    57669     4.0  1518349992
#
#                                           title_cast         director  \
# 0  Elizabeth Berrington|Rudy Blomme|Olivier Bonjo...  Martin McDonagh
#
#    runtime       budget              plot_keywords
# 0    107.0  $15,000,000  dwarf|bruges|irish|hitman

# %%
# Merging the merge data earlier on with the df_imbd
df_merge3 = df_merge1.merge(df_imdb, on="movieId" )
df_merge3.head()
# Out:
#    userId  movieId  rating   timestamp             title  \
# 0    5163    57669     4.0  1518349992  In Bruges (2008)
# 1   87388    57669     3.5  1237455297  In Bruges (2008)
# 2  137050    57669     4.0  1425631854  In Bruges (2008)
# 3  120490    57669     4.5  1408228517  In Bruges (2008)
# 4   50616    57669     4.5  1446941640  In Bruges (2008)
#
#                         genres  \
# 0  Comedy|Crime|Drama|Thriller
# 1  Comedy|Crime|Drama|Thriller
# 2  Comedy|Crime|Drama|Thriller
# 3  Comedy|Crime|Drama|Thriller
# 4  Comedy|Crime|Drama|Thriller
#
#                                           title_cast         director  \
# 0  Elizabeth Berrington|Rudy Blomme|Olivier Bonjo...  Martin McDonagh
# 1  Elizabeth Berrington|Rudy Blomme|Olivier Bonjo...  Martin McDonagh
# 2  Elizabeth Berrington|Rudy Blomme|Olivier Bonjo...  Martin McDonagh
# 3  Elizabeth Berrington|Rudy Blomme|Olivier Bonjo...  Martin McDonagh
# 4  Elizabeth Berrington|Rudy Blomme|Olivier Bonjo...  Martin McDonagh
#
#    runtime       budget              plot_keywords
# 0    107.0  $15,000,000  dwarf|bruges|irish|hitman
# 1    107.0  $15,000,000  dwarf|bruges|irish|hitman
# 2    107.0  $15,000,000  dwarf|bruges|irish|hitman
# 3    107.0  $15,000,000  dwarf|bruges|irish|hitman
# 4    107.0  $15,000,000  dwarf|bruges|irish|hitman

# %% [markdown]
# <a id="section-four"></a>
# # **Exploratory data analysis(EDA)**
# ![](https://aryng.com/assets/img/ani3.gif)
#
# **Lets make visuals Data Scientists!!**

# %% [markdown]
# # **Visualising Ratings**

# %% [markdown]
# # **Ratings Distribution**

# %%
# Get summary statistics of rating
train['rating'].describe()
# Out:
# count    1.000004e+07
# mean     3.533395e+00
# std      1.061124e+00
# min      5.000000e-01
# 25%      3.000000e+00
# 50%      3.500000e+00
# 75%      4.000000e+00
# max      5.000000e+00
# Name: rating, dtype: float64

# %% [markdown]
# ## **Ratings Distribution**

# %%
data = df_merge1['rating'].value_counts().sort_index(ascending=False)

# Create trace
trace = go.Bar(x=data.index,
               text=['{:.1f} %'.format(val) for val in (data.values / df_merge1.shape[0] * 100)],
               textposition='auto',
               textfont=dict(color='#000000'),
               y=data.values,
               marker=dict(color='#db0000'))
# Create layout
layout = dict(title='Distribution Of {} movie-ratings'.format(df_merge1.shape[0]),
              xaxis=dict(title='rating'),
              yaxis=dict(title='Count'))
# Create plot
fig = go.Figure(data=[trace], layout=layout)
iplot(fig)
# Out:
# <div>                            <div id="3852c8d7-f56c-464b-a667-10e06598d3a6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3852c8d7-f56c-464b-a667-10e06598d3a6")) {                    Plotly.newPlot(                        "3852c8d7-f56c-464b-a667-10e06598d3a6",                        [{"marker": {"color": "#db0000"}, "text": ["14.5 %", "8.8 %", "26.5 %", "12.7 %", "19.6 %", "5.1 %", "6.6 %", "1.6 %", "3.1 %", "1.6 %"], "textfont": {"color": "#000000"}, "textposition": "auto", "type": "bar", "x": [5.0, 4.5, 4.0, 3.5, 3.0, 2.5, 2.0, 1.5, 1.0, 0.5], "y": [1445230, 880516, 2652977, 1270642, 1959759, 505578, 656821, 159731, 311213, 157571]}],                        {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter" ...

# %% [markdown]
# **Observations:**
# * We can observe that a high percentage of our movies were rated above average i.e above 3
# * A low percentage were below 3
#
# **Recommendations:**
# * Hence More movies are high quality perhaps people are watching movies that are recommended to them, either by their social groups or the recommender system itself.

# %%
df_merge3.rename(columns={'rating_x': 'rating', 'rating_y': 'numRatings'}, inplace=True)
#Create dataframe
num_ratings = pd.DataFrame(df_merge3.groupby('movieId').count()['rating']).reset_index()
#merge num ratings with df_merge3
df_merge3 = pd.merge(left=df_merge3, right=num_ratings, on='movieId')
# rename columns
df_merge3.rename(columns={'rating_x': 'rating', 'rating_y': 'numRatings'}, inplace=True)

# %%
# pre_process the budget column

# remove commas
df_merge3['budget'] = df_merge3['budget'].str.replace(',', '')

# remove currency signs like "$" and "GBP"
df_merge3['budget'] = df_merge3['budget'].str.extract('(\d+)', expand=False)

# convert the feature into a float
df_merge3['budget'] = df_merge3['budget'].astype(float)

# remove nan values and replacing with 0
df_merge3['budget'] = df_merge3['budget'].replace(np.nan, 0)

# convert the feature into an integer
df_merge3['budget'] = df_merge3['budget'].astype(int)

# %%
#extracting date from title column
df_merge3['release_year'] = df_merge3.title.str.extract('(\(\d\d\d\d\))', expand=False)

#adding date to realse year column
df_merge3['release_year'] = df_merge3.release_year.str.extract('(\d\d\d\d)', expand=False)

#view top 2 rows of the dataframe
df_merge3.head(2)
# Out:
#    userId  movieId  rating   timestamp             title  \
# 0    5163    57669     4.0  1518349992  In Bruges (2008)
# 1   87388    57669     3.5  1237455297  In Bruges (2008)
#
#                         genres  \
# 0  Comedy|Crime|Drama|Thriller
# 1  Comedy|Crime|Drama|Thriller
#
#                                           title_cast         director  \
# 0  Elizabeth Berrington|Rudy Blomme|Olivier Bonjo...  Martin McDonagh
# 1  Elizabeth Berrington|Rudy Blomme|Olivier Bonjo...  Martin McDonagh
#
#    runtime    budget              plot_keywords  numRatings release_year
# 0    107.0  15000000  dwarf|bruges|irish|hitman        4253         2008
# 1    107.0  15000000  dwarf|bruges|irish|hitman        4253         2008

# %%
#drop duplicates on dataframe
data_1= df_merge3.drop_duplicates('movieId')

#view top 2 rows of the dataframe
data_1.head(2)
# Out:
#       userId  movieId  rating   timestamp                               title  \
# 0       5163    57669     4.0  1518349992                    In Bruges (2008)
# 4253  106343        5     4.5  1206238739  Father of the Bride Part II (1995)
#
#                            genres  \
# 0     Comedy|Crime|Drama|Thriller
# 4253                       Comedy
#
#                                              title_cast         director  \
# 0     Elizabeth Berrington|Rudy Blomme|Olivier Bonjo...  Martin McDonagh
# 4253  Steve Martin|Diane Keaton|Martin Short|Kimberl...   Albert Hackett
#
#       runtime    budget                    plot_keywords  numRatings  \
# 0       107.0  15000000        dwarf|bruges|irish|hitman        4253
# 4253    106.0  30000000  fatherhood|doberman|dog|mansion        4648
#
#      release_year
# 0            2008
# 4253         1995

# %%
#create ratings dataframe
ratings_df = pd.DataFrame()

#extract average ratings
ratings_df['Mean_Rating'] = df_merge3.groupby('title')['rating'].mean().values

#extract average number of ratings
ratings_df['Num_Ratings'] = df_merge3.groupby('title')['rating'].count().values

#make a plot
fig, ax = plt.subplots(figsize=(14, 7))
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.set_title('Rating vs. Number of Ratings', fontsize=24, pad=20)
ax.set_xlabel('Rating', fontsize=16, labelpad=20)
ax.set_ylabel('Number of Ratings', fontsize=16, labelpad=20)

plt.scatter(ratings_df['Mean_Rating'], ratings_df['Num_Ratings'], alpha=0.5, color='green')

# %% [markdown]
# * The more a movie gets more ratings it’s average ratings tends to increase. This also means that, If more and more people are watching a particular movie, it probably has a good budget and good marketing, and they are highly rated.

# %% [markdown]
# # **Visualising Genres**
#
# The genres variable will surely be important while building the recommendation engines since it describes the content of the film (i.e. Animation, Horror, Sci-Fi). A basic assumption is that films in the same genre should have similar contents. I'll attempt to see exactly which genres are the most popular.

# %%
movies = df_movies.copy()

# %%
# Make a census of the genre keywords
genre_labels = set()
for s in movies['genres'].str.split('|').values:
    genre_labels = genre_labels.union(set(s))

# Function that counts the number of times each of the genre keywords appear
def count_word(dataset, ref_col, census):
    """  
    
    This function counts the number of times each 
    of the genre keywords appear  
    
    Input : movies dataframe, column from dataframe,
    label column from dataframe
    datatype : dataframe        
    
    output : list    
    
    """
    keyword_count = dict()
    for s in census: 
        keyword_count[s] = 0
    for census_keywords in dataset[ref_col].str.split('|'):        
        if type(census_keywords) == float and pd.isnull(census_keywords): 
            continue        
        for s in [s for s in census_keywords if s in census]: 
            if pd.notnull(s): 
                keyword_count[s] += 1
    
    # convert the dictionary in a list to sort the keywords by frequency
    keyword_occurences = []
    for k,v in keyword_count.items():
        keyword_occurences.append([k,v])
    keyword_occurences.sort(key = lambda x:x[1], reverse = True)
    return keyword_occurences, keyword_count

# Calling this function gives access to a list of genre keywords which are sorted by decreasing frequency
keyword_occurences, dum = count_word(movies, 'genres', genre_labels)
keyword_occurences[:5]
# Out:
# [['Drama', 25606],
#  ['Comedy', 16870],
#  ['Thriller', 8654],
#  ['Romance', 7719],
#  ['Action', 7348]]

# %% [markdown]
# * The top 5 genres are, in that respect order: Drama, Comedy,Thriller, Romance and Action,.We will show this on a wordcloud too in order to make it more visually appealing.

# %%
# Import new libraries
# %matplotlib inline
import wordcloud
from wordcloud import WordCloud, STOPWORDS
# Define the dictionary used to produce the genre wordcloud
genres = dict()
trunc_occurences = keyword_occurences[0:18]
for s in trunc_occurences:
    genres[s[0]] = s[1]

# Create the wordcloud
genre_wordcloud = WordCloud(width=1000,height=400, background_color='black')
genre_wordcloud.generate_from_frequencies(genres)

# Plot the wordcloud
f, ax = plt.subplots(figsize=(16, 8))
plt.imshow(genre_wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %% [markdown]
# * The top 5 genres are, in that respect order: Drama, Comedy, Action, Thriller, and Romance.

# %%
df = df_imdb[['movieId','title_cast','director', 'plot_keywords']]
df = df.merge(df_movies[['movieId', 'genres', 'title']], on='movieId', how='inner')
df.head(1)
# Out:
#    movieId                                         title_cast       director  \
# 0        1  Tom Hanks|Tim Allen|Don Rickles|Jim Varney|Wal...  John Lasseter
#
#                       plot_keywords  \
# 0  toy|rivalry|cowboy|cgi animation
#
#                                         genres             title
# 0  Adventure|Animation|Children|Comedy|Fantasy  Toy Story (1995)

# %%
# Convert data types to strings for string handling
df['title_cast'] = df.title_cast.astype(str)
df['plot_keywords'] = df.plot_keywords.astype(str)
df['genres'] = df.genres.astype(str)
df['director'] = df.director.astype(str)

# Removing spaces between names
df['director'] = df['director'].apply(lambda x: "".join(x.lower() for x in x.split()))
df['title_cast'] = df['title_cast'].apply(lambda x: "".join(x.lower() for x in x.split()))

# Discarding the pipes between the actors' full names and getting only the first three names
df['title_cast'] = df['title_cast'].map(lambda x: x.split('|')[:3])

# Discarding the pipes between the plot keywords' and getting only the first five words
df['plot_keywords'] = df['plot_keywords'].map(lambda x: x.split('|')[:5])
df['plot_keywords'] = df['plot_keywords'].apply(lambda x: " ".join(x))

# Discarding the pipes between the genres 
df['genres'] = df['genres'].map(lambda x: x.lower().split('|'))
df['genres'] = df['genres'].apply(lambda x: " ".join(x))

df.head(1)
# Out:
#    movieId                        title_cast      director  \
# 0        1  [tomhanks, timallen, donrickles]  johnlasseter
#
#                       plot_keywords  \
# 0  toy rivalry cowboy cgi animation
#
#                                         genres             title
# 0  adventure animation children comedy fantasy  Toy Story (1995)

# %% [markdown]
# # **Genre Popularity**

# %%
def most_watched(input_df):
    
    """  
    
    This function gives out the number of ratings
    for each genre for each year since 1970  
    
    Input : dataframe
    datatype : dataframe        
    
    output : Figure (bar graph)
    
    """
    # Create a copy of the input dataframe and merge it to the movies dataframe
    df = input_df.copy()
    df = df.merge(df_movies,on='movieId',how='left')
    
    # Create an empty dataframe
    b = pd.DataFrame()
    
    # Extract the timestamps and genres 
    timestamps = [timestamp for timestamp in df.timestamp]
    all_genres = set(','.join([genres.replace('|',',') for genres in df.genres]).split(','))
    
    # Get the number of ratings for each genre for each year since 1970
    for index,genre in enumerate(all_genres):
        a = pd.Series([int((timestamps[i]/31536000)+1970) for i,x in enumerate(df.genres) if genre in x])
        a = a.value_counts()
        b = pd.concat([b,pd.DataFrame({genre:a})],axis=1)
        
    # Create trace
    trace = go.Bar(x = data.index,
    text = ['{:.1f} %'.format(val) for val in (data.values / df_merge1.shape[0] * 100)],
    textposition = 'auto',
    textfont = dict(color = '#000000'),
    y = data.values,
    marker = dict(color = '#db0000'))
    
    
    # Plot the trends for each genre on the same line graph 
    plt.figure(figsize=(40,20))
    plot = sns.barplot(data=b, ci=None)
      
    # Add plot labels
    plt.title('Trends in genre popularity',fontsize=20)
    plt.xlabel('Genres', fontsize=15)
    plt.ylabel('Number of ratings', fontsize=15)
    
    plt.show()
    
    return

most_watched(train)

# %% [markdown]
# * It is reasonable to expect that movies with a high number of ratings have also garnered a high number of views.
# * It is clear looking at the bar graph that Comedy, Drama and Action have the highest number of ratings and therefore views, it is therefore advisable to commission more of these genres of movie in order to increase viewership which in turn will increase revenue.

# %%
def most_watched(input_df): 
    
    """"
    This function gives out the number of ratings
    for each genre for each year since 1970  
    
    Input : dataframe
    datatype : dataframe        
    
    output : Figure (line graph)
    
    """
    
    # Create a copy of the input dataframe and merge it to the movies dataframe
    df = input_df.copy()
    df = df.merge(df_movies,on='movieId',how='left')
    
    # Create an empty dataframe
    b = pd.DataFrame()
    
    # Extract the timestamps and genres 
    timestamps = [timestamp for timestamp in df.timestamp]
    all_genres = set(','.join([genres.replace('|',',') for genres in df.genres]).split(','))
    
    # Get the number of ratings for each genre for each year since 1970
    for index,genre in enumerate(all_genres):
        a = pd.Series([int((timestamps[i]/31536000)+1970) for i,x in enumerate(df.genres) if genre in x])
        a = a.value_counts()
        b = pd.concat([b,pd.DataFrame({genre:a})],axis=1)
    
    # Plot the trends for each genre on the same line graph 
    plt.figure(figsize=(40,20))
    palette = sns.color_palette("mako_r", 20)
    sns.set()
    sns.set_palette("PuBuGn_d")
    plot = sns.lineplot(data=b, dashes=False, palette=palette)
      
    # Add plot labels
    plt.title('Trends in genre popularity',fontsize=20)
    plt.xlabel('Years', fontsize=15)
    plt.ylabel('Number of ratings', fontsize=15)
    
    plt.show()
    
    return

most_watched(train)

# %% [markdown]
# **Observations:**
# * It is reasonable to expect that movies with a high number of ratings have also garnered a high number of views.
# * Therefore the higher the number of ratings the greater the popularity.
#
# **Recommendations:**
#
# * Netflix should endeavor to match the order of genre of movies available in terms of quantity to the popularity of the genre so as to maximise the views, this in turn will maximise the return on investment in films.
# * For example Drama is currently the most popular genre in the dataset and if comedy were to take the number one spot we would suggest to Netflix to commission more comedy movies than drama.
# * This is especially important because networks/production companies are creating their own streaming servises which reduces the amount of content that they licenced out to Netflix and therefore they are producing in house content.

# %% [markdown]
# # **Visualising Movies**

# %%
# Create a wordcloud of the movie titles
movies['title'] = movies['title'].fillna("").astype('str')
title_corpus = ' '.join(movies['title'])
title_wordcloud = WordCloud(stopwords=STOPWORDS, background_color='white', height=2000, width=4000).generate(title_corpus)

# Plot the wordcloud
plt.figure(figsize=(16,8))
plt.imshow(title_wordcloud)
plt.axis('off')
plt.show()

# %% [markdown]
# **Observations:**
# * We can observe that Man, Girl and Love are larger then the rest, which informs us that they are the most popular title words.
# * II, III and three are relatively small which tells us that they are relatively less popular than other title words.
#
# **Recommendations:**
#
# * The deminutive nature of II, III and three tell us that there were not a lot of franchise films and this is a worry for netflix because we know that franchise films are created because they already have establish fanbases which if brought to netflix would add to the viewership and improve the revenue.
# * Love, La, Girl and Man were the most occuring title words this matches up with the popularity line graph as romance and drama are amongst the top films, if any changes are obseved in the relative popularity of the genre types then this should be reflected in title popularity.

# %% [markdown]
# # **Popular Movies by Genre**

# %%
genre_df = pd.DataFrame(df_merge3['genres'].str.split('|').tolist(), index=df_merge3['movieId']).stack()
genre_df = genre_df.reset_index([0, 'movieId'])
genre_df.columns = ['movieId', 'Genre']

# %%
def make_bar_chart(dataset, attribute, bar_color='#3498db', edge_color='#2980b9', title='Title', xlab='X', ylab='Y', sort_index=False):
    
    """"
    This function gives the count of the
    different genres
    
    Input : dataframe, dataframe column,
    colour of figure, title of figure,
    x and y labels
    datatype : dataframe        
    
    output : Figure (bar plot)
    
    """
    
    if sort_index == False:
        xs = dataset[attribute].value_counts().index
        ys = dataset[attribute].value_counts().values
    else:
        xs = dataset[attribute].value_counts().sort_index().index
        ys = dataset[attribute].value_counts().sort_index().values
    
    # Plotting the figure   
    fig, ax = plt.subplots(figsize=(14, 7))
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.set_title(title, fontsize=24, pad=20)
    ax.set_xlabel(xlab, fontsize=16, labelpad=20)
    ax.set_ylabel(ylab, fontsize=16, labelpad=20)
    # Plot the bar graph
    plt.bar(x=xs, height=ys, color=bar_color, edgecolor=edge_color, linewidth=2)
    plt.xticks(rotation=45)
    
# Show the bar chart with selected features    
make_bar_chart(genre_df, 'Genre', title='Most Popular Movie Genres', xlab='Genre', ylab='Counts')

# %% [markdown]
# **Observations:**
# * Drama, Comedy, Action, Thriller and adventure are the top 5 genre in the dataset.
#
# **Recommndations:**
# * Netflix should endeavor to match the order of genre of movies available in terms of quantity to the popularity of the genre so as to maximise the views, this in turn will maximise the revenue in films.

# %% [markdown]
# # **Movie Published per Year**

# %%
# Create an empty list
years = []
# Finding the number of movies published in each year
for title in df_merge3['title']:
    year_subset = title[-5:-1]
    try: years.append(int(year_subset))
    except: years.append(9999)
# Create a new column in a dataframe.       
df_merge3['moviePubYear'] = years
print('The Number of Movies Published each year:',len(df_merge3[df_merge3['moviePubYear'] == 9999]))
# Out:
# The Number of Movies Published each year: 713

# %%
def make_histogram(dataset, attribute, bins=25, bar_color='#3498db', edge_color='#2980b9', 
                   title='Title', xlab='X', ylab='Y', sort_index=False):
    """"
    This function gives a plot of the
    number of movies published per year
    
    Input : dataframe, dataframe column,
    bins, colour of figure, title of figure,
    x and y labels
    datatype : dataframe        
    
    output : Figure (bar plot)
    
    """
    if attribute == 'moviePubYear':
        dataset = dataset[dataset['moviePubYear'] != 9999]
        
    fig, ax = plt.subplots(figsize=(14, 7))
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.set_title(title, fontsize=24, pad=20)
    ax.set_xlabel(xlab, fontsize=16, labelpad=20)
    ax.set_ylabel(ylab, fontsize=16, labelpad=20)
    
    plt.hist(dataset[attribute], bins=bins, color=bar_color, ec=edge_color, linewidth=2)
    
    plt.xticks(rotation=45)
    
    
make_histogram(df_merge3, 'moviePubYear', title='Movies Published per Year', xlab='Year', ylab='Counts')

# %% [markdown]
# **Observations:**
# * We observed a decrease in the movies published per year from 2000
#
# **Reccomendations:**
# * It is not clear what accounts for the decrease in movies published but possible reasons for this change include finacial crisis in 2000 and in 2009.

# %%
df_merge3.head(2)
# Out:
#    userId  movieId  rating   timestamp             title  \
# 0    5163    57669     4.0  1518349992  In Bruges (2008)
# 1   87388    57669     3.5  1237455297  In Bruges (2008)
#
#                         genres  \
# 0  Comedy|Crime|Drama|Thriller
# 1  Comedy|Crime|Drama|Thriller
#
#                                           title_cast         director  \
# 0  Elizabeth Berrington|Rudy Blomme|Olivier Bonjo...  Martin McDonagh
# 1  Elizabeth Berrington|Rudy Blomme|Olivier Bonjo...  Martin McDonagh
#
#    runtime    budget              plot_keywords  numRatings release_year  \
# 0    107.0  15000000  dwarf|bruges|irish|hitman        4253         2008
# 1    107.0  15000000  dwarf|bruges|irish|hitman        4253         2008
#
#    moviePubYear
# 0          2008
# 1          2008

# %%
# Create a dataframe with the number of movies that the directors have made
director_m = pd.DataFrame(data_1.groupby('director').count()['title'].sort_values(ascending=False)).reset_index()
# View the first five directors
director_m.head()
# Out:
#               director  title
# 0           Luc Besson     26
# 1     See full summary     25
# 2          Woody Allen     25
# 3         Stephen King     23
# 4  William Shakespeare     18

# %%
# the least and most number of movies by directors in the dataset.

print(f'No of unique movies: \t{len(data_1)}\nLeast produced: \t{director_m.title.min()}\nMost produced: \t\t{director_m.title.max()}')
# Out:
# No of unique movies: 	23544
# Least produced: 	1
# Most produced: 		26

# %%
# View the director and the count of ratings
pd.DataFrame(data_1.groupby('director').sum()['numRatings'].sort_values(ascending=False)).reset_index()
# Out:
#                  director  numRatings
# 0       Quentin Tarantino      109919
# 1        Michael Crichton       65157
# 2          J.R.R. Tolkien       62963
# 3         Lilly Wachowski       60988
# 4            Stephen King       59903
# ...                   ...         ...
# 9990      Kirsten Johnson           1
# 9991           Kobi Shely           1
# 9992      Aris Bafaloukas           1
# 9993  Kristinn Thordarson           1
# 9994              50 Cent           1
#
# [9995 rows x 2 columns]

# %% [markdown]
# # **Number of ratings per director**

# %%
#df_merge3.sort_values(by='numRatings', ascending=False).drop_duplicates('movieId')[:100]
director_n = pd.DataFrame(data_1.groupby('director').sum()['numRatings'].sort_values(ascending=False)).reset_index()

# visualize the number of movies per director
plt.figure(figsize = (14, 9.5))
sns.barplot(data = director_n.head(50), y = 'director', x = 'numRatings', color = 'teal')
plt.ylabel('Directors')
plt.xlabel('Number of ratings')
plt.title('Number of ratings per director\n')
#plt.xlim(0, 27)
plt.show()

# %% [markdown]
# # **Number of moviesper director**

# %%
# visualize the number of movies per director
plt.figure(figsize = (14, 9.5))
sns.barplot(data = director_m.head(50), y = 'director', x = 'title', color = 'teal')
plt.ylabel('Directors')
plt.xlabel('Number of movies released')
plt.title('Number of Movies released per director\n')
plt.xlim(0, 27)
plt.show()

# %% [markdown]
# **Observations:**
# * The bar chart reflects the number of movies per director. The chart is layed out such that the directors with the most movies produced are reflected first in descending order of the number of movies per director.
# * Luc Besson is the most prolific director out of all directors in the dataset.

# %%
# Create a list from the dataframe of the movie count of directors
top_100_produced = list(director_m.director.head(100))

top_produced = data_1[data_1['director'].isin(top_100_produced)]

# %%
# find the mean rating for the movies
avg_per_director = df_merge3[['rating','movieId']].groupby('movieId').mean().reset_index()

# %%
# update the ratings of the movies with the average rating
top_produced = pd.merge(top_produced.drop('rating',1),avg_per_director,on='movieId').sort_values('rating',ascending=False)

# %%
print(f'Min_rating: \t{top_produced.rating.min()}\nMax_rating: \t{top_produced.rating.max()}\nMean_rating: \t{round(top_produced.rating.mean(),2)}')
# Out:
# Min_rating: 	0.5
# Max_rating: 	4.5
# Mean_rating: 	3.26

# %%
#print the row related to this index.
def find_minmax(x):
    #use the function 'idmin' to find the index of lowest profit movie.
    min_index = data_1[x].idxmin()
    #use the function 'idmax' to find the index of Highest profit movie.
    high_index =data_1[x].idxmax()
    high = pd.DataFrame(data_1.loc[high_index,:])
    low = pd.DataFrame(data_1.loc[min_index,:])
    
    #print the movie with high and low profit
    print("Movie Which Has Highest "+ x + " : ",data_1['title'][high_index])
    print("Movie Which Has Lowest "+ x + "  : ",data_1['title'][min_index])
    return pd.concat([high,low],axis = 1)

#call the find_minmax function.
find_minmax('budget')
# Out:
# Movie Which Has Highest budget :  My Way (Mai Wei) (2011)
# Movie Which Has Lowest budget  :  Man Who Could Work Miracles, The (1936)
#                                                          9563525  \
# userId                                                    117395
# movieId                                                   100062
# rating                                                         3
# timestamp                                             1573945275
# title                                    My Way (Mai Wei) (2011)
# genres                                          Action|Drama|War
# title_cast     Dong-Gun Jang|Joe Odagiri|Bingbing Fan|In-kwon...
# director                                             Je-kyu Kang
# runtime                                                      137
# budget                                               30000000000
# plot_keywords                 year 1944|dead soldier|1940s|korea
# numRatings                                                    13
# release_year                                                2011
#
#                                                16366
# userId                                          120949
# movieId                                          81768
# rating                                               3
# timestamp                                   1289595242
# title          Man Who Could Work Miracles, The (1936)
# genres                                  Comedy|Fantasy
# title_cast                                         NaN
# director                                           NaN
# runtime                                            NaN
# budget                                               0
# plot_keywords                                      NaN
# numRatings                                           6
# release_year                                      1936

# %% [markdown]
# * We can see that Stephen King (23 movies released) and Edward Burns (9 movies released) are outperforming the directors; inclusive of Luc Besson who has the most movies directed (26).

# %% [markdown]
# # **Top Ten Budget Movies**

# %%
#make a plot which contain top 10 highest budget movies.
#sort the 'budget' column in decending order and store it in the new dataframe.
info = pd.DataFrame(data_1['budget'].sort_values(ascending = False))
info['title'] = data_1['title']
data = list(map(str,(info['title'])))

#extract the top 10 budget movies data from the list and dataframe.
x = list(data[:10])
y = list(info['budget'][:10])

#plot the figure and setup the title and labels.
ax = sns.pointplot(x=y,y=x)
sns.set(rc={'figure.figsize':(10,5)})
ax.set_title("Top 10 High Budget Movies",fontsize = 15)
ax.set_xlabel("Budget",fontsize = 13)
sns.set_style("darkgrid")

# %% [markdown]
# **Observations:**
#
# * This is a line graph which shows the Top 10 high budget movies of which My Way is the Top budget Movie.

# %% [markdown]
# # **Top Ten Longest Movies**

# %%
#top 10 Movies With Longest runtime
#sort the 'runtime' column in decending order and store it in the new dataframe.
info = pd.DataFrame(data_1['runtime'].sort_values(ascending = False))
info['title'] = data_1['title']
data = list(map(str,(info['title'])))

#extract the top 10 longest duraton movies data from the list and dataframe.
x = list(data[:10])
y = list(info['runtime'][:10])

#make the point plot and setup the title and labels.
ax = sns.pointplot(x=y,y=x)
sns.set(rc={'figure.figsize':(10,5)})
ax.set_title("Top 10 Longest Movies",fontsize = 15)
ax.set_xlabel("Runtime",fontsize = 13)
sns.set_style("darkgrid")

# %% [markdown]
# **Observations:**
#
# * This is a line graph which shows the top 10 longest movies of which taken is the longest Movie.

# %% [markdown]
# # Average Runtime Per Annum

# %%
from sklearn.linear_model import LinearRegression

# create a dataframe with runtime data
runtime_data = pd.DataFrame(data_1.dropna().groupby('release_year').mean()['runtime']).dropna()
runtime_data.index = runtime_data.index.astype('int')
runtime_data = runtime_data[runtime_data['runtime']>1].copy()

# train a linear regression model for the trend
lrm = LinearRegression()
runtime_data = runtime_data.reset_index()
lrm.fit(runtime_data.release_year.values.reshape(-1,1),runtime_data.runtime.values.reshape(-1,1))

# make predictions
runtime_data['regression'] = lrm.predict(runtime_data.release_year.values.reshape(-1,1))

# visualize the runtime per annum
runtime_data = runtime_data.set_index('release_year')
runtime_data.plot(figsize=(10,6))
plt.title("Average runtime per annum\n")
plt.ylabel("Average runtime")
plt.show()

# %% [markdown]
# **Observation:**
# * We can see that average runtime of movies have consistantly increased from 1900 to the early 1990's from which time it has plateued until the last year of the dataset, this could be due to the decrease in the crisis of studio lot time which allows movies to be made longer due to the reduction in cast.
# * We can observe that there has been an high variation from 1900 to early 1990 and less variation till the end of the dataset this could be due to the fact that movies produed in the 90's were very short.
#
# **Recommendations:**
# * As seen in the line graph movie runtime had a high variation and that could be attributed to the technological advancement which feedback could not be given to producers or directors but anytime prior to 2000 the runtime has stabilised which could be because everyone now has internet and since they have internet they can voice out their opinions.
# * The later years of 2000 is slightly declining as seen on the graph therefore producesrs should produce shorter movies.

# %% [markdown]
# # **Average Budget Per Annum**

# %%
# create a dataframe with budget data
budget_data = pd.DataFrame(data_1.dropna().groupby('release_year').mean()['budget']).dropna()
budget_data.index = budget_data.index.astype('int')
runtime_data = budget_data[budget_data['budget']>1].copy()

# # make predictions
budget_data = budget_data.reset_index()
budget_data = budget_data.drop('budget',1).merge(pd.DataFrame(budget_data[budget_data['release_year']>1982]), on ='release_year')

# # visualize the budget per annum
plt.figure(figsize=(10,5))
sns.barplot(x='release_year',y='budget',data=budget_data, color='darkblue')
plt.title("Average budget per annum\n")
plt.ylabel("Average budget")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Observations:**
# * There is an observable trend of increase in average budget of budget of film  which could be due to special effects and CGI.
#
# **Recommendations:**
# * This trend is particularly relavent for the streaming service as networks and production houses are producing their own competing sreaming services and therefore are removing their content from existing streaming servises which puts pressure on sreaming servises to create more in-house content.

# %% [markdown]
# # **Genre With Highest Release**

# %%
#make a function will will split the string and return the count of each genre.
def count_genre(x):
    
    """"
    This function gives a function will split
    the string and return the count of each genre.
    
    Input : dataframe column
    datatype : dataframe (integer)        
    
    output : Figure (bar plot)
    
    """
    
    #concatenate all the rows of the genrs.
    data_plot = data_1[x].str.cat(sep = '|')
    data = pd.Series(data_plot.split('|'))
    #conts each of the genre and return.
    info = data.value_counts(ascending=False)
    return info

#call the function for counting the movies of each genre.
total_genre_movies = count_genre('genres')
#plot a 'barh' plot using plot function for 'genre vs number of movies'.
total_genre_movies.plot(kind= 'barh',figsize = (13,6),fontsize=12,colormap='tab20c')

#setup the title and the labels of the plot.
plt.title("Genre With Highest Release",fontsize=15)
plt.xlabel('Number Of Movies',fontsize=13)
plt.ylabel("Genres",fontsize= 13)
sns.set_style("whitegrid")

# %% [markdown]
# **Observations:**
# * Drama, Comedy, Action, Thriller and adventure are the top 5 genre in the dataset.
#
# **Recommndations:**
# * Netflix should endeavor to match the order of genre of movies available in terms of quantity to the popularity of the genre so as to maximise the views, this in turn will maximise the revenue in films.

# %%
i = 0
# Create a list for the genre count
genre_count = []
#
for genre in total_genre_movies.index:
    genre_count.append([genre, total_genre_movies[i]])
    i = i+1
# Create a plot    
plt.rc('font', weight='bold')
f, ax = plt.subplots(figsize=(10, 10))
genre_count.sort(key = lambda x:x[1], reverse = True)
labels, sizes = zip(*genre_count)
labels_selected = [n if v > sum(sizes) * 0.01 else '' for n, v in genre_count]
ax.pie(sizes, labels=labels_selected,
       autopct = lambda x:'{:2.0f}%'.format(x) if x > 1 else '',
       shadow=False, startangle=0)
ax.axis('equal')
# Plotting the pie chart
plt.tight_layout()

# %% [markdown]
# **Observations:**
#
# * The Pie Chart represents the same thing as the Bar graph of the movie released with the added benifit of the relative distribution of releases.

# %% [markdown]
# # **Correlation of Features**

# %%
def plot_correlation_map( df ):
    
    """"
    This function gives a correlation map
    using all the features from merged data.
    
    Input : dataframe column
    datatype : dataframe (integer)        
    
    output : Figure (bar plot)
    
    """
    # Plotting using the features
    
    corr = df.corr()
    _ , ax = plt.subplots( figsize =( 12 , 10 ) )
    cmap = sns.diverging_palette( 240 , 10 , as_cmap = True )
    _ = sns.heatmap(corr,cmap = cmap,square=True, cbar_kws={ 'shrink' : .9 }, ax=ax, annot = True, annot_kws = { 'fontsize' : 12 })

# %%
# Select a number of features from the dataframe to make the correlation map
plot_correlation_map(data_1[['userId','movieId','rating', 'timestamp', 'budget','runtime', 'numRatings']])

# %% [markdown]
# **Observations:**
# * We can obseve that there arent any significat positive correlations amongst the features , aside from timestamp and movieId
# * There is a very clear correlation between movieId and timestamp, this is possibly because movies have different lengths and do not end at exactly the same time

# %% [markdown]
# # Content Base Filtering and Collaborative Filtering

# %% [markdown]
# **What Is Content-based Filtering?**
#
# This filtering is based on the description or some data provided for that product. The system finds the similarity between recommended items based on their description or context. The user’s historical preference is taken into account to find products they may like in the future.
# For instance, if a user likes movies such as ‘Man in black’ then we can recommend him the movies of ‘Will Smith’ or movies with the genre ‘Sci-fi’.
#
# **Techniques used for our content based filtering:**
#
# We used CountVectoriser that is used in Feature Extraction which entirely is responsible for convecting text into vectors.
# and the reason why we chose to use count vectoriser instead of tfidVectoriser is to avoid penalising keywords, directors and genres that occurred more frequently essentially because if we have a high count in the dataset this doesn't mean that the word is less important.
#
# **Why we don't consider Content-based filtering:**
#
# content-based recommendation systems have inherent limitations because of their lack of use of other user data. And because it is inherently retrospective it does not help the user to find discover their potential new favourite movies.
# For instance, let’s say that user X and user Y like action movies. User X also likes comedy movies, because you don’t have that knowledge, you keep offering action movies. Eventually, you’re eliminating other options that user Y potentially might like.
#
#
# **What is cosine similarity?**
#
# Cosine similarity is a technique for measuring the similarity between vectors. It calculates the cosine of the angle between the two vectors. If the angle between the two vectors is zero, the similarity is calculated as 1 because the cosine of zero is 1. So the two vectors are the same. The cosine of any angle varies from 0 to 1. Therefore, similarity rates will vary from 0 to 1. The formula is expressed as follows:
#
# ![cosine.PNG](data:image/png;base64,...)
#
#
#
# **Advantages:**
#
# * The user gets recommended the types of items they love.
# * The user is satisfied by the type of recommendation.
# * New items can be recommended; just data for that item is required.
#
# **Disadvantages:**
#
# * The user will never be recommended for different items.
# * Business cannot be expanded as the user does not try a different type of product.
# * If the user matrix or item matrix is changed the cosine similarity matrix needs to be calculated again.
# * Limited content analysis: If the content doesn’t contain enough information to discriminate the items precisely, the recommendation itself risks being imprecise.
# * Over-specialization: Content-based filtering provides a limited degree of novelty since it has to match up the features of a user’s profile with available items. In the case of item-based filtering, only item profiles are created and users are suggested items similar to what they rate or search for, instead of their history. A perfect content-based filtering system may suggest nothing unexpected or surprising.

# %%
# Create a copy of a dataframe
movies = df_movies.copy()

# %%
# Merge two dataframes
df_1 = df_imdb[['movieId','title_cast','director', 'plot_keywords']]
df_1 = df_1.merge(movies[['movieId', 'genres', 'title']], on='movieId', how='inner')
df_1.head()
# Out:
#    movieId                                         title_cast  \
# 0        1  Tom Hanks|Tim Allen|Don Rickles|Jim Varney|Wal...
# 1        2  Robin Williams|Jonathan Hyde|Kirsten Dunst|Bra...
# 2        3  Walter Matthau|Jack Lemmon|Sophia Loren|Ann-Ma...
# 3        4  Whitney Houston|Angela Bassett|Loretta Devine|...
# 4        5  Steve Martin|Diane Keaton|Martin Short|Kimberl...
#
#               director                                      plot_keywords  \
# 0        John Lasseter                   toy|rivalry|cowboy|cgi animation
# 1   Jonathan Hensleigh                   board game|adventurer|fight|game
# 2  Mark Steven Johnson                         boat|lake|neighbor|rivalry
# 3       Terry McMillan  black american|husband wife relationship|betra...
# 4       Albert Hackett                    fatherhood|doberman|dog|mansion
#
#                                         genres  \
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
#
#                                 title
# 0                    Toy Story (1995)
# 1                      Jumanji (1995)
# 2             Grumpier Old Men (1995)
# 3            Waiting to Exhale (1995)
# 4  Father of the Bride Part II (1995)

# %%
# Convert data types to strings for string handling
df_1['title_cast'] = df_1.title_cast.astype(str)
df_1['plot_keywords'] = df_1.plot_keywords.astype(str)
df_1['genres'] = df_1.genres.astype(str)
df_1['director'] = df_1.director.astype(str)

# Removing spaces between names
df_1['director'] = df_1['director'].apply(lambda x: "".join(x.lower() for x in x.split()))
df_1['title_cast'] = df_1['title_cast'].apply(lambda x: "".join(x.lower() for x in x.split()))

# Discarding the pipes between the actors' full names and getting only the first three names
df_1['title_cast'] = df_1['title_cast'].map(lambda x: x.split('|'))

# Discarding the pipes between the plot keywords' and getting only the first five words
df_1['plot_keywords'] = df_1['plot_keywords'].map(lambda x: x.split('|'))
df_1['plot_keywords'] = df_1['plot_keywords'].apply(lambda x: " ".join(x))

# Discarding the pipes between the genres 
df_1['genres'] = df_1['genres'].map(lambda x: x.lower().split('|'))
df_1['genres'] = df_1['genres'].apply(lambda x: " ".join(x))

df_1.head()
# Out:
#    movieId                                         title_cast  \
# 0        1  [tomhanks, timallen, donrickles, jimvarney, wa...
# 1        2  [robinwilliams, jonathanhyde, kirstendunst, br...
# 2        3  [waltermatthau, jacklemmon, sophialoren, ann-m...
# 3        4  [whitneyhouston, angelabassett, lorettadevine,...
# 4        5  [stevemartin, dianekeaton, martinshort, kimber...
#
#             director                                      plot_keywords  \
# 0       johnlasseter                   toy rivalry cowboy cgi animation
# 1  jonathanhensleigh                   board game adventurer fight game
# 2  markstevenjohnson                         boat lake neighbor rivalry
# 3      terrymcmillan  black american husband wife relationship betra...
# 4      alberthackett                    fatherhood doberman dog mansion
#
#                                         genres  \
# 0  adventure animation children comedy fantasy
# 1                   adventure children fantasy
# 2                               comedy romance
# 3                         comedy drama romance
# 4                                       comedy
#
#                                 title
# 0                    Toy Story (1995)
# 1                      Jumanji (1995)
# 2             Grumpier Old Men (1995)
# 3            Waiting to Exhale (1995)
# 4  Father of the Bride Part II (1995)

# %%
#we convert the tille_cast column from list to string
df_1['liststring'] = df_1['title_cast'].apply(lambda x: ','.join(map(str, x)))

#we remove the commas between the string in each row
df_1['liststring'] = df_1['liststring'].replace(',',' ', regex=True)

#we choose keywords, cast(liststring), diector and genres column to use as our features
df_features = df_1[['liststring','director','plot_keywords','genres']]

#we combine the features columns into  single string
df_1['combined_features'] = df_features['liststring'] +' '+ df_features['director'] +' '+ df_features['plot_keywords'] +' '+ df_features['genres']

#we now feed the combined features to a CountVectorizer() object for getting the cv matrix.
cv =CountVectorizer()
cv_matrix = cv.fit_transform(df_1['combined_features'])

#now we obtain the cosine similarity matrix from the cv matrix
sim_score = cosine_similarity(cv_matrix,cv_matrix)

df_1.set_index('title', inplace = True)
indices = pd.Series(df_1.index)

# %%
print(sim_score)
# Out:
# [[1.         0.10910895 0.07715167 ... 0.03026138 0.         0.07881104]
#  [0.10910895 1.         0.         ... 0.06163336 0.         0.08025724]
#  [0.07715167 0.         1.         ... 0.         0.         0.        ]
#  ...
#  [0.03026138 0.06163336 0.         ... 1.         0.         0.03338903]
#  [0.         0.         0.         ... 0.         1.         0.        ]
#  [0.07881104 0.08025724 0.         ... 0.03338903 0.         1.        ]]

# %%
#Method to get recommenations
def recommendations(title,n,sim_score = sim_score):
    '''
    This method returns movies which are similar.
    
    Input:
        title: name of the movie to be compared
        n: number(quantity) of movies to be returned
        sim_core: similarity score
    Output:
        recommend movies
    '''
    
    recommended_movies = []
    
    # gettin the index of the movie that matches the title
    idx = indices[indices == title].index[0]

    # creating a Series with the similarity scores in descending order
    score_series = pd.Series(sim_score[idx]).sort_values(ascending = False)

    # getting the indexes of the 10 most similar movies
    top_n_indexes = list(score_series.iloc[1:n+1].index)
    
    # populating the list with the titles of the best n matching movies
    for i in top_n_indexes:
        recommended_movies.append(list(df_1.index)[i])
        
    return recommended_movies

# %% [markdown]
# ![i_rec.PNG](data:image/png;base64,...)
#
#
# Here’s a glimpse of what happens when you call the above function.

# %%
recommendations('Innocence (2014)',10)
# Out:
# ['Zu: Warriors from the Magic Mountain (Xin shu shan jian ke) (1983)',
#  'King Kong (1933)',
#  'The Man in the Orange Jacket (2014)',
#  'Island of Dr. Moreau, The (1977)',
#  'She (1965)',
#  'MirrorMask (2005)',
#  'Printed Rainbow (2006)',
#  'Seventh Son (2014)',
#  'The Prophecy: Forsaken (2005)',
#  'The Damned (2014)']

# %% [markdown]
# **Observations:**
# * We can observe that the top 10 movies above are similar movies to the movie Innocent released in 2014.
#
# **Recommendations:**
#
# * Since a user will not be pretty impresive with a list of recommendations, a possible improvement for this content based recommendation system would be to only keeping the most recent.
#
# * Content-based filtering is not practical, or rather, not very dependable when the number of items increases along with a need for clear and differentiated descriptions.
#
# * To overcome all the issues discussed earlier, we can implement collaborative filtering techniques, which have proven to be better and more scalable.
#
# * The content based method is also extremely memory intensive therefore we will focus on collaborative filtering

# %% [markdown]
# # **Collaborative Filtering**
#
# **What Is Collaborative Filtering?**
#
# Collaborative filtering is a technique that can filter out items that a user might like based on reactions by similar users.
#
# It works by searching a large group of people and finding a smaller set of users with tastes similar to a particular user. It looks at the items they like and combines them to create a ranked list of suggestions.
#
# to be more precise it is based on similarity in preference, taste and choices of two users. A good example that we can give you could be if user A likes movies 1,2 and 3 and user B likes movies 2,3 and 4 then this implies that they have similar interests and user A should like movie 4 and B should like movie 1.
#
#
# **Why Do We Consider Collaborating Filtering Over Content Based Filtering?**
#
# Collaborative filtering recommender engine is a much better algorithm then content-based filtering since it can do feature learning on its own, in other words, it can learn which features to use.
#
# **Advantages of Collaborative filtering:**
#
# Taken that we find collaborative filtering better than content-based, we will give a few advantages to support the argument.
#
# * Takes other user ratings into consideration
# * Doesn't need to study or extract information from a recommended item.
# * It adapts to the user's interest which might change over time.
#
# **About Collaborative Filtering Datasets:**
#
# To take note that for us to implement this algorithm or any recommendation algorithms we need a specific dataset that is structured in a specific format. This data should entail a set of items and users who have reacted to some of the items.
#
# While working with such data, you’ll mostly see it in the form of a matrix consisting of the reactions given by a set of users to some items from a set of items. Each row would contain the ratings given by a user, and each column would contain the ratings received by an item. A matrix with five users and five items could look like this:
#
#
# **Rating Matrix:**
#
#
# ![](https://files.realpython.com/media/rating-matrix.04153775e4c1.jpg)
#
# The matrix shows five users who have rated some of the items on a scale of 1 to 5. For example, the first user has given a rating 4 to the third item. n most cases, the cells in the matrix are empty, as users only rate a few items. It’s highly unlikely for every user to rate or react to every item available. A matrix with mostly empty cells is called sparse, and the opposite to that (a mostly filled matrix) is called dense.
#
# **How do you measure the accuracy of the ratings you calculate?**
#
# Essentially there are many approaches but we will explain the main approach that we will need for this project which is the Root Mean Square Error (RMSE), in which you predict ratings for a test dataset of user-item pairs whose rating values are already known. The difference between the known value and the predicted value would be the error. Square all the error values for the test set, find the average (or mean), and then take the square root of that average to get the RMSE.
#
# ![](https://www.analyticsvidhya.com/wp-content/uploads/2016/02/rmse.png)
#
# Another metric to measure the accuracy is Mean Absolute Error (MAE), in which you find the magnitude of error by finding its absolute value and then taking the average of all error values.
#
# However, we will be focusing on the RMSE for our predictions.
#
# Before diving deep into the code we would like to clarify the type of collaborative filtering we are going to implement.
#
# Recommender Systems are divided into three branches of which collaborative filtering is entailed, the figure below will make a clear breakdown to the reader.
#
# ![](https://www.seoclerk.com/pics/want61009-1nSWOn1525162745.jpg)
#
# You will notice that Collaborative filtering consist of two filtering techniques,
#
# * **Model-based Technique**
# * **Memory-based filtering**
#
# We will give a short description of these techniques.
#
# * **Model-based Technique**
# Model-based collaborative filtering algorithms provide item recommendations by first developing a model of user ratings. With these systems you will build a model from user ratings and then make recommendations based on that model, this offers a speed and scalability that not available when
# you are forced to refer back to the entire dataset to make a prediction.
#
# * **Memory based filtering**
# Memory-based rely heavily on simple similarity measures (cosine similarity, Pearson correlation and more) to match similar people or items together.
# These consist of two methods namely **Item-based** and **user based** collaborative filtering.
#
# The figure below defines the two filtering methods.
#
# ![](https://cdn-images-1.medium.com/max/1600/1*7uW5hLXztSu_FOmZOWpB6g.png)

# %% [markdown]
# ## **User-Based and Item Based**
#
# ![](https://cdn-images-1.medium.com/max/1600/1*QvhetbRjCr1vryTch_2HZQ.jpeg)

# %% [markdown]
# ## **User-user collaborative based filtering(UB-CF)**
#
# **User-User Collaborative Filtering:**
#
# Here we find look alike users based on similarity and recommend movies which first user’s look-alike has chosen in past. This algorithm is very effective but takes a lot of time and resources. It requires to compute every user pair information which takes time. Therefore, for big base platforms, this algorithm is hard to implement without a very strong parallelizable system.
#
#  A specific application of this is the user-based Nearest Neighbor algorithm. This algorithm needs two tasks:
# 1.Find the K-nearest neighbors (KNN) to the user a, using a similarity function w to measure the distance between each pair of users:
#
#
#
# ![formula.PNG](data:image/png;base64,...)

# %% [markdown]
# **Advantages:**
# * Easy to implement.
# * Context independent.
# * Compared to other techniques, such as content-based, it is more accurate.
#
# **Disadvantages**
# * Sparsity: The percentage of people who rate items is really low.
# * Scalability: The more K neighbors we consider (under a certain threshold), the better my classification should be. Nevertheless, the more users there are in the system, the greater the cost of finding the nearest K neighbors will be.
# * Cold-start: New users will have no to little information about them to be compared with other users.

# %%
# Creating a small test dataframe to evaluate our models
tests = train.copy()
tests.drop(['timestamp'], axis=1, inplace=True)
tests = tests.head(20000)

# Creating the training data
reader = Reader(rating_scale=(0.5, 5))
test_data = Dataset.load_from_df(tests[['userId','movieId','rating']], reader)

# Compute similarities between users using cosine distance
sim_options = {"name": "cosine",
               "user_based": True}  

# Evaluate the model 
user = KNNWithMeans(sim_options=sim_options)
cv = cross_validate(user, test_data, cv=5, measures=['RMSE'], verbose=True)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.1274  1.1115  1.1154  1.1112  1.1505  1.1232  0.0149
# Fit time          7.01    6.57    7.91    11.72   11.23   8.89    2.16
# Test time         0.05    0.09    0.05    0.06    0.05    0.06    0.01

# %% [markdown]
# Using UBCF gives us a RMSE score of 1.1 (based on a 2% sample of the train data)

# %% [markdown]
# # **Item-item collaborative based filtering**
#
# **Item-Item Collaborative Filtering:**
#
# It is quite similar to the previous algorithm, but instead of finding user’s look-alike, we try finding movie’s look-alike. Once we have a movie’s look-alike matrix, we can easily recommend alike movies to a user who has rated any movie from the dataset. This algorithm is far less resource consuming than user-user collaborative filtering. Hence, for a new user, the algorithm takes far lesser time than user-user collaborate as we don’t need all similarity scores between users.

# %%
# Compute similarities between items using cosine distance
sim_options = {"name": "cosine",
               "user_based": False}  

# Fit the KNNwithmeans algorithm to the training set
item_based = KNNWithMeans(sim_options=sim_options)

# Evaluate the model 
cv = cross_validate(item_based, test_data, cv=5, measures=['RMSE'], verbose=True)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0986  1.0848  1.0700  1.0663  1.0851  1.0810  0.0116
# Fit time          0.63    0.58    0.70    0.99    0.66    0.71    0.14
# Test time         0.04    0.05    0.07    0.05    0.04    0.05    0.01

# %% [markdown]
# Using IBCF gives us a RMSE score of 1.08 (based on a 2% sample of the train data) which is only a slight improvement on the UBCF method

# %% [markdown]
# # **Singular value decomposition (SVD)**
#
#
# SVD is decomposition of a matrix R which is the utility matrix with m equal to the number of users and m number exposed items (movies) into the product of three matrices:
#
# U is a left singular orthogonal matrix, representing the relationship between users and latent factors
# Σ is a diagonal matrix (with positive real values) describing the strength of each latent factor
#
# V(transpose) is a right singular orthogonal matrix, indicating the similarity between items and latent factors.
#
#
# ![](https://i.ytimg.com/vi/HGsEIMXhNpo/maxresdefault.jpg)
#
# Decompose rating matrix R in unique prosuct of 3 matrices,
# with an aim to reveal latent factors in R by minimizing RMSE
#
# * r is rank of R
# * U and V are column orthonomal
# * V^T has orthonomal rows
# * Sum of is diagonal matrix with singular values
#
# The aim of SVD is to make r smaller by settin smallest  singular
# values to 0.

# %% [markdown]
# ## **Model Building**

# %% [markdown]
# **Loading Surprise Dataset:**
#
# We will be using the dataset module which loads the pandas dataframe that is available for this experiment, The reader function is used to parse a file containing ratings data. The default format in which it accepts data is that each rating is stored in a separate line in the order user, movie and rating

# %%
# Loading as Surprise dataframe
df_train = train.copy()
reader = Reader()
# Data selected for model training
data = Dataset.load_from_df(df_train[['userId', 'movieId', 'rating']], reader)

# %%
# Data split 99/1
trainset, testset = train_test_split(data, test_size=0.01)

# %%
# Check the info of the dataset
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000038 entries, 0 to 10000037
# Data columns (total 4 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   userId     int64
#  1   movieId    int64
#  2   rating     float64
#  3   timestamp  int64
# dtypes: float64(1), int64(3)
# memory usage: 305.2 MB

# %% [markdown]
# ### **Base Algorithm**

# %%
# Base algorithm
algo = SVD()

# %%
# Fitting our trainset
algo.fit(trainset)

# %%
# Using the 15% testset to make predictions
predictions = algo.test(testset) 
predictions

test = pd.DataFrame(predictions)

# %%
# View the head
test.head()
# Out:
#       uid     iid  r_ui       est                    details
# 0   84022     480   3.0  3.993243  {'was_impossible': False}
# 1   79899    4848   3.0  4.270622  {'was_impossible': False}
# 2   84579    1407   2.0  3.154377  {'was_impossible': False}
# 3   66042  133419   3.0  3.168310  {'was_impossible': False}
# 4  155206     356   4.0  3.877412  {'was_impossible': False}

# %%
# We are trying to predict ratings for every userId / movieId pair, we implement the below list comprehension to achieve this.
ratings_predictions=[algo.predict(row.userId, row.movieId) for _,row in test_df.iterrows()]
ratings_predictions
# Out:
# [Prediction(uid=1, iid=2011, r_ui=None, est=3.286654917389448, details={'was_impossible': False}),
#  Prediction(uid=1, iid=4144, r_ui=None, est=4.133709616953146, details={'was_impossible': False}),
#  Prediction(uid=1, iid=5767, r_ui=None, est=3.7315163349337483, details={'was_impossible': False}),
#  Prediction(uid=1, iid=6711, r_ui=None, est=4.045247356949513, details={'was_impossible': False}),
#  Prediction(uid=1, iid=7318, r_ui=None, est=2.8911825698581795, details={'was_impossible': False}),
#  Prediction(uid=1, iid=8405, r_ui=None, est=4.018725690592742, details={'was_impossible': False}),
#  Prediction(uid=1, iid=8786, r_ui=None, est=4.052743622096161, details={'was_impossible': False}),
#  Prediction(uid=2, iid=150, r_ui=None, est=3.6077132416708757, details={'was_impossible': False}),
#  Prediction(uid=2, iid=356, r_ui=None, est=3.9408271672882123, details={'was_impossible': False}),
#  Prediction(uid=2, iid=497, r_ui=None, est=3.3582625702436224, details={'was_impossible': False}),
#  Prediction(uid=2, iid=588, r_ui=None, est=3.09414561763501, details={'was_impossible': False}),
#  Prediction(uid=2, iid=653, r_ui=None, est=3.039788472137982, details={'was_impossible': False}),
#  Prediction(uid=2, iid=1080, r_ui=None, est=3.907195395479977, details={'was_impossible': False}),
#  Prediction(uid=2, iid=1196, r_ui=None, est=4.459978678960821, details={'was_impossible': False}),
#  Prediction(uid=2, iid=1198, r_ui=None, est=4.047332607207676, details={'was_impossible': False}),
#  Prediction(uid=2, iid=1201, r_ui=None, est=3.8868128785386555, details={'was_impossible': False}),
#  Prediction(uid=2, iid=1299, r_ui=None, est=3.4548493285503454, details={'was_impossible': False}),
#  Prediction(uid=2, iid=1485, r_ui=None, est=2.9712573738701047, details={'was_impossible': False}),
#  Prediction(uid=2, iid=1580, r_ui=None, est=3.2233194459044827, details={'was_impossible': False}),
#  Prediction(uid=2, iid=1693, r_ui=None, est=3.416587030786821, details={'was_impossible': False}),
#  Prediction(uid=2, iid=2028, r_ui=None, est=3.95858236887138, details={'was_impossible': False}),
#  Prediction(uid=2, iid=2083, r_ui=None, est=3.340669948793507, details={'was_impossible': False}),
#  Prediction(uid=2, iid=2617, r_ui=None, est=2.977648211193519, details={'was_impossible': False}),
#  Prediction(uid=2, iid=2640, r_ui=None, est=2.9074588605338874, details={'was_impossible': False}),
#  Prediction(uid=2, iid=2918, r_ui=None, est=3.702655090393306, details={'was_impossible': False}),
#  Prediction(uid=2, iid=3098, r_ui=None, est=3.8849228022423796, details={'was_impossible': False}),
#  Prediction(uid=2, iid=3114, r_ui=None, est=3.5190328140655787, details={'was_impossible': False}),
#  Prediction(uid=2, iid=3510, r_ui=None, est=3.1886563032553763, details={'was_impossible': False}),
#  Prediction(uid=2, iid=3994, r_ui=None, est=3.8820279384540353, details={'was_impossible': False}),
#  Prediction(uid=2, iid=4103, r_ui=None, est=3.9062566661054783, details={'was_impossible': False}),
#  Prediction(uid=2, iid=4963, r_ui=None, est=3.9905187408936547, details={'was_impossible': False}),
#  Prediction(uid=2, iid=5103, r_ui=None, est=3.214154894861757, details={'was_impossible': False}),
#  Prediction(uid=2, iid=5955, r_ui=None, est=3.446913336117976, details={'was_impossible': False}),
#  Prediction(uid=2, iid=6156, r_ui=None, est=2.9818980050247808, details={'was_impossible': False}),
#  Prediction(uid=2, iid=6287, r_ui=None, est=2.8274748828573792, details={'was_impossible': False}),
#  Prediction(uid=2, iid=6311, r_ui=None, est=3.381376820469413, details={'was_impossible': False}),
#  Prediction(uid=2, iid=6753, r_ui=None, est=3.591978745833482, details={'was_impossible': False}),
#  Prediction(uid=2, iid=7075, r_ui=None, est=3.6915369704974803, details={'was_impossible': False}),
#  Prediction(uid=2, iid=7153, r_ui=None, est=5, details={'was_impossible': False}),
#  Prediction(uid=2, iid=7386, r_ui=None, est=2.5932454192403376, details={'was_impossible': False}),
#  Prediction(uid=2, iid=8961, r_ui=None, est=3.8333027400005584, details={'was_impossible': False}),
#  Prediction(uid=2, iid=30848, r_ui=None, est=3.6756664335801066, details={'was_impossible': False}),
#  Prediction(uid=2, iid=33493, r_ui=None, est=4.342352355899411, details={'was_impossible': False}),
#  Prediction(uid=2, iid=34162, r_ui=None, est=3.1807918694496404, details={'was_impossible': False}),
#  Prediction(uid=2, iid=40815, r_ui=None, est=4.852364962165408, details={'was_impossible': False}),
#  Prediction(uid=3, iid=1, r_ui=None, est=3.713359021869404, details={'was_impossible': False}),
#  Prediction(uid=3, iid=260, r_ui=None, est=3.8834612051735777, details={'was_impossible': False}),
#  Prediction(uid=3, iid=858, r_ui=None, est=4.589225637873747, details={'was_impossible': False}),
#  Prediction(uid=3, iid=1198, r_ui=None, est=3.919236217032597, details={'was_impossible': False}),
#  Prediction(uid=3, iid=1201, r_ui=None, est=4.402232706753448, details={'was_impossible': False}),
#  Prediction(uid=3, iid=1214, r_ui=None, est=4.208858521770768, details={'was_impossible': False}),
#  Prediction(uid=3, iid=1217, r_ui=None, est=4.566319527527582, details={'was_impossible': False}),
#  Prediction(uid=3, iid=1221, r_ui=None, est=4.4429907854815625, details={'was_impossible': False}),
#  Prediction(uid=3, iid=1222, r_ui=None, est=4.480553550107021, details={'was_impossible': False}),
#  Prediction(uid=3, iid=1676, r_ui=None, est=3.5194086819154626, details={'was_impossible': False}),
#  Prediction(uid=3, iid=1909, r_ui=None, est=3.620180753505588, details={'was_impossible': False}),
#  Prediction(uid=3, iid=1960, r_ui=None, est=4.080679290906165, details={'was_impossible': False}),
#  Prediction(uid=3, iid=3471, r_ui=None, est=3.9309930234095702, details={'was_impossible': False}),
#  Prediction(uid=3, iid=3534, r_ui=None, est=3.557175393270095, details={'was_impossible': False}),
#  Prediction(uid=3, iid=3730, r_ui=None, est=4.3095980265856, details={'was_impossible': False}),
#  Prediction(uid=3, iid=3785, r_ui=None, est=2.729184241205462, details={'was_impossible': False}),
#  Prediction(uid=3, iid=3948, r_ui=None, est=3.551897173210387, details={'was_impossible': False}),
#  Prediction(uid=3, iid=3979, r_ui=None, est=2.791726940568048, details={'was_impossible': False}),
#  Prediction(uid=3, iid=4025, r_ui=None, est=2.985232995352711, details={'was_impossible': False}),
#  Prediction(uid=3, iid=4148, r_ui=None, est=3.8813431586275735, details={'was_impossible': False}),
#  Prediction(uid=3, iid=4383, r_ui=None, est=3.9431308345117104, details={'was_impossible': False}),
#  Prediction(uid=3, iid=4816, r_ui=None, est=3.28694985208611, details={'was_impossible': False}),
#  Prediction(uid=3, iid=4979, r_ui=None, est=4.1319342142111815, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5219, r_ui=None, est=3.6113053005580347, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5254, r_ui=None, est=3.43230773435824, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5291, r_ui=None, est=4.61568170226043, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5313, r_ui=None, est=2.8637035669712816, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5364, r_ui=None, est=3.5750679657098354, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5479, r_ui=None, est=3.890353890249541, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5528, r_ui=None, est=3.606208756406953, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5669, r_ui=None, est=3.7544208228672096, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5679, r_ui=None, est=3.3021557073645784, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5782, r_ui=None, est=4.323242069818754, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5872, r_ui=None, est=3.519952534536669, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5900, r_ui=None, est=3.0158935142998256, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5944, r_ui=None, est=3.699695497989475, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5954, r_ui=None, est=4.137222046644534, details={'was_impossible': False}),
#  Prediction(uid=3, iid=6213, r_ui=None, est=3.547142933630482, details={'was_impossible': False}),
#  Prediction(uid=3, iid=6323, r_ui=None, est=4.150834851631254, details={'was_impossible': False}),
#  Prediction(uid=3, iid=6541, r_ui=None, est=3.4209670804624865, details={'was_impossible': False}),
#  Prediction(uid=3, iid=6586, r_ui=None, est=3.2827463102632186, details={'was_impossible': False}),
#  Prediction(uid=3, iid=6934, r_ui=None, est=3.859273848431825, details={'was_impossible': False}),
#  Prediction(uid=3, iid=6952, r_ui=None, est=3.1269411298138077, details={'was_impossible': False}),
#  Prediction(uid=3, iid=7163, r_ui=None, est=3.610435650869437, details={'was_impossible': False}),
#  Prediction(uid=3, iid=7438, r_ui=None, est=4.266471637087405, details={'was_impossible': False}),
#  Prediction(uid=3, iid=7439, r_ui=None, est=3.42382308313401, details={'was_impossible': False}),
#  Prediction(uid=3, iid=7445, r_ui=None, est=4.068729999744251, details={'was_impossible': False}),
#  Prediction(uid=3, iid=8360, r_ui=None, est=3.6506300133070577, details={'was_impossible': False}),
#  Prediction(uid=3, iid=8368, r_ui=None, est=3.8785203665975687, details={'was_impossible': False}),
#  Prediction(uid=3, iid=8370, r_ui=None, est=4.422405382784638, details={'was_impossible': False}),
#  Prediction(uid=3, iid=8529, r_ui=None, est=3.9500315704766535, details={'was_impossible': False}),
#  Prediction(uid=3, iid=8641, r_ui=None, est=3.534572493133243, details={'was_impossible': False}),
#  Prediction(uid=3, iid=8861, r_ui=None, est=3.507456675512917, details={'was_impossible': False}),
#  Prediction(uid=3, iid=8874, r_ui=None, est=4.062441925687845, details={'was_impossible': False}),
#  Prediction(uid=3, iid=27706, r_ui=None, est=3.8945366600233724, details={'was_impossible': False}),
#  Prediction(uid=3, iid=27793, r_ui=None, est=2.6584734411935034, details={'was_impossible': False}),
#  Prediction(uid=3, iid=31184, r_ui=None, est=3.7630015056994144, details={'was_impossible': False}),
#  Prediction(uid=3, iid=31685, r_ui=None, est=3.4068349205332864, details={'was_impossible': False}),
#  Prediction(uid=3, iid=31696, r_ui=None, est=4.005865613366884, details={'was_impossible': False}),
#  Prediction(uid=3, iid=31804, r_ui=None, est=3.8752612650036085, details={'was_impossible': False}),
#  Prediction(uid=3, iid=33615, r_ui=None, est=3.638488984297253, details={'was_impossible': False}),
#  Prediction(uid=3, iid=34150, r_ui=None, est=3.2902792031705292, details={'was_impossible': False}),
#  Prediction(uid=3, iid=34162, r_ui=None, est=3.5895130467726237, details={'was_impossible': False}),
#  Prediction(uid=3, iid=35836, r_ui=None, est=3.4915300712764243, details={'was_impossible': False}),
#  Prediction(uid=3, iid=37386, r_ui=None, est=3.644067553665484, details={'was_impossible': False}),
#  Prediction(uid=3, iid=44022, r_ui=None, est=3.480939390390789, details={'was_impossible': False}),
#  Prediction(uid=3, iid=46972, r_ui=None, est=2.9911890977189475, details={'was_impossible': False}),
#  Prediction(uid=3, iid=47610, r_ui=None, est=4.292416438058197, details={'was_impossible': False}),
#  Prediction(uid=3, iid=48780, r_ui=None, est=4.443749927262323, details={'was_impossible': False}),
#  Prediction(uid=3, iid=49272, r_ui=None, est=3.9135644800817637, details={'was_impossible': False}),
#  Prediction(uid=3, iid=49278, r_ui=None, est=3.875618427419838, details={'was_impossible': False}),
#  Prediction(uid=3, iid=49530, r_ui=None, est=4.140772545256826, details={'was_impossible': False}),
#  Prediction(uid=3, iid=51255, r_ui=None, est=4.065275349591884, details={'was_impossible': False}),
#  Prediction(uid=3, iid=53121, r_ui=None, est=3.3841492317721227, details={'was_impossible': False}),
#  Prediction(uid=3, iid=53129, r_ui=None, est=4.051617362690407, details={'was_impossible': False}),
#  Prediction(uid=3, iid=53464, r_ui=None, est=3.2662591785194497, details={'was_impossible': False}),
#  Prediction(uid=3, iid=55765, r_ui=None, est=4.159185800177843, details={'was_impossible': False}),
#  Prediction(uid=3, iid=55805, r_ui=None, est=3.989512809133868, details={'was_impossible': False}),
#  Prediction(uid=3, iid=58559, r_ui=None, est=4.5974499921545915, details={'was_impossible': False}),
#  Prediction(uid=3, iid=59315, r_ui=None, est=4.027516781332923, details={'was_impossible': False}),
#  Prediction(uid=3, iid=59501, r_ui=None, est=3.4733559871500606, details={'was_impossible': False}),
#  Prediction(uid=3, iid=60069, r_ui=None, est=4.1952570854825195, details={'was_impossible': False}),
#  Prediction(uid=3, iid=61350, r_ui=None, est=3.1553401070761056, details={'was_impossible': False}),
#  Prediction(uid=3, iid=64839, r_ui=None, est=3.9880684349252022, details={'was_impossible': False}),
#  Prediction(uid=3, iid=68319, r_ui=None, est=3.9194666977458397, details={'was_impossible': False}),
#  Prediction(uid=3, iid=68793, r_ui=None, est=3.0432530332346595, details={'was_impossible': False}),
#  Prediction(uid=3, iid=68952, r_ui=None, est=3.0150422564747, details={'was_impossible': False}),
#  Prediction(uid=3, iid=71057, r_ui=None, est=4.1662783488931385, details={'was_impossible': False}),
#  Prediction(uid=3, iid=71464, r_ui=None, est=4.182823721495174, details={'was_impossible': False}),
#  Prediction(uid=3, iid=72209, r_ui=None, est=3.2915334780701104, details={'was_impossible': False}),
#  Prediction(uid=3, iid=74789, r_ui=None, est=3.7808278339807515, details={'was_impossible': False}),
#  Prediction(uid=3, iid=76077, r_ui=None, est=3.182500631659671, details={'was_impossible': False}),
#  Prediction(uid=3, iid=78499, r_ui=None, est=3.7833590457625816, details={'was_impossible': False}),
#  Prediction(uid=3, iid=81845, r_ui=None, est=4.260771086445972, details={'was_impossible': False}),
#  Prediction(uid=3, iid=82202, r_ui=None, est=3.498982383215273, details={'was_impossible': False}),
#  Prediction(uid=3, iid=85020, r_ui=None, est=3.8302657667112756, details={'was_impossible': False}),
#  Prediction(uid=3, iid=85056, r_ui=None, est=3.295591293674158, details={'was_impossible': False}),
#  Prediction(uid=3, iid=88140, r_ui=None, est=3.6936922287869836, details={'was_impossible': False}),
#  Prediction(uid=3, iid=96610, r_ui=None, est=4.042299617220392, details={'was_impossible': False}),
#  Prediction(uid=3, iid=97225, r_ui=None, est=3.618004739385269, details={'was_impossible': False}),
#  Prediction(uid=3, iid=102445, r_ui=None, est=4.136303600354328, details={'was_impossible': False}),
#  Prediction(uid=3, iid=102880, r_ui=None, est=2.4545605137414976, details={'was_impossible': False}),
#  Prediction(uid=3, iid=102903, r_ui=None, est=3.9065959577829217, details={'was_impossible': False}),
#  Prediction(uid=3, iid=103141, r_ui=None, est=3.485707670714986, details={'was_impossible': False}),
#  Prediction(uid=3, iid=103772, r_ui=None, est=3.671447947737182, details={'was_impossible': False}),
#  Prediction(uid=3, iid=105213, r_ui=None, est=3.446987594996122, details={'was_impossible': False}),
#  Prediction(uid=3, iid=109374, r_ui=None, est=4.534377975964365, details={'was_impossible': False}),
#  Prediction(uid=3, iid=109487, r_ui=None, est=4.434700851924915, details={'was_impossible': False}),
#  Prediction(uid=3, iid=111443, r_ui=None, est=4.040268898421604, details={'was_impossible': False}),
#  Prediction(uid=3, iid=111659, r_ui=None, est=3.5798692119604723, details={'was_impossible': False}),
#  Prediction(uid=3, iid=112138, r_ui=None, est=3.470331160824233, details={'was_impossible': False}),
#  Prediction(uid=3, iid=114847, r_ui=None, est=3.742938369269272, details={'was_impossible': False}),
#  Prediction(uid=3, iid=115569, r_ui=None, est=4.317060351341769, details={'was_impossible': False}),
#  Prediction(uid=3, iid=116897, r_ui=None, est=4.504018532739471, details={'was_impossible': False}),
#  Prediction(uid=3, iid=117529, r_ui=None, est=3.453934090856237, details={'was_impossible': False}),
#  Prediction(uid=3, iid=122912, r_ui=None, est=3.9362537696517417, details={'was_impossible': False}),
#  Prediction(uid=3, iid=135143, r_ui=None, est=4.143476440773845, details={'was_impossible': False}),
#  Prediction(uid=3, iid=136449, r_ui=None, est=4.581898511563601, details={'was_impossible': False}),
#  Prediction(uid=3, iid=143385, r_ui=None, est=4.213026673583636, details={'was_impossible': False}),
#  Prediction(uid=3, iid=151763, r_ui=None, est=4.079614512792043, details={'was_impossible': False}),
#  Prediction(uid=4, iid=1036, r_ui=None, est=3.5696092736619827, details={'was_impossible': False}),
#  Prediction(uid=4, iid=1136, r_ui=None, est=4.376481270694796, details={'was_impossible': False}),
#  Prediction(uid=4, iid=1196, r_ui=None, est=3.57541696498913, details={'was_impossible': False}),
#  Prediction(uid=4, iid=1220, r_ui=None, est=3.9574133328673122, details={'was_impossible': False}),
#  Prediction(uid=4, iid=1907, r_ui=None, est=3.5710513723787938, details={'was_impossible': False}),
#  Prediction(uid=4, iid=2716, r_ui=None, est=3.6520473590818403, details={'was_impossible': False}),
#  Prediction(uid=4, iid=2985, r_ui=None, est=2.9804739950572556, details={'was_impossible': False}),
#  Prediction(uid=4, iid=3114, r_ui=None, est=3.748238235810757, details={'was_impossible': False}),
#  Prediction(uid=4, iid=3671, r_ui=None, est=3.5374539274749592, details={'was_impossible': False}),
#  Prediction(uid=4, iid=4709, r_ui=None, est=2.774624245745099, details={'was_impossible': False}),
#  Prediction(uid=4, iid=4816, r_ui=None, est=3.06383476358097, details={'was_impossible': False}),
#  Prediction(uid=4, iid=5110, r_ui=None, est=4.058398347770527, details={'was_impossible': False}),
#  Prediction(uid=4, iid=5418, r_ui=None, est=3.6101823039529357, details={'was_impossible': False}),
#  Prediction(uid=4, iid=5903, r_ui=None, est=3.293436723664989, details={'was_impossible': False}),
#  Prediction(uid=4, iid=6863, r_ui=None, est=3.0587084800788147, details={'was_impossible': False}),
#  Prediction(uid=4, iid=7438, r_ui=None, est=3.942426844942013, details={'was_impossible': False}),
#  Prediction(uid=4, iid=7569, r_ui=None, est=3.3139450907845154, details={'was_impossible': False}),
#  Prediction(uid=4, iid=8665, r_ui=None, est=3.4757077411919592, details={'was_impossible': False}),
#  Prediction(uid=4, iid=34048, r_ui=None, est=2.802903761759321, details={'was_impossible': False}),
#  Prediction(uid=4, iid=45431, r_ui=None, est=2.8163907102109222, details={'was_impossible': False}),
#  Prediction(uid=4, iid=49649, r_ui=None, est=1.4814230558554367, details={'was_impossible': False}),
#  Prediction(uid=4, iid=53125, r_ui=None, est=2.9176678962902765, details={'was_impossible': False}),
#  Prediction(uid=4, iid=69122, r_ui=None, est=3.3704796070399334, details={'was_impossible': False}),
#  Prediction(uid=4, iid=77561, r_ui=None, est=2.456903666581552, details={'was_impossible': False}),
#  Prediction(uid=4, iid=82461, r_ui=None, est=2.850890096451578, details={'was_impossible': False}),
#  Prediction(uid=4, iid=83134, r_ui=None, est=3.7960933709752047, details={'was_impossible': False}),
#  Prediction(uid=4, iid=85414, r_ui=None, est=3.4210568712267486, details={'was_impossible': False}),
#  Prediction(uid=4, iid=86345, r_ui=None, est=4.398865425068768, details={'was_impossible': False}),
#  Prediction(uid=4, iid=88125, r_ui=None, est=3.0337600963069797, details={'was_impossible': False}),
#  Prediction(uid=4, iid=91529, r_ui=None, est=3.2876853765899163, details={'was_impossible': False}),
#  Prediction(uid=4, iid=93510, r_ui=None, est=3.7239634846278413, details={'was_impossible': False}),
#  Prediction(uid=4, iid=93840, r_ui=None, est=3.448935998879144, details={'was_impossible': False}),
#  Prediction(uid=4, iid=96079, r_ui=None, est=3.3669187615958904, details={'was_impossible': False}),
#  Prediction(uid=4, iid=96737, r_ui=None, est=3.4069968172594782, details={'was_impossible': False}),
#  Prediction(uid=4, iid=97304, r_ui=None, est=3.1759454656288346, details={'was_impossible': False}),
#  Prediction(uid=4, iid=103228, r_ui=None, est=2.7914524958648244, details={'was_impossible': False}),
#  Prediction(uid=4, iid=103772, r_ui=None, est=2.5172978600195277, details={'was_impossible': False}),
#  Prediction(uid=4, iid=109487, r_ui=None, est=3.7361518006446146, details={'was_impossible': False}),
#  Prediction(uid=4, iid=111759, r_ui=None, est=3.256585993886165, details={'was_impossible': False}),
#  Prediction(uid=4, iid=111781, r_ui=None, est=3.100540380929366, details={'was_impossible': False}),
#  Prediction(uid=4, iid=112852, r_ui=None, est=3.2858368747208253, details={'was_impossible': False}),
#  Prediction(uid=4, iid=122882, r_ui=None, est=3.8256241092431167, details={'was_impossible': False}),
#  Prediction(uid=4, iid=122918, r_ui=None, est=3.4281264088588626, details={'was_impossible': False}),
#  Prediction(uid=4, iid=134130, r_ui=None, est=3.6402954614789116, details={'was_impossible': False}),
#  Prediction(uid=4, iid=136020, r_ui=None, est=2.8752270771815356, details={'was_impossible': False}),
#  Prediction(uid=4, iid=148626, r_ui=None, est=3.9505740427283897, details={'was_impossible': False}),
#  Prediction(uid=4, iid=156706, r_ui=None, est=2.9488567100295877, details={'was_impossible': False}),
#  Prediction(uid=4, iid=159817, r_ui=None, est=4.297933905260479, details={'was_impossible': False}),
#  Prediction(uid=4, iid=189333, r_ui=None, est=3.398951539757212, details={'was_impossible': False}),
#  Prediction(uid=5, iid=36, r_ui=None, est=4.574999993992275, details={'was_impossible': False}),
#  Prediction(uid=5, iid=122, r_ui=None, est=2.9537584435532374, details={'was_impossible': False}),
#  Prediction(uid=5, iid=147, r_ui=None, est=4.030126263343411, details={'was_impossible': False}),
#  Prediction(uid=5, iid=191, r_ui=None, est=2.8005034810141516, details={'was_impossible': False}),
#  Prediction(uid=5, iid=218, r_ui=None, est=3.855844933727735, details={'was_impossible': False}),
#  Prediction(uid=5, iid=231, r_ui=None, est=2.775533944294865, details={'was_impossible': False}),
#  Prediction(uid=5, iid=248, r_ui=None, est=3.189182229440873, details={'was_impossible': False}),
#  Prediction(uid=5, iid=253, r_ui=None, est=3.7394862899138985, details={'was_impossible': False}),
#  Prediction(uid=5, iid=277, r_ui=None, est=3.594104193893892, details={'was_impossible': False}),
#  Prediction(uid=5, iid=333, r_ui=None, est=3.7613296235631397, details={'was_impossible': False}),
#  Prediction(uid=5, iid=337, r_ui=None, est=4.279733351896657, details={'was_impossible': False}),
#  Prediction(uid=5, iid=344, r_ui=None, est=3.128183642491473, details={'was_impossible': False}),
#  Prediction(uid=5, iid=372, r_ui=None, est=3.7762855535671513, details={'was_impossible': False}),
#  Prediction(uid=5, iid=435, r_ui=None, est=3.1843212628978357, details={'was_impossible': False}),
#  Prediction(uid=5, iid=441, r_ui=None, est=4.145033987923349, details={'was_impossible': False}),
#  Prediction(uid=5, iid=457, r_ui=None, est=4.281072627163516, details={'was_impossible': False}),
#  Prediction(uid=5, iid=491, r_ui=None, est=3.7959681599720616, details={'was_impossible': False}),
#  Prediction(uid=5, iid=608, r_ui=None, est=4.604488266124876, details={'was_impossible': False}),
#  Prediction(uid=5, iid=628, r_ui=None, est=4.075639512787647, details={'was_impossible': False}),
#  Prediction(uid=5, iid=780, r_ui=None, est=3.5773769663905854, details={'was_impossible': False}),
#  Prediction(uid=5, iid=1016, r_ui=None, est=3.2140460858235564, details={'was_impossible': False}),
#  Prediction(uid=5, iid=1196, r_ui=None, est=4.28325308394849, details={'was_impossible': False}),
#  Prediction(uid=5, iid=1235, r_ui=None, est=4.481473991438158, details={'was_impossible': False}),
#  Prediction(uid=5, iid=1270, r_ui=None, est=4.116734079026334, details={'was_impossible': False}),
#  Prediction(uid=6, iid=161, r_ui=None, est=4.144668062403439, details={'was_impossible': False}),
#  Prediction(uid=6, iid=260, r_ui=None, est=4.319242152650107, details={'was_impossible': False}),
#  Prediction(uid=6, iid=608, r_ui=None, est=4.340334396996727, details={'was_impossible': False}),
#  Prediction(uid=6, iid=919, r_ui=None, est=4.022492933405086, details={'was_impossible': False}),
#  Prediction(uid=6, iid=1466, r_ui=None, est=4.0063394671308545, details={'was_impossible': False}),
#  Prediction(uid=6, iid=1704, r_ui=None, est=4.251769706302234, details={'was_impossible': False}),
#  Prediction(uid=7, iid=17, r_ui=None, est=4.4715707937090565, details={'was_impossible': False}),
#  Prediction(uid=7, iid=165, r_ui=None, est=3.2909632859890836, details={'was_impossible': False}),
#  Prediction(uid=7, iid=185, r_ui=None, est=3.2158540872354937, details={'was_impossible': False}),
#  Prediction(uid=7, iid=308, r_ui=None, est=4.478302212683325, details={'was_impossible': False}),
#  Prediction(uid=7, iid=590, r_ui=None, est=3.7456239241644753, details={'was_impossible': False}),
#  Prediction(uid=8, iid=10, r_ui=None, est=3.4617931965145727, details={'was_impossible': False}),
#  Prediction(uid=8, iid=25, r_ui=None, est=3.8859556289929036, details={'was_impossible': False}),
#  Prediction(uid=8, iid=27, r_ui=None, est=3.4476524582172434, details={'was_impossible': False}),
#  Prediction(uid=8, iid=50, r_ui=None, est=4.032012931189599, details={'was_impossible': False}),
#  Prediction(uid=8, iid=69, r_ui=None, est=3.9025605462342217, details={'was_impossible': False}),
#  Prediction(uid=8, iid=207, r_ui=None, est=3.133257409285138, details={'was_impossible': False}),
#  Prediction(uid=8, iid=237, r_ui=None, est=3.2545310230320124, details={'was_impossible': False}),
#  Prediction(uid=8, iid=260, r_ui=None, est=3.1540866176925717, details={'was_impossible': False}),
#  Prediction(uid=8, iid=356, r_ui=None, est=3.779980498305011, details={'was_impossible': False}),
#  Prediction(uid=8, iid=440, r_ui=None, est=3.403310530695899, details={'was_impossible': False}),
#  Prediction(uid=8, iid=588, r_ui=None, est=3.310879335501715, details={'was_impossible': False}),
#  Prediction(uid=8, iid=593, r_ui=None, est=4.021243175520425, details={'was_impossible': False}),
#  Prediction(uid=8, iid=750, r_ui=None, est=3.9813491663930898, details={'was_impossible': False}),
#  Prediction(uid=8, iid=923, r_ui=None, est=3.5375027682639173, details={'was_impossible': False}),
#  Prediction(uid=8, iid=953, r_ui=None, est=3.821223235021449, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1020, r_ui=None, est=3.6968788406909283, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1047, r_ui=None, est=3.8084751004395496, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1092, r_ui=None, est=3.542112951559168, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1210, r_ui=None, est=3.2181704272023652, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1240, r_ui=None, est=3.8942382918642187, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1259, r_ui=None, est=3.885781253588854, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1287, r_ui=None, est=3.1425166621045264, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1358, r_ui=None, est=3.860037567853924, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1370, r_ui=None, est=3.911966148247868, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1485, r_ui=None, est=3.826408694474131, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1552, r_ui=None, est=3.391485912418389, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1573, r_ui=None, est=4.1694613284255135, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1584, r_ui=None, est=3.2527752775082828, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1616, r_ui=None, est=3.0390700427577344, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1625, r_ui=None, est=4.050210813561829, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1645, r_ui=None, est=3.8710915205192844, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1747, r_ui=None, est=3.3622466710231995, details={'was_impossible': False}),
#  Prediction(uid=9, iid=10, r_ui=None, est=3.721530549739426, details={'was_impossible': False}),
#  Prediction(uid=9, iid=61, r_ui=None, est=3.929668893048837, details={'was_impossible': False}),
#  Prediction(uid=9, iid=105, r_ui=None, est=3.753749942062523, details={'was_impossible': False}),
#  Prediction(uid=9, iid=116, r_ui=None, est=3.893263998933605, details={'was_impossible': False}),
#  Prediction(uid=9, iid=161, r_ui=None, est=4.267469519931813, details={'was_impossible': False}),
#  Prediction(uid=9, iid=260, r_ui=None, est=3.9263304162197743, details={'was_impossible': False}),
#  Prediction(uid=9, iid=355, r_ui=None, est=3.3379122960654257, details={'was_impossible': False}),
#  Prediction(uid=9, iid=356, r_ui=None, est=4.679666081483991, details={'was_impossible': False}),
#  Prediction(uid=9, iid=366, r_ui=None, est=2.9250610660846648, details={'was_impossible': False}),
#  Prediction(uid=9, iid=378, r_ui=None, est=4.062507592441385, details={'was_impossible': False}),
#  Prediction(uid=9, iid=387, r_ui=None, est=3.4995001804289636, details={'was_impossible': False}),
#  Prediction(uid=9, iid=435, r_ui=None, est=3.121473117421982, details={'was_impossible': False}),
#  Prediction(uid=9, iid=454, r_ui=None, est=4.185364487761779, details={'was_impossible': False}),
#  Prediction(uid=9, iid=466, r_ui=None, est=3.1241404881956134, details={'was_impossible': False}),
#  Prediction(uid=9, iid=474, r_ui=None, est=4.055339588062324, details={'was_impossible': False}),
#  Prediction(uid=9, iid=516, r_ui=None, est=3.9911519315296804, details={'was_impossible': False}),
#  Prediction(uid=9, iid=541, r_ui=None, est=3.796895453899996, details={'was_impossible': False}),
#  Prediction(uid=9, iid=590, r_ui=None, est=4.395460103546458, details={'was_impossible': False}),
#  Prediction(uid=9, iid=592, r_ui=None, est=3.238068752051331, details={'was_impossible': False}),
#  Prediction(uid=9, iid=594, r_ui=None, est=3.8843957301053162, details={'was_impossible': False}),
#  Prediction(uid=9, iid=597, r_ui=None, est=4.5417700948079425, details={'was_impossible': False}),
#  Prediction(uid=9, iid=616, r_ui=None, est=4.199284175837963, details={'was_impossible': False}),
#  Prediction(uid=9, iid=667, r_ui=None, est=3.4677462661735956, details={'was_impossible': False}),
#  Prediction(uid=9, iid=852, r_ui=None, est=3.672079774028012, details={'was_impossible': False}),
#  Prediction(uid=9, iid=971, r_ui=None, est=3.8987998496166236, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1005, r_ui=None, est=3.633217066884141, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1010, r_ui=None, est=3.722954319138026, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1011, r_ui=None, est=3.726547094060882, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1018, r_ui=None, est=3.929311482746174, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1028, r_ui=None, est=4.170652339672284, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1079, r_ui=None, est=3.729839220082346, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1097, r_ui=None, est=4.279666206730039, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1101, r_ui=None, est=4.156746426769202, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1124, r_ui=None, est=4.3326429338918055, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1125, r_ui=None, est=3.6727127405631133, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1127, r_ui=None, est=4.015336111436389, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1200, r_ui=None, est=3.7685652946191524, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1221, r_ui=None, est=3.9667913388926177, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1222, r_ui=None, est=3.901819280447591, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1258, r_ui=None, est=3.66297170698782, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1298, r_ui=None, est=3.585011975326781, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1299, r_ui=None, est=4.100809783134507, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1347, r_ui=None, est=2.389819551709315, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1372, r_ui=None, est=3.993153941484277, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1376, r_ui=None, est=3.9533220024675217, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1381, r_ui=None, est=2.940051387503658, details={'was_impossible': False}),
#  Prediction(uid=10, iid=260, r_ui=None, est=4.081350721039065, details={'was_impossible': False}),
#  Prediction(uid=10, iid=380, r_ui=None, est=3.34586492226008, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1186, r_ui=None, est=3.244152999001756, details={'was_impossible': False}),
#  Prediction(uid=10, iid=2094, r_ui=None, est=2.7524356448964444, details={'was_impossible': False}),
#  Prediction(uid=10, iid=2505, r_ui=None, est=3.0191384685794382, details={'was_impossible': False}),
#  Prediction(uid=10, iid=2605, r_ui=None, est=2.915542439747695, details={'was_impossible': False}),
#  Prediction(uid=10, iid=2707, r_ui=None, est=3.5111019397671313, details={'was_impossible': False}),
#  Prediction(uid=10, iid=2944, r_ui=None, est=3.736741515383649, details={'was_impossible': False}),
#  Prediction(uid=10, iid=4361, r_ui=None, est=3.1713882053469473, details={'was_impossible': False}),
#  Prediction(uid=10, iid=5049, r_ui=None, est=3.3766792110064126, details={'was_impossible': False}),
#  Prediction(uid=10, iid=6383, r_ui=None, est=2.2633156589041077, details={'was_impossible': False}),
#  Prediction(uid=10, iid=6953, r_ui=None, est=3.7343224325328754, details={'was_impossible': False}),
#  Prediction(uid=10, iid=7444, r_ui=None, est=2.8294947633094694, details={'was_impossible': False}),
#  Prediction(uid=10, iid=7566, r_ui=None, est=3.9346185395989277, details={'was_impossible': False}),
#  Prediction(uid=10, iid=53953, r_ui=None, est=3.4726263073443797, details={'was_impossible': False}),
#  Prediction(uid=11, iid=1207, r_ui=None, est=3.482139486621149, details={'was_impossible': False}),
#  Prediction(uid=11, iid=2329, r_ui=None, est=3.6101456505620737, details={'was_impossible': False}),
#  Prediction(uid=11, iid=2581, r_ui=None, est=2.8146617829659863, details={'was_impossible': False}),
#  Prediction(uid=11, iid=2881, r_ui=None, est=3.1993333588964026, details={'was_impossible': False}),
#  Prediction(uid=11, iid=4210, r_ui=None, est=3.2129127266155617, details={'was_impossible': False}),
#  Prediction(uid=11, iid=33669, r_ui=None, est=3.1581386344137177, details={'was_impossible': False}),
#  Prediction(uid=11, iid=42723, r_ui=None, est=2.388032540229575, details={'was_impossible': False}),
#  Prediction(uid=12, iid=7, r_ui=None, est=2.851955843878856, details={'was_impossible': False}),
#  Prediction(uid=12, iid=21, r_ui=None, est=3.6866267870449945, details={'was_impossible': False}),
#  Prediction(uid=12, iid=47, r_ui=None, est=3.9178271804992373, details={'was_impossible': False}),
#  Prediction(uid=12, iid=50, r_ui=None, est=4.533050931374874, details={'was_impossible': False}),
#  Prediction(uid=12, iid=141, r_ui=None, est=3.1870748057119753, details={'was_impossible': False}),
#  Prediction(uid=12, iid=160, r_ui=None, est=1.4009776841153654, details={'was_impossible': False}),
#  Prediction(uid=12, iid=163, r_ui=None, est=2.856076757689088, details={'was_impossible': False}),
#  Prediction(uid=12, iid=203, r_ui=None, est=2.7078458193060966, details={'was_impossible': False}),
#  Prediction(uid=12, iid=238, r_ui=None, est=2.789557208722243, details={'was_impossible': False}),
#  Prediction(uid=12, iid=268, r_ui=None, est=3.469577067368115, details={'was_impossible': False}),
#  Prediction(uid=12, iid=292, r_ui=None, est=2.8548760189508346, details={'was_impossible': False}),
#  Prediction(uid=12, iid=293, r_ui=None, est=3.9530596467532573, details={'was_impossible': False}),
#  Prediction(uid=12, iid=344, r_ui=None, est=2.300434969914643, details={'was_impossible': False}),
#  Prediction(uid=12, iid=374, r_ui=None, est=1.5585186661227064, details={'was_impossible': False}),
#  Prediction(uid=12, iid=376, r_ui=None, est=2.796779127645094, details={'was_impossible': False}),
#  Prediction(uid=12, iid=380, r_ui=None, est=3.1008510490640915, details={'was_impossible': False}),
#  Prediction(uid=12, iid=477, r_ui=None, est=3.5162671614063603, details={'was_impossible': False}),
#  Prediction(uid=12, iid=497, r_ui=None, est=4.007791120411505, details={'was_impossible': False}),
#  Prediction(uid=12, iid=538, r_ui=None, est=3.5638361621736085, details={'was_impossible': False}),
#  Prediction(uid=12, iid=575, r_ui=None, est=2.289500945694246, details={'was_impossible': False}),
#  Prediction(uid=12, iid=592, r_ui=None, est=3.270618839379342, details={'was_impossible': False}),
#  Prediction(uid=12, iid=603, r_ui=None, est=2.5741933184392907, details={'was_impossible': False}),
#  Prediction(uid=12, iid=608, r_ui=None, est=4.503205346026022, details={'was_impossible': False}),
#  Prediction(uid=12, iid=613, r_ui=None, est=3.3533277019019154, details={'was_impossible': False}),
#  Prediction(uid=12, iid=765, r_ui=None, est=2.429768654462695, details={'was_impossible': False}),
#  Prediction(uid=12, iid=778, r_ui=None, est=4.33527273909557, details={'was_impossible': False}),
#  Prediction(uid=12, iid=780, r_ui=None, est=2.5957729716061904, details={'was_impossible': False}),
#  Prediction(uid=12, iid=858, r_ui=None, est=4.771906346511126, details={'was_impossible': False}),
#  Prediction(uid=12, iid=932, r_ui=None, est=3.755647403513074, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1013, r_ui=None, est=2.737666333523572, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1015, r_ui=None, est=2.815821185232427, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1057, r_ui=None, est=3.492687431787237, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1135, r_ui=None, est=2.7797036341836954, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1136, r_ui=None, est=4.342365998402395, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1183, r_ui=None, est=3.72561180420569, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1188, r_ui=None, est=3.717765723803814, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1194, r_ui=None, est=3.15651738223972, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1200, r_ui=None, est=3.872950995589413, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1225, r_ui=None, est=4.314760931937094, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1230, r_ui=None, est=3.989592482014462, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1231, r_ui=None, est=3.7091487630784052, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1243, r_ui=None, est=4.335074507106254, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1258, r_ui=None, est=4.079049309181062, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1265, r_ui=None, est=3.7002640823138337, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1267, r_ui=None, est=4.101082107237082, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1270, r_ui=None, est=3.9271249455691897, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1387, r_ui=None, est=3.66513583060831, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1391, r_ui=None, est=2.534954136117159, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1393, r_ui=None, est=3.3689630191925724, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1394, r_ui=None, est=4.088693430516584, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1474, r_ui=None, est=1.4247200637096156, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1552, r_ui=None, est=2.536605732619196, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1586, r_ui=None, est=2.4712858056605396, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1596, r_ui=None, est=3.447776362345763, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1644, r_ui=None, est=1.6250393145456727, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1665, r_ui=None, est=2.3226264759984496, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1682, r_ui=None, est=3.6940187018232, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1777, r_ui=None, est=3.2738816399273527, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1876, r_ui=None, est=2.360260835063075, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1884, r_ui=None, est=3.8985703246408834, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1947, r_ui=None, est=4.163449800034293, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2052, r_ui=None, est=1.8960819607444699, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2081, r_ui=None, est=3.1738630535744923, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2108, r_ui=None, est=3.7682141545199976, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2174, r_ui=None, est=3.450880204412527, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2318, r_ui=None, est=4.028108575328827, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2336, r_ui=None, est=4.010412321841329, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2374, r_ui=None, est=2.7657208287198642, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2381, r_ui=None, est=1, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2406, r_ui=None, est=3.3253592095630062, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2420, r_ui=None, est=3.1045963555464526, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2459, r_ui=None, est=2.5773620066110534, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2469, r_ui=None, est=2.7598028235672545, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2500, r_ui=None, est=2.159868308305481, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2599, r_ui=None, est=3.991386911485266, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2762, r_ui=None, est=3.7923236756947665, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2770, r_ui=None, est=2.875761109785093, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2797, r_ui=None, est=3.6329656528343204, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2863, r_ui=None, est=3.7375712893416675, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2881, r_ui=None, est=2.272467578812222, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2901, r_ui=None, est=2.7577205986892905, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2948, r_ui=None, est=3.6347501480520394, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2987, r_ui=None, est=3.668719625734361, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3033, r_ui=None, est=3.0896816521613077, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3089, r_ui=None, est=4.553759530175763, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3148, r_ui=None, est=3.9603293997590865, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3186, r_ui=None, est=3.2453037687833133, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3249, r_ui=None, est=2.874020626430905, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3255, r_ui=None, est=3.3158395390179605, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3262, r_ui=None, est=3.286594490117541, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3264, r_ui=None, est=2.3417759393353403, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3274, r_ui=None, est=2.8154411398385033, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3397, r_ui=None, est=3.4882953477012855, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3435, r_ui=None, est=4.311010871023535, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3478, r_ui=None, est=3.121176970570218, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3538, r_ui=None, est=3.627144863840609, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3578, r_ui=None, est=3.8997621323789433, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3608, r_ui=None, est=3.191796640239311, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3633, r_ui=None, est=3.19176850869107, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3751, r_ui=None, est=3.5336435204512533, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3809, r_ui=None, est=2.990978762329395, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3823, r_ui=None, est=3.530731720783066, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3897, r_ui=None, est=4.222902176918449, details={'was_impossible': False}),
#  Prediction(uid=12, iid=4022, r_ui=None, est=3.4499248214544145, details={'was_impossible': False}),
#  Prediction(uid=12, iid=4027, r_ui=None, est=3.9815789653802307, details={'was_impossible': False}),
#  Prediction(uid=12, iid=4039, r_ui=None, est=2.8004920416875243, details={'was_impossible': False}),
#  Prediction(uid=12, iid=4080, r_ui=None, est=2.509008354202241, details={'was_impossible': False}),
#  Prediction(uid=12, iid=4100, r_ui=None, est=1.57814929087557, details={'was_impossible': False}),
#  Prediction(uid=12, iid=4105, r_ui=None, est=3.476930385818537, details={'was_impossible': False}),
#  Prediction(uid=12, iid=4135, r_ui=None, est=2.9606788434278646, details={'was_impossible': False}),
#  Prediction(uid=12, iid=4246, r_ui=None, est=3.7340445462885072, details={'was_impossible': False}),
#  Prediction(uid=12, iid=4378, r_ui=None, est=3.539442752149979, details={'was_impossible': False}),
#  Prediction(uid=12, iid=4529, r_ui=None, est=3.84744296980197, details={'was_impossible': False}),
#  Prediction(uid=12, iid=4559, r_ui=None, est=2.1369579691625034, details={'was_impossible': False}),
#  Prediction(uid=12, iid=4703, r_ui=None, est=3.680945968739954, details={'was_impossible': False}),
#  Prediction(uid=12, iid=5013, r_ui=None, est=3.93949335477038, details={'was_impossible': False}),
#  Prediction(uid=12, iid=5339, r_ui=None, est=3.940668777604558, details={'was_impossible': False}),
#  Prediction(uid=12, iid=5459, r_ui=None, est=2.2978228329173, details={'was_impossible': False}),
#  Prediction(uid=12, iid=5481, r_ui=None, est=2.890933702615402, details={'was_impossible': False}),
#  Prediction(uid=12, iid=5785, r_ui=None, est=2.354468034595398, details={'was_impossible': False}),
#  Prediction(uid=12, iid=6268, r_ui=None, est=3.550015297952794, details={'was_impossible': False}),
#  Prediction(uid=12, iid=6296, r_ui=None, est=4.00604372301206, details={'was_impossible': False}),
#  Prediction(uid=12, iid=6297, r_ui=None, est=3.4697269022068724, details={'was_impossible': False}),
#  Prediction(uid=12, iid=6539, r_ui=None, est=3.613934545258669, details={'was_impossible': False}),
#  Prediction(uid=12, iid=6711, r_ui=None, est=4.2564518488633905, details={'was_impossible': False}),
#  Prediction(uid=12, iid=6750, r_ui=None, est=3.081534768074235, details={'was_impossible': False}),
#  Prediction(uid=12, iid=6863, r_ui=None, est=3.5783806170163075, details={'was_impossible': False}),
#  Prediction(uid=12, iid=6979, r_ui=None, est=3.5990033809826807, details={'was_impossible': False}),
#  Prediction(uid=12, iid=6993, r_ui=None, est=4.101644627710797, details={'was_impossible': False}),
#  Prediction(uid=12, iid=8017, r_ui=None, est=3.5148048684695175, details={'was_impossible': False}),
#  Prediction(uid=12, iid=8040, r_ui=None, est=2.946087266679691, details={'was_impossible': False}),
#  Prediction(uid=12, iid=8644, r_ui=None, est=3.1116400108968985, details={'was_impossible': False}),
# ...
#  Prediction(uid=23, iid=1228, r_ui=None, est=4.367310104044764, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1249, r_ui=None, est=4.288427541463973, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1265, r_ui=None, est=4.345820455408087, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1291, r_ui=None, est=4.532976143719029, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1344, r_ui=None, est=4.132300194015895, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1357, r_ui=None, est=4.3866212623328025, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1371, r_ui=None, est=3.6914253971189757, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1396, r_ui=None, est=4.258394759085032, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1449, r_ui=None, est=4.174190491900585, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1573, r_ui=None, est=3.765980738647499, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1584, r_ui=None, est=4.238432468268781, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1617, r_ui=None, est=4.64240539987542, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1625, r_ui=None, est=4.320127405550244, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1641, r_ui=None, est=4.406332770575418, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1673, r_ui=None, est=4.080071887051107, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1729, r_ui=None, est=4.167390040244567, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1810, r_ui=None, est=4.018975225025923, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1957, r_ui=None, est=4.6731973662975905, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2028, r_ui=None, est=4.768830192285961, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2058, r_ui=None, est=4.027925942865519, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2064, r_ui=None, est=3.9900235823534973, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2108, r_ui=None, est=4.229276804151151, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2166, r_ui=None, est=4.232864417951235, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2245, r_ui=None, est=3.7775776156729024, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2262, r_ui=None, est=3.2077567466890033, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2294, r_ui=None, est=3.675346538297708, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2301, r_ui=None, est=4.198296707581509, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2336, r_ui=None, est=4.580910582317706, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2411, r_ui=None, est=3.430338744125912, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2417, r_ui=None, est=3.571452625709937, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2470, r_ui=None, est=3.642728747941537, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2528, r_ui=None, est=3.7389161907108646, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2611, r_ui=None, est=4.051830887056123, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2692, r_ui=None, est=4.460420173158182, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2797, r_ui=None, est=4.225664677129213, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2871, r_ui=None, est=4.060547745745023, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2928, r_ui=None, est=3.8666658256739663, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2942, r_ui=None, est=3.2436912167138225, details={'was_impossible': False}),
#  Prediction(uid=23, iid=3019, r_ui=None, est=4.2168284217081675, details={'was_impossible': False}),
#  Prediction(uid=23, iid=3060, r_ui=None, est=4.319554140716356, details={'was_impossible': False}),
#  Prediction(uid=23, iid=3105, r_ui=None, est=4.354312856715689, details={'was_impossible': False}),
#  Prediction(uid=23, iid=3135, r_ui=None, est=4.015212901950344, details={'was_impossible': False}),
#  Prediction(uid=23, iid=3142, r_ui=None, est=3.8908325891522755, details={'was_impossible': False}),
#  Prediction(uid=24, iid=50, r_ui=None, est=4.382162356591562, details={'was_impossible': False}),
#  Prediction(uid=24, iid=1221, r_ui=None, est=4.396591596553124, details={'was_impossible': False}),
#  Prediction(uid=24, iid=1918, r_ui=None, est=3.6925835903232955, details={'was_impossible': False}),
#  Prediction(uid=24, iid=2490, r_ui=None, est=3.911941529996949, details={'was_impossible': False}),
#  Prediction(uid=24, iid=2581, r_ui=None, est=3.6301747772299198, details={'was_impossible': False}),
#  Prediction(uid=24, iid=3623, r_ui=None, est=3.649062688371498, details={'was_impossible': False}),
#  Prediction(uid=24, iid=3863, r_ui=None, est=3.322224502612416, details={'was_impossible': False}),
#  Prediction(uid=24, iid=58559, r_ui=None, est=4.798652652371149, details={'was_impossible': False}),
#  Prediction(uid=25, iid=21, r_ui=None, est=3.566196358057922, details={'was_impossible': False}),
#  Prediction(uid=25, iid=25, r_ui=None, est=3.6803248136637756, details={'was_impossible': False}),
#  Prediction(uid=25, iid=110, r_ui=None, est=3.7027932766260254, details={'was_impossible': False}),
#  Prediction(uid=25, iid=150, r_ui=None, est=3.6984881570813433, details={'was_impossible': False}),
#  Prediction(uid=25, iid=161, r_ui=None, est=3.3213738017784533, details={'was_impossible': False}),
#  Prediction(uid=25, iid=185, r_ui=None, est=3.1123405091035123, details={'was_impossible': False}),
#  Prediction(uid=25, iid=215, r_ui=None, est=3.9955642974473964, details={'was_impossible': False}),
#  Prediction(uid=25, iid=260, r_ui=None, est=3.5966459030167632, details={'was_impossible': False}),
#  Prediction(uid=25, iid=261, r_ui=None, est=3.8081887702608785, details={'was_impossible': False}),
#  Prediction(uid=25, iid=292, r_ui=None, est=3.3366857830390684, details={'was_impossible': False}),
#  Prediction(uid=25, iid=315, r_ui=None, est=2.8997960804171052, details={'was_impossible': False}),
#  Prediction(uid=25, iid=380, r_ui=None, est=3.2928929674503706, details={'was_impossible': False}),
#  Prediction(uid=25, iid=432, r_ui=None, est=2.888689545210507, details={'was_impossible': False}),
#  Prediction(uid=25, iid=457, r_ui=None, est=3.7518083086450797, details={'was_impossible': False}),
#  Prediction(uid=25, iid=480, r_ui=None, est=3.2940822282080076, details={'was_impossible': False}),
#  Prediction(uid=25, iid=595, r_ui=None, est=3.3946703648596603, details={'was_impossible': False}),
#  Prediction(uid=26, iid=455, r_ui=None, est=2.6941949821245172, details={'was_impossible': False}),
#  Prediction(uid=26, iid=590, r_ui=None, est=3.5938497328879633, details={'was_impossible': False}),
#  Prediction(uid=26, iid=1270, r_ui=None, est=4.091825059221431, details={'was_impossible': False}),
#  Prediction(uid=26, iid=2382, r_ui=None, est=1.9957807563482708, details={'was_impossible': False}),
#  Prediction(uid=26, iid=4951, r_ui=None, est=3.525851965314236, details={'was_impossible': False}),
#  Prediction(uid=26, iid=72249, r_ui=None, est=3.435995076929395, details={'was_impossible': False}),
#  Prediction(uid=27, iid=260, r_ui=None, est=3.7400688143181124, details={'was_impossible': False}),
#  Prediction(uid=27, iid=356, r_ui=None, est=4.275889764478976, details={'was_impossible': False}),
#  Prediction(uid=27, iid=597, r_ui=None, est=3.8644802188985885, details={'was_impossible': False}),
#  Prediction(uid=27, iid=1008, r_ui=None, est=3.513138040097219, details={'was_impossible': False}),
#  Prediction(uid=27, iid=1082, r_ui=None, est=3.9107693495211633, details={'was_impossible': False}),
#  Prediction(uid=27, iid=1101, r_ui=None, est=3.4902354282701022, details={'was_impossible': False}),
#  Prediction(uid=27, iid=1196, r_ui=None, est=3.906331224342715, details={'was_impossible': False}),
#  Prediction(uid=27, iid=1931, r_ui=None, est=4.352477816213938, details={'was_impossible': False}),
#  Prediction(uid=27, iid=1952, r_ui=None, est=4.206086052495681, details={'was_impossible': False}),
#  Prediction(uid=27, iid=2145, r_ui=None, est=3.9551588246828153, details={'was_impossible': False}),
#  Prediction(uid=27, iid=3098, r_ui=None, est=4.290005642253445, details={'was_impossible': False}),
#  Prediction(uid=27, iid=3365, r_ui=None, est=4.065450429788942, details={'was_impossible': False}),
#  Prediction(uid=27, iid=3671, r_ui=None, est=4.2478125423902116, details={'was_impossible': False}),
#  Prediction(uid=28, iid=610, r_ui=None, est=4.750481454073257, details={'was_impossible': False}),
#  Prediction(uid=28, iid=1407, r_ui=None, est=4.021768760719319, details={'was_impossible': False}),
#  Prediction(uid=28, iid=1580, r_ui=None, est=4.525574038215285, details={'was_impossible': False}),
#  Prediction(uid=28, iid=1584, r_ui=None, est=4.506254769162149, details={'was_impossible': False}),
#  Prediction(uid=28, iid=1909, r_ui=None, est=4.330191384620991, details={'was_impossible': False}),
#  Prediction(uid=28, iid=2021, r_ui=None, est=4.250786775927041, details={'was_impossible': False}),
#  Prediction(uid=28, iid=2311, r_ui=None, est=4.167308737416739, details={'was_impossible': False}),
#  Prediction(uid=28, iid=2723, r_ui=None, est=3.887562912357053, details={'was_impossible': False}),
#  Prediction(uid=29, iid=69, r_ui=None, est=3.215868223177887, details={'was_impossible': False}),
#  Prediction(uid=29, iid=175, r_ui=None, est=3.4529241863398017, details={'was_impossible': False}),
#  Prediction(uid=29, iid=562, r_ui=None, est=3.9612212615113025, details={'was_impossible': False}),
#  Prediction(uid=29, iid=1354, r_ui=None, est=4.007104246290667, details={'was_impossible': False}),
#  Prediction(uid=29, iid=1619, r_ui=None, est=3.677119659315031, details={'was_impossible': False}),
#  Prediction(uid=29, iid=55553, r_ui=None, est=3.1783227453655893, details={'was_impossible': False}),
#  Prediction(uid=29, iid=69784, r_ui=None, est=2.9676934585280037, details={'was_impossible': False}),
#  Prediction(uid=29, iid=72641, r_ui=None, est=3.5727102242169146, details={'was_impossible': False}),
#  Prediction(uid=30, iid=410, r_ui=None, est=3.178032581568788, details={'was_impossible': False}),
#  Prediction(uid=30, iid=1580, r_ui=None, est=3.6426987043162993, details={'was_impossible': False}),
#  Prediction(uid=30, iid=4701, r_ui=None, est=3.8060301479514713, details={'was_impossible': False}),
#  Prediction(uid=30, iid=33004, r_ui=None, est=3.889059002522303, details={'was_impossible': False}),
#  Prediction(uid=30, iid=33794, r_ui=None, est=3.839280474606745, details={'was_impossible': False}),
#  Prediction(uid=30, iid=91542, r_ui=None, est=4.064353895307997, details={'was_impossible': False}),
#  Prediction(uid=31, iid=47, r_ui=None, est=2.5214338522237343, details={'was_impossible': False}),
#  Prediction(uid=31, iid=110, r_ui=None, est=2.8287239227122285, details={'was_impossible': False}),
#  Prediction(uid=31, iid=141, r_ui=None, est=2.6043942673453753, details={'was_impossible': False}),
#  Prediction(uid=31, iid=161, r_ui=None, est=2.6389660803647663, details={'was_impossible': False}),
#  Prediction(uid=31, iid=253, r_ui=None, est=1.6209527180315688, details={'was_impossible': False}),
#  Prediction(uid=31, iid=260, r_ui=None, est=2.411574963932214, details={'was_impossible': False}),
#  Prediction(uid=31, iid=377, r_ui=None, est=2.962095986129263, details={'was_impossible': False}),
#  Prediction(uid=31, iid=434, r_ui=None, est=2.283615986743883, details={'was_impossible': False}),
#  Prediction(uid=31, iid=454, r_ui=None, est=2.3755591422101476, details={'was_impossible': False}),
#  Prediction(uid=31, iid=474, r_ui=None, est=2.7106602661865047, details={'was_impossible': False}),
#  Prediction(uid=31, iid=587, r_ui=None, est=2.614844029034078, details={'was_impossible': False}),
#  Prediction(uid=31, iid=648, r_ui=None, est=2.230999524594996, details={'was_impossible': False}),
#  Prediction(uid=31, iid=736, r_ui=None, est=2.492911983552183, details={'was_impossible': False}),
#  Prediction(uid=31, iid=932, r_ui=None, est=2.7914876870489884, details={'was_impossible': False}),
#  Prediction(uid=31, iid=1036, r_ui=None, est=3.0015313250097204, details={'was_impossible': False}),
#  Prediction(uid=31, iid=1079, r_ui=None, est=2.7817292381765033, details={'was_impossible': False}),
#  Prediction(uid=31, iid=1258, r_ui=None, est=2.7995349819910045, details={'was_impossible': False}),
#  Prediction(uid=31, iid=1393, r_ui=None, est=2.866421875821586, details={'was_impossible': False}),
#  Prediction(uid=31, iid=1459, r_ui=None, est=2.409993385506368, details={'was_impossible': False}),
#  Prediction(uid=31, iid=1479, r_ui=None, est=1.7937214099588483, details={'was_impossible': False}),
#  Prediction(uid=31, iid=1625, r_ui=None, est=2.640094596381127, details={'was_impossible': False}),
#  Prediction(uid=31, iid=1641, r_ui=None, est=2.9005919631591564, details={'was_impossible': False}),
#  Prediction(uid=31, iid=1693, r_ui=None, est=2.5884523775675174, details={'was_impossible': False}),
#  Prediction(uid=31, iid=1923, r_ui=None, est=2.4294838489192245, details={'was_impossible': False}),
#  Prediction(uid=31, iid=2028, r_ui=None, est=2.84081753312643, details={'was_impossible': False}),
#  Prediction(uid=31, iid=2081, r_ui=None, est=2.828742276287752, details={'was_impossible': False}),
#  Prediction(uid=31, iid=2141, r_ui=None, est=2.5288708677388616, details={'was_impossible': False}),
#  Prediction(uid=31, iid=2262, r_ui=None, est=2.188715846165158, details={'was_impossible': False}),
#  Prediction(uid=31, iid=2321, r_ui=None, est=2.404254539308985, details={'was_impossible': False}),
#  Prediction(uid=31, iid=2396, r_ui=None, est=2.9689362161070854, details={'was_impossible': False}),
#  Prediction(uid=31, iid=2710, r_ui=None, est=1.589184016364008, details={'was_impossible': False}),
#  Prediction(uid=31, iid=3004, r_ui=None, est=1.4171296039086778, details={'was_impossible': False}),
#  Prediction(uid=31, iid=3081, r_ui=None, est=2.0019316004407997, details={'was_impossible': False}),
#  Prediction(uid=31, iid=3175, r_ui=None, est=2.603968866027829, details={'was_impossible': False}),
#  Prediction(uid=31, iid=3206, r_ui=None, est=2.1330442460282844, details={'was_impossible': False}),
#  Prediction(uid=31, iid=3253, r_ui=None, est=2.4800974903081467, details={'was_impossible': False}),
#  Prediction(uid=31, iid=3408, r_ui=None, est=2.851595321286384, details={'was_impossible': False}),
#  Prediction(uid=31, iid=3420, r_ui=None, est=2.848990154547561, details={'was_impossible': False}),
#  Prediction(uid=31, iid=3481, r_ui=None, est=2.6865358093778453, details={'was_impossible': False}),
#  Prediction(uid=31, iid=3525, r_ui=None, est=2.1801771059918207, details={'was_impossible': False}),
#  Prediction(uid=31, iid=3755, r_ui=None, est=2.0413265477809093, details={'was_impossible': False}),
#  Prediction(uid=31, iid=3793, r_ui=None, est=2.3249560159909417, details={'was_impossible': False}),
#  Prediction(uid=31, iid=3841, r_ui=None, est=1.9594962522544883, details={'was_impossible': False}),
#  Prediction(uid=31, iid=4174, r_ui=None, est=2.681626358677404, details={'was_impossible': False}),
#  Prediction(uid=31, iid=4392, r_ui=None, est=2.446897443583313, details={'was_impossible': False}),
#  Prediction(uid=31, iid=4564, r_ui=None, est=2.2254588538582256, details={'was_impossible': False}),
#  Prediction(uid=31, iid=4639, r_ui=None, est=1.9389466949376084, details={'was_impossible': False}),
#  Prediction(uid=31, iid=4973, r_ui=None, est=2.644380052207641, details={'was_impossible': False}),
#  Prediction(uid=31, iid=4995, r_ui=None, est=2.9398011861507807, details={'was_impossible': False}),
#  Prediction(uid=31, iid=5377, r_ui=None, est=2.6267937656205915, details={'was_impossible': False}),
#  Prediction(uid=31, iid=5472, r_ui=None, est=2.5494461002748947, details={'was_impossible': False}),
#  ...]

# %%
# Converting our prediction into a familiar format-Dataframe
df_pred=pd.DataFrame(ratings_predictions)
df_pred
# Out:
#             uid   iid  r_ui       est                    details
# 0             1  2011  None  3.286655  {'was_impossible': False}
# 1             1  4144  None  4.133710  {'was_impossible': False}
# 2             1  5767  None  3.731516  {'was_impossible': False}
# 3             1  6711  None  4.045247  {'was_impossible': False}
# 4             1  7318  None  2.891183  {'was_impossible': False}
# ...         ...   ...   ...       ...                        ...
# 5000014  162541  4079  None  3.219511  {'was_impossible': False}
# 5000015  162541  4467  None  4.012342  {'was_impossible': False}
# 5000016  162541  4980  None  2.785919  {'was_impossible': False}
# 5000017  162541  5689  None  2.662126  {'was_impossible': False}
# 5000018  162541  7153  None  4.732452  {'was_impossible': False}
#
# [5000019 rows x 5 columns]

# %%
# Renaming our predictions to original names
df_pred=df_pred.rename(columns={'uid':'userId', 'iid':'movieId','est':'rating'})
df_pred.drop(['r_ui','details'],axis=1,inplace=True)

# %%
# Snippet of our ratings
df_pred.head()
# Out:
#    userId  movieId    rating
# 0       1     2011  3.286655
# 1       1     4144  4.133710
# 2       1     5767  3.731516
# 3       1     6711  4.045247
# 4       1     7318  2.891183

# %%
# Concatenating userId/movieId into a single Id column.(code has to be run twice to get desired outcome)
df_pred['Id']=df_pred.apply(lambda x:'%s_%s' % (x['userId'],x['movieId']),axis=1)
df_pred['Id']=df_pred.apply(lambda x:'%s_%s' % (x['userId'],x['movieId']),axis=1)

# %%
# View the first five rows of the dataframe
df_pred.head()
# Out:
#    userId  movieId    rating      Id
# 0       1     2011  3.286655  1_2011
# 1       1     4144  4.133710  1_4144
# 2       1     5767  3.731516  1_5767
# 3       1     6711  4.045247  1_6711
# 4       1     7318  2.891183  1_7318

# %%
# Drop the columns: 'userId' and 'movieId'
df_pred.drop(['userId', 'movieId'], inplace=True, axis= 1)

# %%
# View the predicted dataset
df_pred = df_pred[['Id', 'rating']]

# %%
# View the first 5 rows
df_pred.head()
# Out:
#        Id    rating
# 0  1_2011  3.286655
# 1  1_4144  4.133710
# 2  1_5767  3.731516
# 3  1_6711  4.045247
# 4  1_7318  2.891183

# %%
# View the shape of the dataset to be submitted 
df_pred.shape
# Out:
# (5000019, 2)

# %%
# The submitted base model
df_pred.to_csv("SVD_model_base.csv", index=False)

# %% [markdown]
# # SVD prediction with altered parameters

# %% [markdown]
# Parameters:
#
# - n_factors – The number of factors. Default is 100.
# - n_epochs – The number of iteration of the SGD procedure. Default is 20.
# - init_mean – The mean of the normal distribution for factor vectors initialization. Default is 0.
# - init_std_dev – The standard deviation of the normal distribution for factor vectors initialization. Default is 0.1.
# - lr_all – The learning rate for all parameters. Default is 0.005.
# - reg_all – The regularization term for all parameters. Default is 0.02.

# %%
# Copy of the train dataset
df_train = train.copy()
reader = Reader(rating_scale=(0, 5))
# Data for training the SVD model
sup_data= Dataset.load_from_df(df_train[['userId', 'movieId', 'rating']], reader)

# %%
# The full dataset for model training
sup_train = sup_data.build_full_trainset()
# The parameters obtained from randomised search CV
algo = SVD(n_factors = 300 , lr_all = 0.006 , reg_all = 0.04 , n_epochs = 60 , init_std_dev = 0.04)
# Fit the model
algo.fit(sup_train)

# %%
# We are trying to predict ratings for every userId / movieId pair, we implement the below list comprehension to achieve this.
ratings_predictions=[algo.predict(row.userId, row.movieId) for _,row in test_df.iterrows()]
# View the predictions
ratings_predictions
# Out:
# [Prediction(uid=1, iid=2011, r_ui=None, est=3.2857556418327434, details={'was_impossible': False}),
#  Prediction(uid=1, iid=4144, r_ui=None, est=4.2297152322406815, details={'was_impossible': False}),
#  Prediction(uid=1, iid=5767, r_ui=None, est=3.777706729961335, details={'was_impossible': False}),
#  Prediction(uid=1, iid=6711, r_ui=None, est=3.6565617825321755, details={'was_impossible': False}),
#  Prediction(uid=1, iid=7318, r_ui=None, est=2.78552183223654, details={'was_impossible': False}),
#  Prediction(uid=1, iid=8405, r_ui=None, est=3.8679097317057316, details={'was_impossible': False}),
#  Prediction(uid=1, iid=8786, r_ui=None, est=3.8681484921427582, details={'was_impossible': False}),
#  Prediction(uid=2, iid=150, r_ui=None, est=3.425616206231933, details={'was_impossible': False}),
#  Prediction(uid=2, iid=356, r_ui=None, est=3.142713872897682, details={'was_impossible': False}),
#  Prediction(uid=2, iid=497, r_ui=None, est=3.624895389094436, details={'was_impossible': False}),
#  Prediction(uid=2, iid=588, r_ui=None, est=3.4269914650055138, details={'was_impossible': False}),
#  Prediction(uid=2, iid=653, r_ui=None, est=3.1173606952379975, details={'was_impossible': False}),
#  Prediction(uid=2, iid=1080, r_ui=None, est=4.107721418239296, details={'was_impossible': False}),
#  Prediction(uid=2, iid=1196, r_ui=None, est=4.698442621088881, details={'was_impossible': False}),
#  Prediction(uid=2, iid=1198, r_ui=None, est=3.739085883481708, details={'was_impossible': False}),
#  Prediction(uid=2, iid=1201, r_ui=None, est=3.839970024654509, details={'was_impossible': False}),
#  Prediction(uid=2, iid=1299, r_ui=None, est=3.3768728770970133, details={'was_impossible': False}),
#  Prediction(uid=2, iid=1485, r_ui=None, est=2.891100670097023, details={'was_impossible': False}),
#  Prediction(uid=2, iid=1580, r_ui=None, est=3.820827807912812, details={'was_impossible': False}),
#  Prediction(uid=2, iid=1693, r_ui=None, est=3.681731550041532, details={'was_impossible': False}),
#  Prediction(uid=2, iid=2028, r_ui=None, est=3.990944897489966, details={'was_impossible': False}),
#  Prediction(uid=2, iid=2083, r_ui=None, est=3.689960672034782, details={'was_impossible': False}),
#  Prediction(uid=2, iid=2617, r_ui=None, est=2.9456088610949247, details={'was_impossible': False}),
#  Prediction(uid=2, iid=2640, r_ui=None, est=2.8690433904035033, details={'was_impossible': False}),
#  Prediction(uid=2, iid=2918, r_ui=None, est=3.4693855765110384, details={'was_impossible': False}),
#  Prediction(uid=2, iid=3098, r_ui=None, est=4.007802650085694, details={'was_impossible': False}),
#  Prediction(uid=2, iid=3114, r_ui=None, est=4.169273636738014, details={'was_impossible': False}),
#  Prediction(uid=2, iid=3510, r_ui=None, est=3.0703501832125966, details={'was_impossible': False}),
#  Prediction(uid=2, iid=3994, r_ui=None, est=3.2827112390063338, details={'was_impossible': False}),
#  Prediction(uid=2, iid=4103, r_ui=None, est=3.536164690025289, details={'was_impossible': False}),
#  Prediction(uid=2, iid=4963, r_ui=None, est=4.4637260273120924, details={'was_impossible': False}),
#  Prediction(uid=2, iid=5103, r_ui=None, est=3.220413415621954, details={'was_impossible': False}),
#  Prediction(uid=2, iid=5955, r_ui=None, est=3.3744367432584537, details={'was_impossible': False}),
#  Prediction(uid=2, iid=6156, r_ui=None, est=3.282881236787927, details={'was_impossible': False}),
#  Prediction(uid=2, iid=6287, r_ui=None, est=2.8480258501065228, details={'was_impossible': False}),
#  Prediction(uid=2, iid=6311, r_ui=None, est=3.9266165019645456, details={'was_impossible': False}),
#  Prediction(uid=2, iid=6753, r_ui=None, est=3.3363362593142565, details={'was_impossible': False}),
#  Prediction(uid=2, iid=7075, r_ui=None, est=3.210347228005172, details={'was_impossible': False}),
#  Prediction(uid=2, iid=7153, r_ui=None, est=5, details={'was_impossible': False}),
#  Prediction(uid=2, iid=7386, r_ui=None, est=2.8735835370751945, details={'was_impossible': False}),
#  Prediction(uid=2, iid=8961, r_ui=None, est=4.252814547798207, details={'was_impossible': False}),
#  Prediction(uid=2, iid=30848, r_ui=None, est=3.3522587131401713, details={'was_impossible': False}),
#  Prediction(uid=2, iid=33493, r_ui=None, est=4.364559310160606, details={'was_impossible': False}),
#  Prediction(uid=2, iid=34162, r_ui=None, est=3.2971988682863373, details={'was_impossible': False}),
#  Prediction(uid=2, iid=40815, r_ui=None, est=4.669537938805846, details={'was_impossible': False}),
#  Prediction(uid=3, iid=1, r_ui=None, est=3.64838281231755, details={'was_impossible': False}),
#  Prediction(uid=3, iid=260, r_ui=None, est=4.091354250445011, details={'was_impossible': False}),
#  Prediction(uid=3, iid=858, r_ui=None, est=4.535821223093949, details={'was_impossible': False}),
#  Prediction(uid=3, iid=1198, r_ui=None, est=3.815863875514476, details={'was_impossible': False}),
#  Prediction(uid=3, iid=1201, r_ui=None, est=4.32408262542555, details={'was_impossible': False}),
#  Prediction(uid=3, iid=1214, r_ui=None, est=4.094004093576753, details={'was_impossible': False}),
#  Prediction(uid=3, iid=1217, r_ui=None, est=4.32515720017084, details={'was_impossible': False}),
#  Prediction(uid=3, iid=1221, r_ui=None, est=4.451971116012197, details={'was_impossible': False}),
#  Prediction(uid=3, iid=1222, r_ui=None, est=4.257366320915464, details={'was_impossible': False}),
#  Prediction(uid=3, iid=1676, r_ui=None, est=3.5326998926652946, details={'was_impossible': False}),
#  Prediction(uid=3, iid=1909, r_ui=None, est=3.610161117568962, details={'was_impossible': False}),
#  Prediction(uid=3, iid=1960, r_ui=None, est=4.159194445659811, details={'was_impossible': False}),
#  Prediction(uid=3, iid=3471, r_ui=None, est=3.8060144212681983, details={'was_impossible': False}),
#  Prediction(uid=3, iid=3534, r_ui=None, est=3.2742219987533985, details={'was_impossible': False}),
#  Prediction(uid=3, iid=3730, r_ui=None, est=4.1647675422413375, details={'was_impossible': False}),
#  Prediction(uid=3, iid=3785, r_ui=None, est=2.6458948971015195, details={'was_impossible': False}),
#  Prediction(uid=3, iid=3948, r_ui=None, est=3.3097612133684127, details={'was_impossible': False}),
#  Prediction(uid=3, iid=3979, r_ui=None, est=2.7617533293562646, details={'was_impossible': False}),
#  Prediction(uid=3, iid=4025, r_ui=None, est=2.7909097878560427, details={'was_impossible': False}),
#  Prediction(uid=3, iid=4148, r_ui=None, est=3.58047724978159, details={'was_impossible': False}),
#  Prediction(uid=3, iid=4383, r_ui=None, est=4.069067051206554, details={'was_impossible': False}),
#  Prediction(uid=3, iid=4816, r_ui=None, est=3.3892995797577323, details={'was_impossible': False}),
#  Prediction(uid=3, iid=4979, r_ui=None, est=4.1515523230448945, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5219, r_ui=None, est=3.5297215445082513, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5254, r_ui=None, est=3.4005855879250797, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5291, r_ui=None, est=4.390938645855481, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5313, r_ui=None, est=2.80711038777192, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5364, r_ui=None, est=3.54072660458142, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5479, r_ui=None, est=3.7966857621154575, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5528, r_ui=None, est=3.709899256487081, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5669, r_ui=None, est=3.9034464044858312, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5679, r_ui=None, est=3.0808559382930807, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5782, r_ui=None, est=4.2848173085501955, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5872, r_ui=None, est=3.494497508548145, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5900, r_ui=None, est=3.355328410677048, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5944, r_ui=None, est=3.649679081536713, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5954, r_ui=None, est=4.190785709940077, details={'was_impossible': False}),
#  Prediction(uid=3, iid=6213, r_ui=None, est=3.4234807710492117, details={'was_impossible': False}),
#  Prediction(uid=3, iid=6323, r_ui=None, est=3.777548007282392, details={'was_impossible': False}),
#  Prediction(uid=3, iid=6541, r_ui=None, est=3.3710326261785366, details={'was_impossible': False}),
#  Prediction(uid=3, iid=6586, r_ui=None, est=3.0288181249043284, details={'was_impossible': False}),
#  Prediction(uid=3, iid=6934, r_ui=None, est=3.799782249113912, details={'was_impossible': False}),
#  Prediction(uid=3, iid=6952, r_ui=None, est=3.0449584475439146, details={'was_impossible': False}),
#  Prediction(uid=3, iid=7163, r_ui=None, est=3.5862261080910343, details={'was_impossible': False}),
#  Prediction(uid=3, iid=7438, r_ui=None, est=3.9360300971595157, details={'was_impossible': False}),
#  Prediction(uid=3, iid=7439, r_ui=None, est=3.4081126935906987, details={'was_impossible': False}),
#  Prediction(uid=3, iid=7445, r_ui=None, est=4.1388850932034975, details={'was_impossible': False}),
#  Prediction(uid=3, iid=8360, r_ui=None, est=3.6071086731529207, details={'was_impossible': False}),
#  Prediction(uid=3, iid=8368, r_ui=None, est=3.8643332738104834, details={'was_impossible': False}),
#  Prediction(uid=3, iid=8370, r_ui=None, est=4.100100783167576, details={'was_impossible': False}),
#  Prediction(uid=3, iid=8529, r_ui=None, est=3.8584113140126344, details={'was_impossible': False}),
#  Prediction(uid=3, iid=8641, r_ui=None, est=3.4601265634100717, details={'was_impossible': False}),
#  Prediction(uid=3, iid=8861, r_ui=None, est=3.3837542476312192, details={'was_impossible': False}),
#  Prediction(uid=3, iid=8874, r_ui=None, est=3.7436277597435437, details={'was_impossible': False}),
#  Prediction(uid=3, iid=27706, r_ui=None, est=3.714339291552054, details={'was_impossible': False}),
#  Prediction(uid=3, iid=27793, r_ui=None, est=2.666343616195063, details={'was_impossible': False}),
#  Prediction(uid=3, iid=31184, r_ui=None, est=3.799482047782831, details={'was_impossible': False}),
#  Prediction(uid=3, iid=31685, r_ui=None, est=3.4367553104549993, details={'was_impossible': False}),
#  Prediction(uid=3, iid=31696, r_ui=None, est=3.9271060168053586, details={'was_impossible': False}),
#  Prediction(uid=3, iid=31804, r_ui=None, est=3.8564903243746613, details={'was_impossible': False}),
#  Prediction(uid=3, iid=33615, r_ui=None, est=3.7718144165276244, details={'was_impossible': False}),
#  Prediction(uid=3, iid=34150, r_ui=None, est=3.119313138576624, details={'was_impossible': False}),
#  Prediction(uid=3, iid=34162, r_ui=None, est=3.4734003122404418, details={'was_impossible': False}),
#  Prediction(uid=3, iid=35836, r_ui=None, est=3.228145350642746, details={'was_impossible': False}),
#  Prediction(uid=3, iid=37386, r_ui=None, est=3.609100310831186, details={'was_impossible': False}),
#  Prediction(uid=3, iid=44022, r_ui=None, est=3.6424244470508906, details={'was_impossible': False}),
#  Prediction(uid=3, iid=46972, r_ui=None, est=3.0181712533679446, details={'was_impossible': False}),
#  Prediction(uid=3, iid=47610, r_ui=None, est=3.954035482702609, details={'was_impossible': False}),
#  Prediction(uid=3, iid=48780, r_ui=None, est=4.265614636714727, details={'was_impossible': False}),
#  Prediction(uid=3, iid=49272, r_ui=None, est=3.978537987012138, details={'was_impossible': False}),
#  Prediction(uid=3, iid=49278, r_ui=None, est=3.7795055991808786, details={'was_impossible': False}),
#  Prediction(uid=3, iid=49530, r_ui=None, est=4.09783776487313, details={'was_impossible': False}),
#  Prediction(uid=3, iid=51255, r_ui=None, est=3.7477773116560296, details={'was_impossible': False}),
#  Prediction(uid=3, iid=53121, r_ui=None, est=3.1239716203656105, details={'was_impossible': False}),
#  Prediction(uid=3, iid=53129, r_ui=None, est=3.9223908854411444, details={'was_impossible': False}),
#  Prediction(uid=3, iid=53464, r_ui=None, est=3.0557944924577773, details={'was_impossible': False}),
#  Prediction(uid=3, iid=55765, r_ui=None, est=4.12474425752959, details={'was_impossible': False}),
#  Prediction(uid=3, iid=55805, r_ui=None, est=3.866897282499054, details={'was_impossible': False}),
#  Prediction(uid=3, iid=58559, r_ui=None, est=4.4193381480771805, details={'was_impossible': False}),
#  Prediction(uid=3, iid=59315, r_ui=None, est=3.945106761922759, details={'was_impossible': False}),
#  Prediction(uid=3, iid=59501, r_ui=None, est=3.4635082695811614, details={'was_impossible': False}),
#  Prediction(uid=3, iid=60069, r_ui=None, est=4.287370854368878, details={'was_impossible': False}),
#  Prediction(uid=3, iid=61350, r_ui=None, est=3.295544290161738, details={'was_impossible': False}),
#  Prediction(uid=3, iid=64839, r_ui=None, est=3.882189466191488, details={'was_impossible': False}),
#  Prediction(uid=3, iid=68319, r_ui=None, est=3.586264576735843, details={'was_impossible': False}),
#  Prediction(uid=3, iid=68793, r_ui=None, est=3.1476740732826243, details={'was_impossible': False}),
#  Prediction(uid=3, iid=68952, r_ui=None, est=3.4108770396041646, details={'was_impossible': False}),
#  Prediction(uid=3, iid=71057, r_ui=None, est=4.044404546596151, details={'was_impossible': False}),
#  Prediction(uid=3, iid=71464, r_ui=None, est=3.879424344376588, details={'was_impossible': False}),
#  Prediction(uid=3, iid=72209, r_ui=None, est=3.289133735716176, details={'was_impossible': False}),
#  Prediction(uid=3, iid=74789, r_ui=None, est=3.812610696102509, details={'was_impossible': False}),
#  Prediction(uid=3, iid=76077, r_ui=None, est=3.2656395018790216, details={'was_impossible': False}),
#  Prediction(uid=3, iid=78499, r_ui=None, est=3.7472256254661707, details={'was_impossible': False}),
#  Prediction(uid=3, iid=81845, r_ui=None, est=4.148755568909388, details={'was_impossible': False}),
#  Prediction(uid=3, iid=82202, r_ui=None, est=3.5230587670865052, details={'was_impossible': False}),
#  Prediction(uid=3, iid=85020, r_ui=None, est=3.678866317145024, details={'was_impossible': False}),
#  Prediction(uid=3, iid=85056, r_ui=None, est=3.31024585631547, details={'was_impossible': False}),
#  Prediction(uid=3, iid=88140, r_ui=None, est=3.6547813001819365, details={'was_impossible': False}),
#  Prediction(uid=3, iid=96610, r_ui=None, est=3.9457478255491405, details={'was_impossible': False}),
#  Prediction(uid=3, iid=97225, r_ui=None, est=3.5895274239499857, details={'was_impossible': False}),
#  Prediction(uid=3, iid=102445, r_ui=None, est=4.018402863737812, details={'was_impossible': False}),
#  Prediction(uid=3, iid=102880, r_ui=None, est=2.582905670070634, details={'was_impossible': False}),
#  Prediction(uid=3, iid=102903, r_ui=None, est=3.887634577522259, details={'was_impossible': False}),
#  Prediction(uid=3, iid=103141, r_ui=None, est=3.5330899448823017, details={'was_impossible': False}),
#  Prediction(uid=3, iid=103772, r_ui=None, est=3.5962452000660328, details={'was_impossible': False}),
#  Prediction(uid=3, iid=105213, r_ui=None, est=3.415845554642573, details={'was_impossible': False}),
#  Prediction(uid=3, iid=109374, r_ui=None, est=4.369233456674241, details={'was_impossible': False}),
#  Prediction(uid=3, iid=109487, r_ui=None, est=4.423554011363118, details={'was_impossible': False}),
#  Prediction(uid=3, iid=111443, r_ui=None, est=3.9367117357302117, details={'was_impossible': False}),
#  Prediction(uid=3, iid=111659, r_ui=None, est=3.732772491014213, details={'was_impossible': False}),
#  Prediction(uid=3, iid=112138, r_ui=None, est=3.5031081196383624, details={'was_impossible': False}),
#  Prediction(uid=3, iid=114847, r_ui=None, est=3.8186330240226196, details={'was_impossible': False}),
#  Prediction(uid=3, iid=115569, r_ui=None, est=4.131388769484485, details={'was_impossible': False}),
#  Prediction(uid=3, iid=116897, r_ui=None, est=4.405352852186755, details={'was_impossible': False}),
#  Prediction(uid=3, iid=117529, r_ui=None, est=3.3869172208568044, details={'was_impossible': False}),
#  Prediction(uid=3, iid=122912, r_ui=None, est=3.922400469976197, details={'was_impossible': False}),
#  Prediction(uid=3, iid=135143, r_ui=None, est=3.908916136583385, details={'was_impossible': False}),
#  Prediction(uid=3, iid=136449, r_ui=None, est=4.436445633263856, details={'was_impossible': False}),
#  Prediction(uid=3, iid=143385, r_ui=None, est=4.207524323059785, details={'was_impossible': False}),
#  Prediction(uid=3, iid=151763, r_ui=None, est=4.233935840048454, details={'was_impossible': False}),
#  Prediction(uid=4, iid=1036, r_ui=None, est=3.507386969587903, details={'was_impossible': False}),
#  Prediction(uid=4, iid=1136, r_ui=None, est=4.062456565554723, details={'was_impossible': False}),
#  Prediction(uid=4, iid=1196, r_ui=None, est=3.4276122340130732, details={'was_impossible': False}),
#  Prediction(uid=4, iid=1220, r_ui=None, est=3.8052895671081357, details={'was_impossible': False}),
#  Prediction(uid=4, iid=1907, r_ui=None, est=3.9460701572593124, details={'was_impossible': False}),
#  Prediction(uid=4, iid=2716, r_ui=None, est=3.302260419778728, details={'was_impossible': False}),
#  Prediction(uid=4, iid=2985, r_ui=None, est=2.997620113242094, details={'was_impossible': False}),
#  Prediction(uid=4, iid=3114, r_ui=None, est=3.797090232256071, details={'was_impossible': False}),
#  Prediction(uid=4, iid=3671, r_ui=None, est=3.57142836058028, details={'was_impossible': False}),
#  Prediction(uid=4, iid=4709, r_ui=None, est=3.3142519862161723, details={'was_impossible': False}),
#  Prediction(uid=4, iid=4816, r_ui=None, est=3.6695559283609356, details={'was_impossible': False}),
#  Prediction(uid=4, iid=5110, r_ui=None, est=3.9986394015168956, details={'was_impossible': False}),
#  Prediction(uid=4, iid=5418, r_ui=None, est=3.6612701237572907, details={'was_impossible': False}),
#  Prediction(uid=4, iid=5903, r_ui=None, est=3.7034244212155265, details={'was_impossible': False}),
#  Prediction(uid=4, iid=6863, r_ui=None, est=3.3390050562185793, details={'was_impossible': False}),
#  Prediction(uid=4, iid=7438, r_ui=None, est=3.9373594147459507, details={'was_impossible': False}),
#  Prediction(uid=4, iid=7569, r_ui=None, est=3.422211635274898, details={'was_impossible': False}),
#  Prediction(uid=4, iid=8665, r_ui=None, est=3.498217747729, details={'was_impossible': False}),
#  Prediction(uid=4, iid=34048, r_ui=None, est=2.6471998667616177, details={'was_impossible': False}),
#  Prediction(uid=4, iid=45431, r_ui=None, est=2.8525596332424845, details={'was_impossible': False}),
#  Prediction(uid=4, iid=49649, r_ui=None, est=1.6086737515811758, details={'was_impossible': False}),
#  Prediction(uid=4, iid=53125, r_ui=None, est=3.115914569805566, details={'was_impossible': False}),
#  Prediction(uid=4, iid=69122, r_ui=None, est=3.202254713777456, details={'was_impossible': False}),
#  Prediction(uid=4, iid=77561, r_ui=None, est=2.3130562127492995, details={'was_impossible': False}),
#  Prediction(uid=4, iid=82461, r_ui=None, est=2.8246734427156848, details={'was_impossible': False}),
#  Prediction(uid=4, iid=83134, r_ui=None, est=3.725120546933145, details={'was_impossible': False}),
#  Prediction(uid=4, iid=85414, r_ui=None, est=3.1296018751893024, details={'was_impossible': False}),
#  Prediction(uid=4, iid=86345, r_ui=None, est=4.458916427407565, details={'was_impossible': False}),
#  Prediction(uid=4, iid=88125, r_ui=None, est=3.477728422789635, details={'was_impossible': False}),
#  Prediction(uid=4, iid=91529, r_ui=None, est=3.4667264596850047, details={'was_impossible': False}),
#  Prediction(uid=4, iid=93510, r_ui=None, est=3.6756972587191044, details={'was_impossible': False}),
#  Prediction(uid=4, iid=93840, r_ui=None, est=3.461479875820864, details={'was_impossible': False}),
#  Prediction(uid=4, iid=96079, r_ui=None, est=3.2224708416115044, details={'was_impossible': False}),
#  Prediction(uid=4, iid=96737, r_ui=None, est=3.64142431186466, details={'was_impossible': False}),
#  Prediction(uid=4, iid=97304, r_ui=None, est=3.6045010456620212, details={'was_impossible': False}),
#  Prediction(uid=4, iid=103228, r_ui=None, est=2.9709721965066187, details={'was_impossible': False}),
#  Prediction(uid=4, iid=103772, r_ui=None, est=2.2438254491574168, details={'was_impossible': False}),
#  Prediction(uid=4, iid=109487, r_ui=None, est=3.890087565344268, details={'was_impossible': False}),
#  Prediction(uid=4, iid=111759, r_ui=None, est=3.4049338204662716, details={'was_impossible': False}),
#  Prediction(uid=4, iid=111781, r_ui=None, est=3.106072857153059, details={'was_impossible': False}),
#  Prediction(uid=4, iid=112852, r_ui=None, est=3.108678282721785, details={'was_impossible': False}),
#  Prediction(uid=4, iid=122882, r_ui=None, est=4.022018692668299, details={'was_impossible': False}),
#  Prediction(uid=4, iid=122918, r_ui=None, est=3.134547747684762, details={'was_impossible': False}),
#  Prediction(uid=4, iid=134130, r_ui=None, est=3.4621250338719367, details={'was_impossible': False}),
#  Prediction(uid=4, iid=136020, r_ui=None, est=2.744909514052351, details={'was_impossible': False}),
#  Prediction(uid=4, iid=148626, r_ui=None, est=4.262856929968631, details={'was_impossible': False}),
#  Prediction(uid=4, iid=156706, r_ui=None, est=2.7225456088494915, details={'was_impossible': False}),
#  Prediction(uid=4, iid=159817, r_ui=None, est=4.4254509868325425, details={'was_impossible': False}),
#  Prediction(uid=4, iid=189333, r_ui=None, est=3.3534536104260084, details={'was_impossible': False}),
#  Prediction(uid=5, iid=36, r_ui=None, est=4.598711116250286, details={'was_impossible': False}),
#  Prediction(uid=5, iid=122, r_ui=None, est=3.135719395997514, details={'was_impossible': False}),
#  Prediction(uid=5, iid=147, r_ui=None, est=4.286413416301519, details={'was_impossible': False}),
#  Prediction(uid=5, iid=191, r_ui=None, est=3.0039363756787716, details={'was_impossible': False}),
#  Prediction(uid=5, iid=218, r_ui=None, est=3.995154026783084, details={'was_impossible': False}),
#  Prediction(uid=5, iid=231, r_ui=None, est=2.508898180916561, details={'was_impossible': False}),
#  Prediction(uid=5, iid=248, r_ui=None, est=3.0422943437683645, details={'was_impossible': False}),
#  Prediction(uid=5, iid=253, r_ui=None, est=4.010374135638876, details={'was_impossible': False}),
#  Prediction(uid=5, iid=277, r_ui=None, est=3.6613690291033643, details={'was_impossible': False}),
#  Prediction(uid=5, iid=333, r_ui=None, est=3.3909832554048096, details={'was_impossible': False}),
#  Prediction(uid=5, iid=337, r_ui=None, est=4.515804337895992, details={'was_impossible': False}),
#  Prediction(uid=5, iid=344, r_ui=None, est=2.6438918981937207, details={'was_impossible': False}),
#  Prediction(uid=5, iid=372, r_ui=None, est=3.8416297246440734, details={'was_impossible': False}),
#  Prediction(uid=5, iid=435, r_ui=None, est=2.823493075016099, details={'was_impossible': False}),
#  Prediction(uid=5, iid=441, r_ui=None, est=4.165487472902796, details={'was_impossible': False}),
#  Prediction(uid=5, iid=457, r_ui=None, est=4.357474815955437, details={'was_impossible': False}),
#  Prediction(uid=5, iid=491, r_ui=None, est=3.785019087649972, details={'was_impossible': False}),
#  Prediction(uid=5, iid=608, r_ui=None, est=4.674256509089014, details={'was_impossible': False}),
#  Prediction(uid=5, iid=628, r_ui=None, est=4.478817251092844, details={'was_impossible': False}),
#  Prediction(uid=5, iid=780, r_ui=None, est=3.3610225987477715, details={'was_impossible': False}),
#  Prediction(uid=5, iid=1016, r_ui=None, est=3.2558621478604826, details={'was_impossible': False}),
#  Prediction(uid=5, iid=1196, r_ui=None, est=4.577856677052966, details={'was_impossible': False}),
#  Prediction(uid=5, iid=1235, r_ui=None, est=4.619017874350861, details={'was_impossible': False}),
#  Prediction(uid=5, iid=1270, r_ui=None, est=3.9607302751585607, details={'was_impossible': False}),
#  Prediction(uid=6, iid=161, r_ui=None, est=4.075505452194383, details={'was_impossible': False}),
#  Prediction(uid=6, iid=260, r_ui=None, est=4.680914556913758, details={'was_impossible': False}),
#  Prediction(uid=6, iid=608, r_ui=None, est=4.318014006272903, details={'was_impossible': False}),
#  Prediction(uid=6, iid=919, r_ui=None, est=4.125585593749319, details={'was_impossible': False}),
#  Prediction(uid=6, iid=1466, r_ui=None, est=4.249502641278498, details={'was_impossible': False}),
#  Prediction(uid=6, iid=1704, r_ui=None, est=4.504078429954657, details={'was_impossible': False}),
#  Prediction(uid=7, iid=17, r_ui=None, est=4.267901656494242, details={'was_impossible': False}),
#  Prediction(uid=7, iid=165, r_ui=None, est=3.179434837796985, details={'was_impossible': False}),
#  Prediction(uid=7, iid=185, r_ui=None, est=3.159314128584491, details={'was_impossible': False}),
#  Prediction(uid=7, iid=308, r_ui=None, est=4.194338894993483, details={'was_impossible': False}),
#  Prediction(uid=7, iid=590, r_ui=None, est=4.022539107654753, details={'was_impossible': False}),
#  Prediction(uid=8, iid=10, r_ui=None, est=3.8857087996436754, details={'was_impossible': False}),
#  Prediction(uid=8, iid=25, r_ui=None, est=3.9022363648711886, details={'was_impossible': False}),
#  Prediction(uid=8, iid=27, r_ui=None, est=3.315731510806417, details={'was_impossible': False}),
#  Prediction(uid=8, iid=50, r_ui=None, est=3.8788361569816434, details={'was_impossible': False}),
#  Prediction(uid=8, iid=69, r_ui=None, est=4.044331873607549, details={'was_impossible': False}),
#  Prediction(uid=8, iid=207, r_ui=None, est=3.1240889798982097, details={'was_impossible': False}),
#  Prediction(uid=8, iid=237, r_ui=None, est=3.3105115722662877, details={'was_impossible': False}),
#  Prediction(uid=8, iid=260, r_ui=None, est=3.6456117289389054, details={'was_impossible': False}),
#  Prediction(uid=8, iid=356, r_ui=None, est=4.065318090338689, details={'was_impossible': False}),
#  Prediction(uid=8, iid=440, r_ui=None, est=3.2157889859862556, details={'was_impossible': False}),
#  Prediction(uid=8, iid=588, r_ui=None, est=2.8679925116505416, details={'was_impossible': False}),
#  Prediction(uid=8, iid=593, r_ui=None, est=4.045036403829149, details={'was_impossible': False}),
#  Prediction(uid=8, iid=750, r_ui=None, est=4.15148602447903, details={'was_impossible': False}),
#  Prediction(uid=8, iid=923, r_ui=None, est=3.739861216362928, details={'was_impossible': False}),
#  Prediction(uid=8, iid=953, r_ui=None, est=3.712149605150594, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1020, r_ui=None, est=3.494521601339405, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1047, r_ui=None, est=3.7748204063251105, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1092, r_ui=None, est=4.107187267935046, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1210, r_ui=None, est=3.754839095761131, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1240, r_ui=None, est=3.8493391539969726, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1259, r_ui=None, est=3.660324143486931, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1287, r_ui=None, est=3.7300417318678454, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1358, r_ui=None, est=3.6618180764913575, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1370, r_ui=None, est=3.929296512486595, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1485, r_ui=None, est=4.032139268791027, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1552, r_ui=None, est=3.518299199979976, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1573, r_ui=None, est=3.993512304955041, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1584, r_ui=None, est=3.5824462435944318, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1616, r_ui=None, est=2.9925851199394673, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1625, r_ui=None, est=4.157071198532572, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1645, r_ui=None, est=3.9567587409387635, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1747, r_ui=None, est=3.435782839338198, details={'was_impossible': False}),
#  Prediction(uid=9, iid=10, r_ui=None, est=3.523352951617536, details={'was_impossible': False}),
#  Prediction(uid=9, iid=61, r_ui=None, est=4.156509041856481, details={'was_impossible': False}),
#  Prediction(uid=9, iid=105, r_ui=None, est=4.2244619078525005, details={'was_impossible': False}),
#  Prediction(uid=9, iid=116, r_ui=None, est=4.153071681951607, details={'was_impossible': False}),
#  Prediction(uid=9, iid=161, r_ui=None, est=4.260843838822334, details={'was_impossible': False}),
#  Prediction(uid=9, iid=260, r_ui=None, est=4.300495572573937, details={'was_impossible': False}),
#  Prediction(uid=9, iid=355, r_ui=None, est=3.297883589460679, details={'was_impossible': False}),
#  Prediction(uid=9, iid=356, r_ui=None, est=4.4485348176216295, details={'was_impossible': False}),
#  Prediction(uid=9, iid=366, r_ui=None, est=2.736984326016054, details={'was_impossible': False}),
#  Prediction(uid=9, iid=378, r_ui=None, est=3.7781439890429667, details={'was_impossible': False}),
#  Prediction(uid=9, iid=387, r_ui=None, est=3.3612951860016222, details={'was_impossible': False}),
#  Prediction(uid=9, iid=435, r_ui=None, est=2.952754130908868, details={'was_impossible': False}),
#  Prediction(uid=9, iid=454, r_ui=None, est=4.095426414204234, details={'was_impossible': False}),
#  Prediction(uid=9, iid=466, r_ui=None, est=2.6014842351673577, details={'was_impossible': False}),
#  Prediction(uid=9, iid=474, r_ui=None, est=3.919147439059894, details={'was_impossible': False}),
#  Prediction(uid=9, iid=516, r_ui=None, est=4.180030035867348, details={'was_impossible': False}),
#  Prediction(uid=9, iid=541, r_ui=None, est=3.6706854576552823, details={'was_impossible': False}),
#  Prediction(uid=9, iid=590, r_ui=None, est=4.073413783186199, details={'was_impossible': False}),
#  Prediction(uid=9, iid=592, r_ui=None, est=3.255614984841341, details={'was_impossible': False}),
#  Prediction(uid=9, iid=594, r_ui=None, est=4.221711934122359, details={'was_impossible': False}),
#  Prediction(uid=9, iid=597, r_ui=None, est=4.386451421052119, details={'was_impossible': False}),
#  Prediction(uid=9, iid=616, r_ui=None, est=4.1103675733873155, details={'was_impossible': False}),
#  Prediction(uid=9, iid=667, r_ui=None, est=2.8623690797255072, details={'was_impossible': False}),
#  Prediction(uid=9, iid=852, r_ui=None, est=3.284897398776118, details={'was_impossible': False}),
#  Prediction(uid=9, iid=971, r_ui=None, est=3.8930505452317195, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1005, r_ui=None, est=3.704829227574826, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1010, r_ui=None, est=3.4374675027458865, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1011, r_ui=None, est=3.415015458623492, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1018, r_ui=None, est=3.5961115467401195, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1028, r_ui=None, est=4.340370307825258, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1079, r_ui=None, est=3.444060546037693, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1097, r_ui=None, est=4.476242097216996, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1101, r_ui=None, est=4.477755587972581, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1124, r_ui=None, est=4.165749504777105, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1125, r_ui=None, est=3.5340409879202244, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1127, r_ui=None, est=3.936663328462485, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1200, r_ui=None, est=3.4511766517308766, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1221, r_ui=None, est=3.86178958769263, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1222, r_ui=None, est=3.7091913057342003, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1258, r_ui=None, est=4.138574797065326, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1298, r_ui=None, est=4.077565820161172, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1299, r_ui=None, est=4.212185342613843, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1347, r_ui=None, est=2.9035878880786132, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1372, r_ui=None, est=4.017256905010801, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1376, r_ui=None, est=3.993765373929913, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1381, r_ui=None, est=2.9125909081516577, details={'was_impossible': False}),
#  Prediction(uid=10, iid=260, r_ui=None, est=4.463164277753648, details={'was_impossible': False}),
#  Prediction(uid=10, iid=380, r_ui=None, est=3.291199444719842, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1186, r_ui=None, est=3.27673863281215, details={'was_impossible': False}),
#  Prediction(uid=10, iid=2094, r_ui=None, est=2.6920572659436943, details={'was_impossible': False}),
#  Prediction(uid=10, iid=2505, r_ui=None, est=3.0301603924889906, details={'was_impossible': False}),
#  Prediction(uid=10, iid=2605, r_ui=None, est=2.907527682613148, details={'was_impossible': False}),
#  Prediction(uid=10, iid=2707, r_ui=None, est=3.517002108506753, details={'was_impossible': False}),
#  Prediction(uid=10, iid=2944, r_ui=None, est=3.73184439765201, details={'was_impossible': False}),
#  Prediction(uid=10, iid=4361, r_ui=None, est=3.2170880877138996, details={'was_impossible': False}),
#  Prediction(uid=10, iid=5049, r_ui=None, est=3.355151125346288, details={'was_impossible': False}),
#  Prediction(uid=10, iid=6383, r_ui=None, est=2.383719536703701, details={'was_impossible': False}),
#  Prediction(uid=10, iid=6953, r_ui=None, est=3.6348549819655998, details={'was_impossible': False}),
#  Prediction(uid=10, iid=7444, r_ui=None, est=2.6771773748897014, details={'was_impossible': False}),
#  Prediction(uid=10, iid=7566, r_ui=None, est=4.029190450744514, details={'was_impossible': False}),
#  Prediction(uid=10, iid=53953, r_ui=None, est=3.4215991258054137, details={'was_impossible': False}),
#  Prediction(uid=11, iid=1207, r_ui=None, est=2.9421801658509414, details={'was_impossible': False}),
#  Prediction(uid=11, iid=2329, r_ui=None, est=3.5675660195158363, details={'was_impossible': False}),
#  Prediction(uid=11, iid=2581, r_ui=None, est=2.6047920932695487, details={'was_impossible': False}),
#  Prediction(uid=11, iid=2881, r_ui=None, est=3.1474789718699014, details={'was_impossible': False}),
#  Prediction(uid=11, iid=4210, r_ui=None, est=2.8299935894602055, details={'was_impossible': False}),
#  Prediction(uid=11, iid=33669, r_ui=None, est=2.8478985746996406, details={'was_impossible': False}),
#  Prediction(uid=11, iid=42723, r_ui=None, est=2.6202660745874384, details={'was_impossible': False}),
#  Prediction(uid=12, iid=7, r_ui=None, est=3.1072029020884666, details={'was_impossible': False}),
#  Prediction(uid=12, iid=21, r_ui=None, est=3.7000759231889857, details={'was_impossible': False}),
#  Prediction(uid=12, iid=47, r_ui=None, est=4.038480089954039, details={'was_impossible': False}),
#  Prediction(uid=12, iid=50, r_ui=None, est=4.60294061553752, details={'was_impossible': False}),
#  Prediction(uid=12, iid=141, r_ui=None, est=3.6950219443850116, details={'was_impossible': False}),
#  Prediction(uid=12, iid=160, r_ui=None, est=1.8671976274579871, details={'was_impossible': False}),
#  Prediction(uid=12, iid=163, r_ui=None, est=3.1220845321879516, details={'was_impossible': False}),
#  Prediction(uid=12, iid=203, r_ui=None, est=2.797409252488444, details={'was_impossible': False}),
#  Prediction(uid=12, iid=238, r_ui=None, est=2.8098805296953056, details={'was_impossible': False}),
#  Prediction(uid=12, iid=268, r_ui=None, est=3.2811054130275075, details={'was_impossible': False}),
#  Prediction(uid=12, iid=292, r_ui=None, est=3.000028548207606, details={'was_impossible': False}),
#  Prediction(uid=12, iid=293, r_ui=None, est=3.877467930412892, details={'was_impossible': False}),
#  Prediction(uid=12, iid=344, r_ui=None, est=2.2091507834559714, details={'was_impossible': False}),
#  Prediction(uid=12, iid=374, r_ui=None, est=1.4657234790917884, details={'was_impossible': False}),
#  Prediction(uid=12, iid=376, r_ui=None, est=2.9067387950243484, details={'was_impossible': False}),
#  Prediction(uid=12, iid=380, r_ui=None, est=3.197944361941488, details={'was_impossible': False}),
#  Prediction(uid=12, iid=477, r_ui=None, est=3.4303793926601824, details={'was_impossible': False}),
#  Prediction(uid=12, iid=497, r_ui=None, est=3.844082765439153, details={'was_impossible': False}),
#  Prediction(uid=12, iid=538, r_ui=None, est=3.658427232253983, details={'was_impossible': False}),
#  Prediction(uid=12, iid=575, r_ui=None, est=2.261279808499688, details={'was_impossible': False}),
#  Prediction(uid=12, iid=592, r_ui=None, est=3.0908221546297074, details={'was_impossible': False}),
#  Prediction(uid=12, iid=603, r_ui=None, est=2.5082047915590047, details={'was_impossible': False}),
#  Prediction(uid=12, iid=608, r_ui=None, est=4.5402140477291795, details={'was_impossible': False}),
#  Prediction(uid=12, iid=613, r_ui=None, est=3.4305824522144617, details={'was_impossible': False}),
#  Prediction(uid=12, iid=765, r_ui=None, est=2.443871361037022, details={'was_impossible': False}),
#  Prediction(uid=12, iid=778, r_ui=None, est=4.183876637719967, details={'was_impossible': False}),
#  Prediction(uid=12, iid=780, r_ui=None, est=2.9524756584484937, details={'was_impossible': False}),
#  Prediction(uid=12, iid=858, r_ui=None, est=4.5133684434225945, details={'was_impossible': False}),
#  Prediction(uid=12, iid=932, r_ui=None, est=3.662865093992866, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1013, r_ui=None, est=3.23629093545056, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1015, r_ui=None, est=2.652595502278731, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1057, r_ui=None, est=3.588989154437854, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1135, r_ui=None, est=2.734624777341386, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1136, r_ui=None, est=3.900046400643004, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1183, r_ui=None, est=3.7228555233222185, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1188, r_ui=None, est=3.8696330922941784, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1194, r_ui=None, est=2.780624894834729, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1200, r_ui=None, est=3.9122677370225762, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1225, r_ui=None, est=4.030883917187005, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1230, r_ui=None, est=4.074254417561313, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1231, r_ui=None, est=3.5828798044181, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1243, r_ui=None, est=4.207528705169597, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1258, r_ui=None, est=4.136232778185014, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1265, r_ui=None, est=3.63558882639852, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1267, r_ui=None, est=4.153489227702838, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1270, r_ui=None, est=3.598011627260322, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1387, r_ui=None, est=3.738234325452626, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1391, r_ui=None, est=2.8817340594347933, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1393, r_ui=None, est=3.5061338419482118, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1394, r_ui=None, est=3.9769636173312763, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1474, r_ui=None, est=1.613583251604438, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1552, r_ui=None, est=2.518833700816403, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1586, r_ui=None, est=2.4956556302643573, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1596, r_ui=None, est=3.287454194673183, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1644, r_ui=None, est=2.0006207553297433, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1665, r_ui=None, est=2.1104465077128616, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1682, r_ui=None, est=3.6017053883885204, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1777, r_ui=None, est=3.0638689214429604, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1876, r_ui=None, est=2.4570283861937723, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1884, r_ui=None, est=3.594358760953811, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1947, r_ui=None, est=3.5868036477312892, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2052, r_ui=None, est=2.3255364757993515, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2081, r_ui=None, est=3.0716339640355184, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2108, r_ui=None, est=3.2943105235837242, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2174, r_ui=None, est=3.601772350087711, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2318, r_ui=None, est=3.7502868548352555, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2336, r_ui=None, est=3.832892814070245, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2374, r_ui=None, est=2.7388369778232713, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2381, r_ui=None, est=1.5640960600211362, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2406, r_ui=None, est=3.3750516749327986, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2420, r_ui=None, est=3.1664429766875988, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2459, r_ui=None, est=2.8386453349448617, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2469, r_ui=None, est=2.9605103611042995, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2500, r_ui=None, est=2.3827091012376505, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2599, r_ui=None, est=3.9746972563101126, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2762, r_ui=None, est=4.096872448688838, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2770, r_ui=None, est=2.4411799365392315, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2797, r_ui=None, est=3.874898994609898, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2863, r_ui=None, est=3.8473121801686845, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2881, r_ui=None, est=2.446592660731997, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2901, r_ui=None, est=2.6897528441973213, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2948, r_ui=None, est=3.6004550122429952, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2987, r_ui=None, est=3.360042195433864, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3033, r_ui=None, est=3.188450588513727, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3089, r_ui=None, est=3.899820540386209, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3148, r_ui=None, est=3.7269696466113675, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3186, r_ui=None, est=3.618201536118408, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3249, r_ui=None, est=2.954178111327455, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3255, r_ui=None, est=3.3567835302317848, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3262, r_ui=None, est=3.2327112673609366, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3264, r_ui=None, est=2.3946053096935156, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3274, r_ui=None, est=2.847429530072577, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3397, r_ui=None, est=3.472849743311885, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3435, r_ui=None, est=3.9976569564632283, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3478, r_ui=None, est=2.980531374575601, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3538, r_ui=None, est=3.587149593094262, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3578, r_ui=None, est=3.6574477345299123, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3608, r_ui=None, est=2.8140584632655328, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3633, r_ui=None, est=3.1416626293069356, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3751, r_ui=None, est=3.5239115145812314, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3809, r_ui=None, est=3.0281321549844695, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3823, r_ui=None, est=3.4757427234597893, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3897, r_ui=None, est=4.137244043471175, details={'was_impossible': False}),
#  Prediction(uid=12, iid=4022, r_ui=None, est=3.414424847059545, details={'was_impossible': False}),
#  Prediction(uid=12, iid=4027, r_ui=None, est=3.859288463858358, details={'was_impossible': False}),
#  Prediction(uid=12, iid=4039, r_ui=None, est=2.701248630614264, details={'was_impossible': False}),
#  Prediction(uid=12, iid=4080, r_ui=None, est=2.6310772774258924, details={'was_impossible': False}),
#  Prediction(uid=12, iid=4100, r_ui=None, est=1.661760711412299, details={'was_impossible': False}),
#  Prediction(uid=12, iid=4105, r_ui=None, est=3.6181277117430204, details={'was_impossible': False}),
#  Prediction(uid=12, iid=4135, r_ui=None, est=2.7529570160492742, details={'was_impossible': False}),
#  Prediction(uid=12, iid=4246, r_ui=None, est=3.521350696091984, details={'was_impossible': False}),
#  Prediction(uid=12, iid=4378, r_ui=None, est=3.48376346268329, details={'was_impossible': False}),
#  Prediction(uid=12, iid=4529, r_ui=None, est=3.6601020948858767, details={'was_impossible': False}),
#  Prediction(uid=12, iid=4559, r_ui=None, est=2.1001229189953223, details={'was_impossible': False}),
#  Prediction(uid=12, iid=4703, r_ui=None, est=3.641948160856099, details={'was_impossible': False}),
#  Prediction(uid=12, iid=5013, r_ui=None, est=3.5881948979697875, details={'was_impossible': False}),
#  Prediction(uid=12, iid=5339, r_ui=None, est=3.614311464143779, details={'was_impossible': False}),
#  Prediction(uid=12, iid=5459, r_ui=None, est=2.314533883173693, details={'was_impossible': False}),
#  Prediction(uid=12, iid=5481, r_ui=None, est=2.443926576915918, details={'was_impossible': False}),
#  Prediction(uid=12, iid=5785, r_ui=None, est=2.508470963290827, details={'was_impossible': False}),
#  Prediction(uid=12, iid=6268, r_ui=None, est=3.837685463588322, details={'was_impossible': False}),
#  Prediction(uid=12, iid=6296, r_ui=None, est=3.7346569438744095, details={'was_impossible': False}),
#  Prediction(uid=12, iid=6297, r_ui=None, est=3.354488369016673, details={'was_impossible': False}),
#  Prediction(uid=12, iid=6539, r_ui=None, est=3.62551544912065, details={'was_impossible': False}),
#  Prediction(uid=12, iid=6711, r_ui=None, est=4.1898071574466496, details={'was_impossible': False}),
#  Prediction(uid=12, iid=6750, r_ui=None, est=3.0644472122416895, details={'was_impossible': False}),
#  Prediction(uid=12, iid=6863, r_ui=None, est=3.233450270175444, details={'was_impossible': False}),
#  Prediction(uid=12, iid=6979, r_ui=None, est=3.640597287195635, details={'was_impossible': False}),
#  Prediction(uid=12, iid=6993, r_ui=None, est=3.994486590957102, details={'was_impossible': False}),
#  Prediction(uid=12, iid=8017, r_ui=None, est=3.706274232596688, details={'was_impossible': False}),
#  Prediction(uid=12, iid=8040, r_ui=None, est=2.9468971997441544, details={'was_impossible': False}),
#  Prediction(uid=12, iid=8644, r_ui=None, est=2.9219657542785438, details={'was_impossible': False}),
# ...
#  Prediction(uid=23, iid=1228, r_ui=None, est=4.4675997901332405, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1249, r_ui=None, est=4.0095403893639565, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1265, r_ui=None, est=4.433980080863392, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1291, r_ui=None, est=4.289754306539107, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1344, r_ui=None, est=4.139248267899222, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1357, r_ui=None, est=4.6340231365823135, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1371, r_ui=None, est=3.472027226093758, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1396, r_ui=None, est=4.333628125378095, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1449, r_ui=None, est=4.149853028451298, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1573, r_ui=None, est=3.3671758966253416, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1584, r_ui=None, est=4.081403491007445, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1617, r_ui=None, est=4.452592760067809, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1625, r_ui=None, est=3.9846627005853437, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1641, r_ui=None, est=4.300074580937414, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1673, r_ui=None, est=3.973110399277464, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1729, r_ui=None, est=3.8830022734744802, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1810, r_ui=None, est=3.9488168534412407, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1957, r_ui=None, est=4.783931920276238, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2028, r_ui=None, est=4.713132284642164, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2058, r_ui=None, est=3.619620422660871, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2064, r_ui=None, est=4.394275656971033, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2108, r_ui=None, est=4.459973055668406, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2166, r_ui=None, est=4.03518060909175, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2245, r_ui=None, est=3.764499744621869, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2262, r_ui=None, est=3.4886841476175676, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2294, r_ui=None, est=3.517088578520691, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2301, r_ui=None, est=4.087032881862054, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2336, r_ui=None, est=4.139920515480074, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2411, r_ui=None, est=3.7049098195735555, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2417, r_ui=None, est=3.3642115873306615, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2470, r_ui=None, est=3.48579533809067, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2528, r_ui=None, est=3.5384710510942154, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2611, r_ui=None, est=4.180451068489938, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2692, r_ui=None, est=3.9261402800584486, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2797, r_ui=None, est=4.492725579384214, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2871, r_ui=None, est=3.839798253091648, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2928, r_ui=None, est=4.020276701980938, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2942, r_ui=None, est=3.543822354241247, details={'was_impossible': False}),
#  Prediction(uid=23, iid=3019, r_ui=None, est=3.7376602299655395, details={'was_impossible': False}),
#  Prediction(uid=23, iid=3060, r_ui=None, est=4.25675600407056, details={'was_impossible': False}),
#  Prediction(uid=23, iid=3105, r_ui=None, est=4.654153947735512, details={'was_impossible': False}),
#  Prediction(uid=23, iid=3135, r_ui=None, est=4.414011639408001, details={'was_impossible': False}),
#  Prediction(uid=23, iid=3142, r_ui=None, est=3.9045264302193297, details={'was_impossible': False}),
#  Prediction(uid=24, iid=50, r_ui=None, est=4.388367090373483, details={'was_impossible': False}),
#  Prediction(uid=24, iid=1221, r_ui=None, est=4.232640983415338, details={'was_impossible': False}),
#  Prediction(uid=24, iid=1918, r_ui=None, est=3.916656254080897, details={'was_impossible': False}),
#  Prediction(uid=24, iid=2490, r_ui=None, est=3.9868490813999133, details={'was_impossible': False}),
#  Prediction(uid=24, iid=2581, r_ui=None, est=3.6576883424162294, details={'was_impossible': False}),
#  Prediction(uid=24, iid=3623, r_ui=None, est=3.834618104758997, details={'was_impossible': False}),
#  Prediction(uid=24, iid=3863, r_ui=None, est=3.5570641168168797, details={'was_impossible': False}),
#  Prediction(uid=24, iid=58559, r_ui=None, est=4.423021834970808, details={'was_impossible': False}),
#  Prediction(uid=25, iid=21, r_ui=None, est=3.869519912971637, details={'was_impossible': False}),
#  Prediction(uid=25, iid=25, r_ui=None, est=4.005352162329685, details={'was_impossible': False}),
#  Prediction(uid=25, iid=110, r_ui=None, est=3.871268874306523, details={'was_impossible': False}),
#  Prediction(uid=25, iid=150, r_ui=None, est=3.623898712037904, details={'was_impossible': False}),
#  Prediction(uid=25, iid=161, r_ui=None, est=3.642439499752443, details={'was_impossible': False}),
#  Prediction(uid=25, iid=185, r_ui=None, est=3.2503238568812036, details={'was_impossible': False}),
#  Prediction(uid=25, iid=215, r_ui=None, est=3.8316570535398458, details={'was_impossible': False}),
#  Prediction(uid=25, iid=260, r_ui=None, est=3.8353967657199566, details={'was_impossible': False}),
#  Prediction(uid=25, iid=261, r_ui=None, est=3.6488944214957764, details={'was_impossible': False}),
#  Prediction(uid=25, iid=292, r_ui=None, est=3.3347862452813324, details={'was_impossible': False}),
#  Prediction(uid=25, iid=315, r_ui=None, est=2.9471254901688897, details={'was_impossible': False}),
#  Prediction(uid=25, iid=380, r_ui=None, est=3.1842021276596824, details={'was_impossible': False}),
#  Prediction(uid=25, iid=432, r_ui=None, est=2.882338096606867, details={'was_impossible': False}),
#  Prediction(uid=25, iid=457, r_ui=None, est=3.887760181802971, details={'was_impossible': False}),
#  Prediction(uid=25, iid=480, r_ui=None, est=3.965076415453675, details={'was_impossible': False}),
#  Prediction(uid=25, iid=595, r_ui=None, est=3.5027976172997164, details={'was_impossible': False}),
#  Prediction(uid=26, iid=455, r_ui=None, est=2.4452159622873877, details={'was_impossible': False}),
#  Prediction(uid=26, iid=590, r_ui=None, est=3.550709955366857, details={'was_impossible': False}),
#  Prediction(uid=26, iid=1270, r_ui=None, est=3.76852193603622, details={'was_impossible': False}),
#  Prediction(uid=26, iid=2382, r_ui=None, est=2.272052244007475, details={'was_impossible': False}),
#  Prediction(uid=26, iid=4951, r_ui=None, est=3.5036583823769685, details={'was_impossible': False}),
#  Prediction(uid=26, iid=72249, r_ui=None, est=3.472756803081596, details={'was_impossible': False}),
#  Prediction(uid=27, iid=260, r_ui=None, est=3.6010754639885256, details={'was_impossible': False}),
#  Prediction(uid=27, iid=356, r_ui=None, est=3.9846175030791127, details={'was_impossible': False}),
#  Prediction(uid=27, iid=597, r_ui=None, est=4.215452191038498, details={'was_impossible': False}),
#  Prediction(uid=27, iid=1008, r_ui=None, est=3.4724504269502945, details={'was_impossible': False}),
#  Prediction(uid=27, iid=1082, r_ui=None, est=4.276530764579664, details={'was_impossible': False}),
#  Prediction(uid=27, iid=1101, r_ui=None, est=3.848645791275854, details={'was_impossible': False}),
#  Prediction(uid=27, iid=1196, r_ui=None, est=3.457341126104244, details={'was_impossible': False}),
#  Prediction(uid=27, iid=1931, r_ui=None, est=4.580591347019909, details={'was_impossible': False}),
#  Prediction(uid=27, iid=1952, r_ui=None, est=4.076152096809526, details={'was_impossible': False}),
#  Prediction(uid=27, iid=2145, r_ui=None, est=3.691962230763644, details={'was_impossible': False}),
#  Prediction(uid=27, iid=3098, r_ui=None, est=3.9393454081589807, details={'was_impossible': False}),
#  Prediction(uid=27, iid=3365, r_ui=None, est=4.177929547564423, details={'was_impossible': False}),
#  Prediction(uid=27, iid=3671, r_ui=None, est=4.346410346417727, details={'was_impossible': False}),
#  Prediction(uid=28, iid=610, r_ui=None, est=4.339283771771904, details={'was_impossible': False}),
#  Prediction(uid=28, iid=1407, r_ui=None, est=4.115042884718564, details={'was_impossible': False}),
#  Prediction(uid=28, iid=1580, r_ui=None, est=4.403616419557851, details={'was_impossible': False}),
#  Prediction(uid=28, iid=1584, r_ui=None, est=4.575853044692205, details={'was_impossible': False}),
#  Prediction(uid=28, iid=1909, r_ui=None, est=4.132780739790953, details={'was_impossible': False}),
#  Prediction(uid=28, iid=2021, r_ui=None, est=4.193068074289366, details={'was_impossible': False}),
#  Prediction(uid=28, iid=2311, r_ui=None, est=4.3322590236931005, details={'was_impossible': False}),
#  Prediction(uid=28, iid=2723, r_ui=None, est=3.8697432093407627, details={'was_impossible': False}),
#  Prediction(uid=29, iid=69, r_ui=None, est=3.3788577220035387, details={'was_impossible': False}),
#  Prediction(uid=29, iid=175, r_ui=None, est=3.7122168148346515, details={'was_impossible': False}),
#  Prediction(uid=29, iid=562, r_ui=None, est=3.673160231887244, details={'was_impossible': False}),
#  Prediction(uid=29, iid=1354, r_ui=None, est=3.8101149420621616, details={'was_impossible': False}),
#  Prediction(uid=29, iid=1619, r_ui=None, est=3.435695756108151, details={'was_impossible': False}),
#  Prediction(uid=29, iid=55553, r_ui=None, est=3.287600257280683, details={'was_impossible': False}),
#  Prediction(uid=29, iid=69784, r_ui=None, est=3.167587432749786, details={'was_impossible': False}),
#  Prediction(uid=29, iid=72641, r_ui=None, est=3.393741061325843, details={'was_impossible': False}),
#  Prediction(uid=30, iid=410, r_ui=None, est=3.778252330354393, details={'was_impossible': False}),
#  Prediction(uid=30, iid=1580, r_ui=None, est=3.95720752386469, details={'was_impossible': False}),
#  Prediction(uid=30, iid=4701, r_ui=None, est=3.6646212028043212, details={'was_impossible': False}),
#  Prediction(uid=30, iid=33004, r_ui=None, est=3.9698280975572033, details={'was_impossible': False}),
#  Prediction(uid=30, iid=33794, r_ui=None, est=3.7707022110203803, details={'was_impossible': False}),
#  Prediction(uid=30, iid=91542, r_ui=None, est=3.506636088500875, details={'was_impossible': False}),
#  Prediction(uid=31, iid=47, r_ui=None, est=2.5085408210505986, details={'was_impossible': False}),
#  Prediction(uid=31, iid=110, r_ui=None, est=2.636359789317647, details={'was_impossible': False}),
#  Prediction(uid=31, iid=141, r_ui=None, est=2.4675801834292916, details={'was_impossible': False}),
#  Prediction(uid=31, iid=161, r_ui=None, est=2.652781266989383, details={'was_impossible': False}),
#  Prediction(uid=31, iid=253, r_ui=None, est=1.893108194516289, details={'was_impossible': False}),
#  Prediction(uid=31, iid=260, r_ui=None, est=2.495880748871654, details={'was_impossible': False}),
#  Prediction(uid=31, iid=377, r_ui=None, est=2.9159468124883174, details={'was_impossible': False}),
#  Prediction(uid=31, iid=434, r_ui=None, est=2.333038537788967, details={'was_impossible': False}),
#  Prediction(uid=31, iid=454, r_ui=None, est=2.6397640180351964, details={'was_impossible': False}),
#  Prediction(uid=31, iid=474, r_ui=None, est=2.868090218819817, details={'was_impossible': False}),
#  Prediction(uid=31, iid=587, r_ui=None, est=2.7334558902727486, details={'was_impossible': False}),
#  Prediction(uid=31, iid=648, r_ui=None, est=2.163129047727848, details={'was_impossible': False}),
#  Prediction(uid=31, iid=736, r_ui=None, est=2.356939051985689, details={'was_impossible': False}),
#  Prediction(uid=31, iid=932, r_ui=None, est=3.1609607628431915, details={'was_impossible': False}),
#  Prediction(uid=31, iid=1036, r_ui=None, est=3.090688915036503, details={'was_impossible': False}),
#  Prediction(uid=31, iid=1079, r_ui=None, est=2.9126522784150586, details={'was_impossible': False}),
#  Prediction(uid=31, iid=1258, r_ui=None, est=3.0356303888445213, details={'was_impossible': False}),
#  Prediction(uid=31, iid=1393, r_ui=None, est=2.705343935835324, details={'was_impossible': False}),
#  Prediction(uid=31, iid=1459, r_ui=None, est=2.5370062539667613, details={'was_impossible': False}),
#  Prediction(uid=31, iid=1479, r_ui=None, est=2.0640345913903415, details={'was_impossible': False}),
#  Prediction(uid=31, iid=1625, r_ui=None, est=2.833091448850078, details={'was_impossible': False}),
#  Prediction(uid=31, iid=1641, r_ui=None, est=3.1040291544886403, details={'was_impossible': False}),
#  Prediction(uid=31, iid=1693, r_ui=None, est=2.3756108631571196, details={'was_impossible': False}),
#  Prediction(uid=31, iid=1923, r_ui=None, est=2.417084065744691, details={'was_impossible': False}),
#  Prediction(uid=31, iid=2028, r_ui=None, est=2.8892396017842477, details={'was_impossible': False}),
#  Prediction(uid=31, iid=2081, r_ui=None, est=2.6502351874744567, details={'was_impossible': False}),
#  Prediction(uid=31, iid=2141, r_ui=None, est=2.64994065532767, details={'was_impossible': False}),
#  Prediction(uid=31, iid=2262, r_ui=None, est=2.4323140392274167, details={'was_impossible': False}),
#  Prediction(uid=31, iid=2321, r_ui=None, est=2.4462073147429284, details={'was_impossible': False}),
#  Prediction(uid=31, iid=2396, r_ui=None, est=3.035295012185295, details={'was_impossible': False}),
#  Prediction(uid=31, iid=2710, r_ui=None, est=1.731935943679159, details={'was_impossible': False}),
#  Prediction(uid=31, iid=3004, r_ui=None, est=1.6224949926915542, details={'was_impossible': False}),
#  Prediction(uid=31, iid=3081, r_ui=None, est=2.1523256096312866, details={'was_impossible': False}),
#  Prediction(uid=31, iid=3175, r_ui=None, est=2.947744646984523, details={'was_impossible': False}),
#  Prediction(uid=31, iid=3206, r_ui=None, est=2.4265794978542683, details={'was_impossible': False}),
#  Prediction(uid=31, iid=3253, r_ui=None, est=2.412640643442858, details={'was_impossible': False}),
#  Prediction(uid=31, iid=3408, r_ui=None, est=2.954448055345328, details={'was_impossible': False}),
#  Prediction(uid=31, iid=3420, r_ui=None, est=2.677932556621695, details={'was_impossible': False}),
#  Prediction(uid=31, iid=3481, r_ui=None, est=2.617351363819342, details={'was_impossible': False}),
#  Prediction(uid=31, iid=3525, r_ui=None, est=2.2910496751729785, details={'was_impossible': False}),
#  Prediction(uid=31, iid=3755, r_ui=None, est=1.9011660578480398, details={'was_impossible': False}),
#  Prediction(uid=31, iid=3793, r_ui=None, est=2.1103852916849033, details={'was_impossible': False}),
#  Prediction(uid=31, iid=3841, r_ui=None, est=2.0864686885898998, details={'was_impossible': False}),
#  Prediction(uid=31, iid=4174, r_ui=None, est=2.91134248552967, details={'was_impossible': False}),
#  Prediction(uid=31, iid=4392, r_ui=None, est=2.729026419551035, details={'was_impossible': False}),
#  Prediction(uid=31, iid=4564, r_ui=None, est=2.2217770511772437, details={'was_impossible': False}),
#  Prediction(uid=31, iid=4639, r_ui=None, est=1.6924703709248126, details={'was_impossible': False}),
#  Prediction(uid=31, iid=4973, r_ui=None, est=2.8366598972645325, details={'was_impossible': False}),
#  Prediction(uid=31, iid=4995, r_ui=None, est=2.9632112597867097, details={'was_impossible': False}),
#  Prediction(uid=31, iid=5377, r_ui=None, est=2.8188894986463833, details={'was_impossible': False}),
#  Prediction(uid=31, iid=5472, r_ui=None, est=2.52890717828904, details={'was_impossible': False}),
#  ...]

# %%
# Converting our prediction into a familiar format-Dataframe
df_pred=pd.DataFrame(ratings_predictions)
# View the predictions from a dataframe
df_pred
# Out:
#             uid   iid  r_ui       est                    details
# 0             1  2011  None  3.285756  {'was_impossible': False}
# 1             1  4144  None  4.229715  {'was_impossible': False}
# 2             1  5767  None  3.777707  {'was_impossible': False}
# 3             1  6711  None  3.656562  {'was_impossible': False}
# 4             1  7318  None  2.785522  {'was_impossible': False}
# ...         ...   ...   ...       ...                        ...
# 5000014  162541  4079  None  3.838687  {'was_impossible': False}
# 5000015  162541  4467  None  3.991202  {'was_impossible': False}
# 5000016  162541  4980  None  2.768307  {'was_impossible': False}
# 5000017  162541  5689  None  2.850262  {'was_impossible': False}
# 5000018  162541  7153  None  4.863075  {'was_impossible': False}
#
# [5000019 rows x 5 columns]

# %%
# Renaming our predictions to original names
df_pred=df_pred.rename(columns={'uid':'userId', 'iid':'movieId','est':'rating'})
# Drop the columns not required for the submission
df_pred.drop(['r_ui','details'],axis=1,inplace=True)

# %%
# Snippet of our ratings
df_pred.head()
# Out:
#    userId  movieId    rating
# 0       1     2011  3.285756
# 1       1     4144  4.229715
# 2       1     5767  3.777707
# 3       1     6711  3.656562
# 4       1     7318  2.785522

# %%
# Concatenating userId/movieId into a single Id column.(code has to be run twice to get desired outcome)
df_pred['Id']=df_pred.apply(lambda x:'%s_%s' % (x['userId'],x['movieId']),axis=1)
df_pred['Id']=df_pred.apply(lambda x:'%s_%s' % (x['userId'],x['movieId']),axis=1)

# %%
# View the top 5 rows for the prediction
df_pred.head()
# Out:
#    userId  movieId    rating      Id
# 0       1     2011  3.285756  1_2011
# 1       1     4144  4.229715  1_4144
# 2       1     5767  3.777707  1_5767
# 3       1     6711  3.656562  1_6711
# 4       1     7318  2.785522  1_7318

# %%
# Drop the features that will not be required for the submission
df_pred.drop(['userId', 'movieId'], inplace=True, axis= 1)

# %%
# Datframe that will be ready for submission
df_pred = df_pred[['Id', 'rating']]

# %%
# View the first 5 rows 
df_pred.head()
# Out:
#        Id    rating
# 0  1_2011  3.285756
# 1  1_4144  4.229715
# 2  1_5767  3.777707
# 3  1_6711  3.656562
# 4  1_7318  2.785522

# %%
# Shape of the prediction dataset
df_pred.shape
# Out:
# (5000019, 2)

# %%
# Submission final csv. file
df_pred.to_csv("SVD_altered_params.csv", index=False)

# %% [markdown]
# # **Additional Links For Notebook**

# %% [markdown]
# There are a number of models that were used before selecting the SVD model as the performing model. By clicking on the models represented, it will directly link to the model on Github.
#
# 1. [Baseline model](https://github.com/Thami-ex/unsupervised-predict-streamlit-template/blob/master/Notebooks/Baseline%20Only%20model.ipynb)
#
# 2. [Co Clustering model](https://github.com/Thami-ex/unsupervised-predict-streamlit-template/blob/master/Notebooks/Co_Clustering%20Model.ipynb)
#
# 3. [Non-Negative Matrix Factorization model](https://github.com/Thami-ex/unsupervised-predict-streamlit-template/blob/master/Notebooks/nmf-model.ipynb)
#
# 4. [SVDpp](https://github.com/Thami-ex/unsupervised-predict-streamlit-template/blob/master/Notebooks/SVDpp%20Model%20.ipynb)

# %% [markdown]
# # Links
#
# - [Github](https://github.com/Thami-ex/unsupervised-predict-streamlit-template)
# - [Trello Board](https://trello.com/b/9pCAjCmW/team5unsupervised)

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# In this notebook, the movieLens dataset was used to create our recommender system. The dataset draws on movie ratings and movie specific data dating back over 50 years. The EDA revealed to us that there was an increase in movie production from 1990 to 2000 which subsequently slowed down in the last few years.
#
#
# We observed that a high percentage of our movies were rated above  3  with the top 3 occurring ratings being 4, 3 and 5 in that order and that alone comprised 50% of total ratings. There are 19 unique movie genres in the dataset with Drama, comedy and thriller being the 3 most popular genres.
#
#
# We attempted  4 different techniques for building a recommender system. Due to its computational inefficiency we excluded the content base method as a solution.
#
#
# In order to produce new recommendations we attempted collaborative based filtering methods because they draw only on past interactions between users and items. These methods do not require item meta-data like their content-based counterparts. This has an added advantage of adapting users' interest which might change over time.
#
#
# We found that  sparsity and scalability were a challenge when we attempted both user-based and item-based memory methods. We settled on the singular value decomposition(SVD), a collaborative filtering method that deals with the sparsity that  we had with the user-user and item-item memory based methods, the advantage of being computationally more efficient than content based method .
#
#
# The SVD model was able to predict new ratings with a RMSE score of 0.79343 on kaggle.
#
#
# **Possible improvements:**
#
# Collaborative filtering methods have an issue with the cold start problem, which the content based filtering method doesn’t. This problem can be addressed by implementing a hybrid recommender system that uses a combination of both content and collaborative filtering based methods.

# %% [markdown]
# # Collaborators
#
# 1. Thamsanqa Funzani
# 2. Maria Rakau
# 3. Kundani Netshiongolwe
# 4. Lancelot Ngobeni
# 5. Warren Alpha Mbekezeli
# 6. Lazola Javu

# %% [markdown]
# # **Acknowledgements**

# %% [markdown]
# ![](https://media.giphy.com/media/oenruB2DKC7p6/giphy.gif)

# %% [markdown]
# # Reference

# %% [markdown]
# https://codeburst.io/explanation-of-recommender-systems-in-information-retrieval-13077e1d916c [Accessed: 25/11/20]
#
# www.quora.com. (n.d.). Recommendation Systems: What is the difference between item-to-item collaborative filtering and content-based filtering? - Quora. [online] Available at: https://www.quora.com/Recommendation-Systems-What-is-the-difference-between-item-to-item-collaborative-filtering-and-content-based-filtering
#
# Lungu, C. (2018). Building a recommender system. [online] Machine Learning Blog. Available at: http://www.clungu.com/Building-a-recommender-system
#
# Cold start problem - http://www.yusp.com/blog/cold-start-problem-recommender-systems/ 32a. Frank Kane, Sundog Education
#
# Towards datascience. 2018. Building and Testing Recommender Systems With Surprise, Step-By-Step. [ONLINE] Available at: https://towardsdatascience.com/building-and-testing-recommender-systems-with-surprise-step-by-step-d4ba702ef80b. [Accessed 13 December 2020].

# %% [markdown]
# # Comet

# %%
# #Log Parameters of all models
# params ={'SVD_model type': 'SVD',
#          'SVD_Params': str(svd_params),
         
#          'stratify':True
# }

# %%
# # Log our parameters and results
# experiment.log_parameters(params)

# %%
# experiment.end()
# experiment.display
